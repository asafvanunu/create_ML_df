# %% [markdown]
# **Name**:
# Create_ML_data_frame
#
# **Description**:
# This note book create a dateframe of GOES images and their temporal 4 previous images.
#
# **Date created**:
# `2024-12-24`
#
# **Author**:
# Asaf Vanunu
#
# ---

# %%
import GOES_VIIRS_tools
import os
import rioxarray
import pandas as pd
import geopandas as gpd
import numpy as np
import rasterio
import matplotlib.pyplot as plt
from rasterio.plot import show
import xarray as xr
from datetime import datetime, timedelta, time

# %% [markdown]
# * open CSV of GOES and VIIRS df

# %%
for file in os.listdir(os.getcwd()): ## loop through all files in the directory
    if file.endswith("csv"): ## if the file is a csv
        df = pd.read_csv(file) ## read the csv
df[:5]
# Out:
#      GOES_file_name    GOES_date_time  \
# 0  s202201010731.nc  2022-01-01 07:31
# 1  s202201010911.nc  2022-01-01 09:11
# 2  s202201011846.nc  2022-01-01 18:46
# 3  s202201012021.nc  2022-01-01 20:21
# 4  s202201012031.nc  2022-01-01 20:31
#
#                                                 MCMI  \
# 0  F:\ML_project\GOES_16\MCMI\OR_ABI-L2-MCMIPC-M6...
# 1  F:\ML_project\GOES_16\MCMI\OR_ABI-L2-MCMIPC-M6...
# 2  F:\ML_project\GOES_16\MCMI\OR_ABI-L2-MCMIPC-M6...
# 3  F:\ML_project\GOES_16\MCMI\OR_ABI-L2-MCMIPC-M6...
# 4  F:\ML_project\GOES_16\MCMI\OR_ABI-L2-MCMIPC-M6...
#
#                                                  FDC  \
# 0  F:\ML_project\GOES_16\FDC\OR_ABI-L2-FDCC-M6_G1...
# 1  F:\ML_project\GOES_16\FDC\OR_ABI-L2-FDCC-M6_G1...
# 2  F:\ML_project\GOES_16\FDC\OR_ABI-L2-FDCC-M6_G1...
# 3  F:\ML_project\GOES_16\FDC\OR_ABI-L2-FDCC-M6_G1...
# 4  F:\ML_project\GOES_16\FDC\OR_ABI-L2-FDCC-M6_G1...
#
#                                                  ACM  \
# 0  F:\ML_project\GOES_16\ACM\OR_ABI-L2-ACMC-M6_G1...
# 1  F:\ML_project\GOES_16\ACM\OR_ABI-L2-ACMC-M6_G1...
# 2  F:\ML_project\GOES_16\ACM\OR_ABI-L2-ACMC-M6_G1...
# 3  F:\ML_project\GOES_16\ACM\OR_ABI-L2-ACMC-M6_G1...
# 4  F:\ML_project\GOES_16\ACM\OR_ABI-L2-ACMC-M6_G1...
#
#                                     VIIRS_file  \
# 0  VNP14IMG.A2022001.0724.002.2024075110909.nc
# 1  VNP14IMG.A2022001.0906.002.2024075110907.nc
# 2  VNP14IMG.A2022001.1842.002.2024075110906.nc
# 3  VNP14IMG.A2022001.2018.002.2024075110907.nc
# 4  VNP14IMG.A2022001.2024.002.2024075110907.nc
#
#                                 VIIRS_file_full_path
# 0  F:\ML_project\east_us\VIIRS\VIIRS_fire\VNP14IM...
# 1  F:\ML_project\east_us\VIIRS\VIIRS_fire\VNP14IM...
# 2  F:\ML_project\east_us\VIIRS\VIIRS_fire\VNP14IM...
# 3  F:\ML_project\east_us\VIIRS\VIIRS_fire\VNP14IM...
# 4  F:\ML_project\east_us\VIIRS\VIIRS_fire\VNP14IM...

# %% [markdown]
# * Now we will set the dir of the temporal GOES images

# %%
temporal_GOES_dir = "F:\\ML_project\\GOES_16\\temporal_GOES"

# %% [markdown]
# * create a function to make GOES date as the dir of the temporal images

# %%
def GOES_date_to_dir_format(goes_date):
    """Get a GOES date and return it in the format that the directory uses.

    Args:
        goes_date (str): GOES date in a string for example "2022-01-01 07:31"
    """
    under_line_date = goes_date.replace(" ", "_") ## replace the space with an underscore
    out_format = under_line_date.replace(":", "-") ## replace the colon with nothing
    return out_format ## return the date in the format that the directory uses

# %% [markdown]
# * now we can create an array of this date format

# %%
GOES_time_dir_format_list = np.array(list(map(GOES_date_to_dir_format, df["GOES_date_time"]))) ## get the GOES date in the format that the directory uses
GOES_time_dir_format_list[:5]
# Out:
# array(['2022-01-01_07-31', '2022-01-01_09-11', '2022-01-01_18-46',
#        '2022-01-01_20-21', '2022-01-01_20-31'], dtype='<U16')

# %%
def GOES_dir_format_to_str(goes_dir_format):
    """get the GOES directory format and return it in a string format.

    Args:
        goes_dir_format (str): for example "2022-01-01_07-31"
    """
    YMD = goes_dir_format.split("_")[0] ## get the year, month, and day
    HM = goes_dir_format.split("_")[1] ## get the hour and minute
    HM_out = HM.replace("-", ":") ## replace the dash with a colon
    out = f"{YMD} {HM_out}" ## combine the year, month, day, hour, and minute
    return out ## return the date in a string format

# %% [markdown]
# * Now we can create function to get files in each folder

# %%
def get_GOES_temproal_df(goes_time_in_dir_format, temporal_GOES_dir):
    """Insert GOES date in the format that the directory uses and return a dataframe with GOES images matching that time in FDC, ACM and MCMI
    

    Args:
        goes_time_in_dir_format (str): GOES dir format for exmaple "2022-01-01_07-31"
        temporal_GOES_dir (str): Directory where the GOES images are stored
    """
    product_list = ["FDC", "ACM", "MCMI"] ## list of products
    dir_path = os.path.join(temporal_GOES_dir, goes_time_in_dir_format) ## get the directory path
    if os.path.exists(dir_path): ## if the directory exists
        print(f"Directory {dir_path} exists") ## print that the directory exists
        ACM_files_list = [] ## list to store the ACM files
        FDC_files_list = [] ## list to store the FDC files
        MCMI_files_list = [] ## list to store the MCMI files
        for product in product_list: ## loop through the products
            product_dir = os.path.join(dir_path, product) ## get the product directory
            list_of_images_dir = [os.path.join(product_dir, image) for image in os.listdir(product_dir)] ## get the list of images in the directory
            if len(list_of_images_dir) !=4: ## if the length of the list is not 4
                print(f"Missing images in {product_dir}") ## print that the images are missing
                return None ## return None
            else: ## if the length of the list is 4
                list_of_images_dir.sort(reverse=True) ## sort the list
                for image in list_of_images_dir: ## loop through the images
                    if product == "FDC": ## if the product is FDC
                        FDC_files_list.append(image) ## append the image to the FDC list
                    elif product == "ACM": ## if the product is ACM
                        ACM_files_list.append(image) ## append the image to the ACM list
                    elif product == "MCMI": ## if the product is MCMI
                        MCMI_files_list.append(image) ## append the image to the MCMI list
                        
        file_name_time = GOES_dir_format_to_str(goes_time_in_dir_format) ## get the file name in str
        file_name_time_list = np.repeat(file_name_time, len(ACM_files_list)) ## repeat the file name 4 times
        d = {"GOES_date_time": file_name_time_list, "MCMI": MCMI_files_list, "FDC":FDC_files_list, "ACM":ACM_files_list} ## create a dictionary
        df = pd.DataFrame(data = d) ## create a dataframe
        return df
    else:
        print(f"Directory {dir_path} does not exist") ## print that the directory does not exist
        return None ## return None

# %%
df_temporal_list = [] ## list to store the dataframes
no_4_files = [] ## list to store the GOES time that do not have 4 files
for i in range(len(GOES_time_dir_format_list)): ## loop through the GOES time dir format list
    goes_time = GOES_time_dir_format_list[i] ## get the GOES time
    df_temporal = get_GOES_temproal_df(goes_time, temporal_GOES_dir) ## get the GOES temporal dataframe
    if isinstance(df_temporal, pd.DataFrame):
        df_temporal_list.append(df_temporal)
        print(f"Appended {i}")
    else:
        no_4_files.append(GOES_dir_format_to_str(goes_time))
# Out:
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-01_07-31 exists
# Appended 0
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-01_09-11 exists
# Appended 1
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-01_18-46 exists
# Appended 2
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-01_20-21 exists
# Appended 3
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-01_20-31 exists
# Appended 4
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-02_07-11 exists
# Appended 5
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-02_08-46 exists
# Appended 6
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-02_08-51 exists
# Appended 7
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-02_18-21 exists
# Appended 8
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-02_18-31 exists
# Appended 9
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-02_20-06 exists
# Appended 10
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-02_20-11 exists
# Appended 11
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-03_06-51 exists
# Appended 12
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-03_08-31 exists
# Appended 13
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-03_08-36 exists
# Appended 14
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-03_18-06 exists
# Appended 15
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-03_18-11 exists
# Appended 16
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-03_19-46 exists
# Appended 17
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-03_19-51 exists
# Appended 18
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-04_08-11 exists
# Appended 19
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-04_08-16 exists
# Appended 20
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-04_17-46 exists
# Appended 21
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-04_19-31 exists
# Appended 22
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-04_21-11 exists
# Appended 23
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-05_06-11 exists
# Appended 24
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-05_07-51 exists
# Appended 25
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-05_08-01 exists
# Appended 26
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-05_09-36 exists
# Appended 27
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-05_17-31 exists
# Appended 28
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-05_19-11 exists
# Appended 29
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-05_20-51 exists
# Appended 30
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-06_07-36 exists
# Appended 31
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-06_09-16 exists
# Appended 32
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-06_18-51 exists
# Appended 33
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-06_20-31 exists
# Appended 34
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-06_20-36 exists
# Appended 35
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-07_07-16 exists
# Appended 36
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-07_08-51 exists
# Appended 37
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-07_09-01 exists
# Appended 38
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-07_18-31 exists
# Appended 39
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-07_18-36 exists
# Appended 40
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-07_20-11 exists
# Appended 41
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-07_20-16 exists
# Appended 42
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-08_06-51 exists
# Appended 43
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-08_07-01 exists
# Appended 44
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-08_08-36 exists
# Appended 45
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-08_08-41 exists
# Appended 46
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-08_18-11 exists
# Appended 47
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-08_18-16 exists
# Appended 48
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-08_19-51 exists
# Appended 49
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-08_20-01 exists
# Appended 50
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-09_06-36 exists
# Appended 51
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-09_06-41 exists
# Appended 52
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-09_08-16 exists
# Appended 53
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-09_08-21 exists
# Appended 54
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-09_17-51 exists
# Appended 55
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-09_18-01 exists
# Appended 56
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-09_19-36 exists
# Appended 57
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-09_19-41 exists
# Appended 58
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-10_08-01 exists
# Appended 59
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-10_09-41 exists
# Appended 60
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-10_17-36 exists
# Appended 61
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-10_19-16 exists
# Appended 62
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-10_21-01 exists
# Appended 63
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-11_07-41 exists
# Appended 64
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-11_09-21 exists
# Appended 65
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-11_19-01 exists
# Appended 66
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-11_20-41 exists
# Appended 67
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-12_07-21 exists
# Appended 68
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-12_09-01 exists
# Appended 69
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-12_09-06 exists
# Appended 70
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-12_18-36 exists
# Appended 71
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-12_18-41 exists
# Appended 72
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-12_20-16 exists
# Appended 73
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-12_20-21 exists
# Appended 74
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-13_07-06 exists
# Appended 75
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-13_08-41 exists
# Appended 76
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-13_08-46 exists
# Appended 77
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-13_18-16 exists
# Appended 78
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-13_18-21 exists
# Appended 79
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-13_20-01 exists
# Appended 80
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-13_20-06 exists
# Appended 81
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-14_06-41 exists
# Appended 82
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-14_06-46 exists
# Appended 83
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-14_08-21 exists
# Appended 84
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-14_08-31 exists
# Appended 85
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-14_18-01 exists
# Appended 86
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-14_18-06 exists
# Appended 87
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-14_19-41 exists
# Appended 88
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-14_21-21 exists
# Appended 89
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-15_06-21 exists
# Appended 90
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-15_06-31 exists
# Appended 91
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-15_08-06 exists
# Appended 92
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-15_08-11 exists
# Appended 93
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-15_17-41 exists
# Appended 94
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-15_19-21 exists
# Appended 95
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-15_21-06 exists
# Appended 96
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-16_07-46 exists
# Appended 97
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-16_09-31 exists
# Appended 98
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-16_19-06 exists
# Appended 99
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-16_20-41 exists
# Appended 100
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-16_20-46 exists
# Appended 101
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-17_07-31 exists
# Appended 102
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-17_09-06 exists
# Appended 103
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-17_09-11 exists
# Appended 104
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-17_18-46 exists
# Appended 105
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-17_20-21 exists
# Appended 106
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-17_20-31 exists
# Appended 107
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-18_07-11 exists
# Appended 108
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-18_08-46 exists
# Appended 109
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-18_08-51 exists
# Appended 110
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-18_18-21 exists
# Appended 111
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-18_18-31 exists
# Appended 112
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-18_20-06 exists
# Appended 113
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-18_20-11 exists
# Appended 114
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-19_06-46 exists
# Appended 115
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-19_06-51 exists
# Appended 116
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-19_08-31 exists
# Appended 117
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-19_08-36 exists
# Appended 118
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-19_18-06 exists
# Appended 119
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-19_18-11 exists
# Appended 120
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-19_19-46 exists
# Appended 121
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-20_06-31 exists
# Appended 122
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-20_06-36 exists
# Appended 123
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-20_08-11 exists
# Appended 124
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-20_17-46 exists
# Appended 125
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-20_19-31 exists
# Appended 126
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-20_21-11 exists
# Appended 127
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-21_07-51 exists
# Appended 128
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-21_09-36 exists
# Appended 129
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-21_19-11 exists
# Appended 130
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-21_20-51 exists
# Appended 131
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-22_07-36 exists
# Appended 132
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-22_09-16 exists
# Appended 133
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-22_18-51 exists
# Appended 134
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-22_20-31 exists
# Appended 135
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-22_20-36 exists
# Appended 136
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-23_07-16 exists
# Appended 137
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-23_08-51 exists
# Appended 138
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-23_09-01 exists
# Appended 139
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-23_18-36 exists
# Appended 140
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-23_20-11 exists
# Appended 141
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-23_20-16 exists
# Appended 142
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-24_06-51 exists
# Appended 143
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-24_07-01 exists
# Appended 144
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-24_08-36 exists
# Appended 145
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-24_08-41 exists
# Appended 146
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-24_18-11 exists
# Appended 147
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-24_18-16 exists
# Appended 148
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-24_19-51 exists
# Appended 149
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-24_20-01 exists
# Appended 150
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-25_08-16 exists
# Appended 151
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-25_08-21 exists
# Appended 152
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-25_18-01 exists
# Appended 153
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-25_19-36 exists
# Appended 154
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-25_21-16 exists
# Appended 155
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-26_08-01 exists
# Appended 156
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-26_09-41 exists
# Appended 157
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-26_17-36 exists
# Appended 158
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-26_19-16 exists
# Appended 159
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-26_21-01 exists
# Appended 160
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-27_07-41 exists
# Appended 161
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-27_09-16 exists
# Appended 162
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-27_09-21 exists
# Appended 163
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-27_19-01 exists
# Appended 164
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-27_20-41 exists
# Appended 165
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-28_07-21 exists
# Appended 166
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-28_09-01 exists
# Appended 167
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-28_09-06 exists
# Appended 168
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-28_18-36 exists
# Appended 169
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-28_18-41 exists
# Appended 170
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-28_20-16 exists
# Appended 171
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-28_20-21 exists
# Appended 172
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-29_07-01 exists
# Appended 173
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-29_07-06 exists
# Appended 174
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-29_08-41 exists
# Appended 175
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-29_08-46 exists
# Appended 176
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-29_18-16 exists
# Appended 177
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-29_18-21 exists
# Appended 178
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-29_20-01 exists
# Appended 179
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-29_20-06 exists
# Appended 180
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-30_06-41 exists
# Appended 181
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-30_06-46 exists
# Appended 182
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-30_08-21 exists
# Appended 183
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-30_08-31 exists
# Appended 184
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-30_18-01 exists
# Appended 185
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-30_18-06 exists
# Appended 186
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-30_19-41 exists
# Appended 187
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-31_06-21 exists
# Appended 188
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-31_08-06 exists
# Appended 189
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-31_08-11 exists
# Appended 190
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-31_17-41 exists
# Appended 191
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-31_19-21 exists
# Appended 192
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-01-31_21-06 exists
# Appended 193
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-01_07-46 exists
# Appended 194
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-01_09-21 exists
# Appended 195
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-01_09-31 exists
# Appended 196
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-01_19-06 exists
# Appended 197
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-01_20-41 exists
# Appended 198
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-01_20-46 exists
# Appended 199
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-02_07-31 exists
# Appended 200
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-02_09-11 exists
# Appended 201
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-02_18-41 exists
# Appended 202
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-02_18-46 exists
# Appended 203
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-02_20-21 exists
# Appended 204
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-02_20-31 exists
# Appended 205
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-03_07-11 exists
# Appended 206
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-03_08-51 exists
# Appended 207
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-03_18-21 exists
# Appended 208
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-03_18-31 exists
# Appended 209
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-03_20-06 exists
# Appended 210
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-04_06-46 exists
# Appended 211
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-04_06-51 exists
# Appended 212
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-04_08-31 exists
# Appended 213
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-04_08-36 exists
# Appended 214
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-04_18-06 exists
# Appended 215
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-04_19-46 exists
# Appended 216
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-05_06-36 exists
# Appended 217
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-05_08-11 exists
# Appended 218
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-05_08-16 exists
# Appended 219
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-05_09-51 exists
# Appended 220
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-05_17-46 exists
# Appended 221
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-05_19-31 exists
# Appended 222
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-05_21-11 exists
# Appended 223
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-06_07-51 exists
# Appended 224
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-06_09-36 exists
# Appended 225
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-06_19-11 exists
# Appended 226
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-06_20-46 exists
# Appended 227
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-06_20-51 exists
# Appended 228
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-07_07-36 exists
# Appended 229
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-07_09-11 exists
# Appended 230
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-07_09-16 exists
# Appended 231
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-07_18-51 exists
# Appended 232
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-07_20-31 exists
# Appended 233
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-07_20-36 exists
# Appended 234
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-08_07-16 exists
# Appended 235
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-08_08-51 exists
# Appended 236
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-08_09-01 exists
# Appended 237
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-08_18-31 exists
# Appended 238
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-08_18-36 exists
# Appended 239
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-08_20-11 exists
# Appended 240
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-08_20-16 exists
# Appended 241
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-09_06-51 exists
# Appended 242
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-09_07-01 exists
# Appended 243
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-09_08-36 exists
# Appended 244
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-09_08-41 exists
# Appended 245
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-09_18-11 exists
# Appended 246
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-09_18-16 exists
# Appended 247
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-09_19-51 exists
# Appended 248
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-09_20-01 exists
# Appended 249
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-10_06-36 exists
# Appended 250
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-10_06-41 exists
# Appended 251
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-10_08-16 exists
# Appended 252
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-10_08-21 exists
# Appended 253
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-10_17-51 exists
# Appended 254
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-10_18-01 exists
# Appended 255
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-10_19-36 exists
# Appended 256
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-10_21-16 exists
# Appended 257
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-11_08-01 exists
# Appended 258
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-11_09-41 exists
# Appended 259
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-11_17-36 exists
# Appended 260
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-11_19-16 exists
# Appended 261
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-11_21-01 exists
# Appended 262
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-12_07-41 exists
# Appended 263
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-12_09-21 exists
# Appended 264
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-12_19-01 exists
# Appended 265
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-12_20-36 exists
# Appended 266
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-12_20-41 exists
# Appended 267
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-13_07-21 exists
# Appended 268
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-13_09-01 exists
# Appended 269
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-13_09-06 exists
# Appended 270
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-13_18-41 exists
# Appended 271
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-13_20-16 exists
# Appended 272
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-13_20-21 exists
# Appended 273
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-14_07-01 exists
# Appended 274
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-14_07-06 exists
# Appended 275
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-14_08-41 exists
# Appended 276
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-14_08-46 exists
# Appended 277
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-14_18-16 exists
# Appended 278
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-14_18-21 exists
# Appended 279
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-14_20-01 exists
# Appended 280
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-14_20-06 exists
# Appended 281
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-15_06-41 exists
# Appended 282
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-15_06-46 exists
# Appended 283
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-15_08-21 exists
# Appended 284
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-15_08-31 exists
# Appended 285
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-15_18-01 exists
# Appended 286
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-15_18-06 exists
# Appended 287
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-15_19-41 exists
# Appended 288
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-16_06-21 exists
# Appended 289
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-16_08-06 exists
# Appended 290
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-16_09-46 exists
# Appended 291
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-16_17-41 exists
# Appended 292
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-16_19-21 exists
# Appended 293
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-16_21-06 exists
# Appended 294
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-17_07-46 exists
# Appended 295
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-17_09-31 exists
# Appended 296
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-17_19-06 exists
# Appended 297
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-17_20-41 exists
# Appended 298
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-17_20-46 exists
# Appended 299
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-18_07-31 exists
# Appended 300
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-18_09-11 exists
# Appended 301
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-18_18-41 exists
# Appended 302
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-18_18-46 exists
# Appended 303
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-18_20-21 exists
# Appended 304
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-18_20-31 exists
# Appended 305
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-19_07-06 exists
# Appended 306
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-19_07-11 exists
# Appended 307
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-19_08-46 exists
# Appended 308
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-19_08-51 exists
# Appended 309
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-19_18-21 exists
# Appended 310
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-19_18-31 exists
# Appended 311
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-19_20-06 exists
# Appended 312
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-19_20-11 exists
# Appended 313
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-20_06-46 exists
# Appended 314
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-20_06-51 exists
# Appended 315
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-20_08-31 exists
# Appended 316
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-20_08-36 exists
# Appended 317
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-20_18-06 exists
# Appended 318
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-20_18-11 exists
# Appended 319
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-20_19-46 exists
# Appended 320
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-20_19-51 exists
# Appended 321
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-21_06-36 exists
# Appended 322
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-21_08-11 exists
# Appended 323
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-21_09-51 exists
# Appended 324
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-21_17-46 exists
# Appended 325
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-21_19-31 exists
# Appended 326
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-21_21-11 exists
# Appended 327
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-22_06-11 exists
# Appended 328
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-22_07-51 exists
# Appended 329
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-22_09-36 exists
# Appended 330
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-22_17-31 exists
# Appended 331
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-22_19-11 exists
# Appended 332
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-22_20-46 exists
# Appended 333
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-22_20-51 exists
# Appended 334
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-23_07-36 exists
# Appended 335
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-23_09-16 exists
# Appended 336
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-23_18-46 exists
# Appended 337
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-23_18-51 exists
# Appended 338
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-23_20-31 exists
# Appended 339
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-23_20-36 exists
# Appended 340
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-24_07-16 exists
# Appended 341
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-24_08-51 exists
# Appended 342
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-24_09-01 exists
# Appended 343
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-24_18-31 exists
# Appended 344
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-24_18-36 exists
# Appended 345
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-24_20-11 exists
# Appended 346
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-24_20-16 exists
# Appended 347
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-25_06-51 exists
# Appended 348
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-25_07-01 exists
# Appended 349
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-25_08-36 exists
# Appended 350
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-25_08-41 exists
# Appended 351
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-25_18-11 exists
# Appended 352
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-25_18-16 exists
# Appended 353
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-25_19-51 exists
# Appended 354
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-25_20-01 exists
# Appended 355
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-26_06-36 exists
# Appended 356
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-26_06-41 exists
# Appended 357
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-26_08-16 exists
# Appended 358
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-26_08-21 exists
# Appended 359
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-26_17-51 exists
# Appended 360
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-26_19-36 exists
# Appended 361
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-27_06-16 exists
# Appended 362
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-27_08-01 exists
# Appended 363
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-27_08-06 exists
# Appended 364
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-27_09-41 exists
# Appended 365
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-27_17-36 exists
# Appended 366
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-27_19-16 exists
# Appended 367
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-27_21-01 exists
# Appended 368
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-28_07-41 exists
# Appended 369
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-28_09-16 exists
# Appended 370
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-28_09-21 exists
# Appended 371
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-28_19-01 exists
# Appended 372
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-28_20-36 exists
# Appended 373
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-02-28_20-41 exists
# Appended 374
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-01_07-21 exists
# Appended 375
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-01_09-01 exists
# Appended 376
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-01_09-06 exists
# Appended 377
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-01_18-36 exists
# Appended 378
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-01_18-41 exists
# Appended 379
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-01_20-16 exists
# Appended 380
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-01_20-21 exists
# Appended 381
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-02_07-01 exists
# Appended 382
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-02_07-06 exists
# Appended 383
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-02_08-41 exists
# Appended 384
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-02_08-46 exists
# Appended 385
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-02_18-16 exists
# Appended 386
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-02_18-21 exists
# Appended 387
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-02_20-01 exists
# Appended 388
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-02_20-06 exists
# Appended 389
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-03_06-41 exists
# Appended 390
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-03_06-46 exists
# Appended 391
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-03_08-21 exists
# Appended 392
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-03_08-31 exists
# Appended 393
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-03_18-01 exists
# Appended 394
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-03_18-06 exists
# Appended 395
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-03_19-41 exists
# Appended 396
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-03_19-46 exists
# Appended 397
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-04_06-21 exists
# Appended 398
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-04_08-06 exists
# Appended 399
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-04_08-11 exists
# Appended 400
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-04_17-41 exists
# Appended 401
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-04_19-21 exists
# Appended 402
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-04_21-06 exists
# Appended 403
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-05_07-46 exists
# Appended 404
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-05_09-21 exists
# Appended 405
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-05_09-31 exists
# Appended 406
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-05_17-21 exists
# Missing images in F:\ML_project\GOES_16\temporal_GOES\2022-03-05_17-21\ACM
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-05_19-06 exists
# Appended 408
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-05_20-41 exists
# Appended 409
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-05_20-46 exists
# Appended 410
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-06_07-31 exists
# Appended 411
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-06_09-06 exists
# Appended 412
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-06_09-11 exists
# Appended 413
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-06_18-41 exists
# Appended 414
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-06_18-46 exists
# Appended 415
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-06_20-21 exists
# Appended 416
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-06_20-31 exists
# Appended 417
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-07_07-11 exists
# Appended 418
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-07_08-46 exists
# Appended 419
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-07_08-51 exists
# Appended 420
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-07_18-21 exists
# Appended 421
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-07_18-31 exists
# Appended 422
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-07_20-06 exists
# Appended 423
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-08_06-46 exists
# Appended 424
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-08_06-51 exists
# Appended 425
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-08_08-31 exists
# Appended 426
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-08_08-36 exists
# Appended 427
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-08_18-06 exists
# Appended 428
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-08_18-11 exists
# Appended 429
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-08_19-46 exists
# Appended 430
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-08_19-51 exists
# Appended 431
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-09_06-31 exists
# Appended 432
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-09_06-36 exists
# Appended 433
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-09_08-11 exists
# Appended 434
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-09_08-16 exists
# Appended 435
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-09_09-51 exists
# Appended 436
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-09_17-46 exists
# Appended 437
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-09_19-31 exists
# Appended 438
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-09_21-11 exists
# Appended 439
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-10_07-51 exists
# Appended 440
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-10_09-36 exists
# Appended 441
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-10_19-11 exists
# Appended 442
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-10_20-46 exists
# Appended 443
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-10_20-51 exists
# Appended 444
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-11_07-36 exists
# Appended 445
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-11_09-16 exists
# Appended 446
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-11_18-51 exists
# Appended 447
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-11_20-31 exists
# Appended 448
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-11_20-36 exists
# Appended 449
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-12_07-16 exists
# Appended 450
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-12_08-51 exists
# Appended 451
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-12_09-01 exists
# Appended 452
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-12_18-36 exists
# Appended 453
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-12_20-11 exists
# Appended 454
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-12_20-16 exists
# Appended 455
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-13_06-51 exists
# Appended 456
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-13_07-01 exists
# Appended 457
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-13_08-36 exists
# Appended 458
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-13_08-41 exists
# Appended 459
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-13_18-11 exists
# Appended 460
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-13_18-16 exists
# Appended 461
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-13_19-51 exists
# Appended 462
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-13_20-01 exists
# Appended 463
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-14_06-36 exists
# Appended 464
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-14_06-41 exists
# Appended 465
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-14_08-16 exists
# Appended 466
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-14_08-21 exists
# Appended 467
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-14_17-51 exists
# Appended 468
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-14_18-01 exists
# Appended 469
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-14_19-36 exists
# Appended 470
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-14_21-16 exists
# Appended 471
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-15_06-16 exists
# Appended 472
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-15_08-01 exists
# Appended 473
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-15_08-06 exists
# Appended 474
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-15_09-41 exists
# Appended 475
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-15_19-16 exists
# Appended 476
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-15_20-51 exists
# Appended 477
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-15_21-01 exists
# Appended 478
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-16_07-41 exists
# Appended 479
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-16_09-16 exists
# Appended 480
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-16_09-21 exists
# Appended 481
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-16_19-01 exists
# Appended 482
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-16_20-36 exists
# Appended 483
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-16_20-41 exists
# Appended 484
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-17_07-21 exists
# Appended 485
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-17_09-01 exists
# Appended 486
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-17_09-06 exists
# Appended 487
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-17_18-36 exists
# Appended 488
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-17_18-41 exists
# Appended 489
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-17_20-16 exists
# Appended 490
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-17_20-21 exists
# Appended 491
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-18_07-06 exists
# Appended 492
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-18_08-41 exists
# Appended 493
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-18_08-46 exists
# Appended 494
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-18_18-16 exists
# Appended 495
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-18_18-21 exists
# Appended 496
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-18_20-01 exists
# Appended 497
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-18_20-06 exists
# Appended 498
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-19_06-41 exists
# Appended 499
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-19_06-46 exists
# Appended 500
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-19_08-21 exists
# Appended 501
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-19_08-31 exists
# Appended 502
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-19_18-01 exists
# Appended 503
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-19_18-06 exists
# Appended 504
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-19_19-41 exists
# Appended 505
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-19_19-46 exists
# Appended 506
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-20_08-06 exists
# Appended 507
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-20_08-11 exists
# Appended 508
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-20_09-46 exists
# Appended 509
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-20_17-41 exists
# Appended 510
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-20_19-21 exists
# Appended 511
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-20_21-06 exists
# Appended 512
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-21_07-46 exists
# Appended 513
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-21_09-21 exists
# Appended 514
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-21_09-31 exists
# Appended 515
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-21_17-21 exists
# Appended 516
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-21_19-06 exists
# Appended 517
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-21_20-41 exists
# Appended 518
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-21_20-46 exists
# Appended 519
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-22_07-31 exists
# Appended 520
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-22_09-11 exists
# Appended 521
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-22_18-46 exists
# Appended 522
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-22_20-21 exists
# Appended 523
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-22_20-31 exists
# Appended 524
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-23_07-06 exists
# Appended 525
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-23_07-11 exists
# Appended 526
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-23_08-46 exists
# Appended 527
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-23_08-51 exists
# Appended 528
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-23_18-21 exists
# Appended 529
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-23_18-31 exists
# Appended 530
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-23_20-06 exists
# Appended 531
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-23_20-11 exists
# Appended 532
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-24_06-46 exists
# Appended 533
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-24_06-51 exists
# Appended 534
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-24_08-31 exists
# Appended 535
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-24_08-36 exists
# Appended 536
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-24_18-06 exists
# Appended 537
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-24_18-11 exists
# Appended 538
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-24_19-46 exists
# Appended 539
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-24_19-51 exists
# Appended 540
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-25_08-11 exists
# Appended 541
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-25_08-16 exists
# Appended 542
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-25_09-51 exists
# Appended 543
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-25_17-46 exists
# Appended 544
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-25_19-31 exists
# Appended 545
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-25_21-11 exists
# Appended 546
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-26_07-51 exists
# Appended 547
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-26_08-01 exists
# Appended 548
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-26_09-36 exists
# Appended 549
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-26_17-31 exists
# Appended 550
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-26_19-11 exists
# Appended 551
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-26_20-46 exists
# Appended 552
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-26_20-51 exists
# Appended 553
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-27_07-36 exists
# Appended 554
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-27_09-11 exists
# Appended 555
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-27_09-16 exists
# Appended 556
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-27_18-51 exists
# Appended 557
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-27_20-31 exists
# Appended 558
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-27_20-36 exists
# Appended 559
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-28_07-16 exists
# Appended 560
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-28_08-51 exists
# Appended 561
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-28_09-01 exists
# Appended 562
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-28_18-31 exists
# Appended 563
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-28_18-36 exists
# Appended 564
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-28_20-11 exists
# Appended 565
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-28_20-16 exists
# Appended 566
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-29_06-51 exists
# Appended 567
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-29_07-01 exists
# Appended 568
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-29_08-36 exists
# Appended 569
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-29_08-41 exists
# Appended 570
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-29_18-11 exists
# Appended 571
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-29_18-16 exists
# Appended 572
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-29_19-51 exists
# Appended 573
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-29_20-01 exists
# Appended 574
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-30_06-36 exists
# Appended 575
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-30_06-41 exists
# Appended 576
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-30_08-16 exists
# Appended 577
# Directory F:\ML_project\GOES_16\temporal_GOES\2022-03-30_08-21 exists
# ...
# Appended 4269
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-11-29_09-41 exists
# Appended 4270
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-11-29_17-36 exists
# Appended 4271
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-11-29_19-16 exists
# Appended 4272
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-11-29_21-01 exists
# Appended 4273
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-11-30_07-41 exists
# Appended 4274
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-11-30_09-21 exists
# Appended 4275
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-11-30_19-01 exists
# Appended 4276
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-11-30_20-41 exists
# Appended 4277
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-01_07-21 exists
# Appended 4278
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-01_09-06 exists
# Appended 4279
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-01_18-41 exists
# Appended 4280
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-01_20-16 exists
# Appended 4281
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-01_20-21 exists
# Appended 4282
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-02_07-01 exists
# Appended 4283
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-02_08-41 exists
# Appended 4284
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-02_08-46 exists
# Appended 4285
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-02_18-16 exists
# Appended 4286
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-02_20-01 exists
# Appended 4287
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-02_20-06 exists
# Appended 4288
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-03_06-46 exists
# Appended 4289
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-03_08-21 exists
# Appended 4290
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-03_08-31 exists
# Appended 4291
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-03_18-01 exists
# Appended 4292
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-03_18-06 exists
# Appended 4293
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-03_19-41 exists
# Appended 4294
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-03_19-46 exists
# Appended 4295
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-04_08-06 exists
# Appended 4296
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-04_08-11 exists
# Appended 4297
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-04_19-21 exists
# Appended 4298
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-04_21-06 exists
# Appended 4299
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-05_07-46 exists
# Appended 4300
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-05_09-31 exists
# Appended 4301
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-05_17-21 exists
# Appended 4302
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-05_20-46 exists
# Appended 4303
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-06_07-31 exists
# Appended 4304
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-06_09-06 exists
# Appended 4305
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-06_09-11 exists
# Appended 4306
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-06_18-46 exists
# Appended 4307
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-06_20-21 exists
# Appended 4308
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-06_20-31 exists
# Appended 4309
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-07_07-11 exists
# Appended 4310
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-07_08-46 exists
# Appended 4311
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-07_08-51 exists
# Appended 4312
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-07_18-21 exists
# Appended 4313
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-07_18-31 exists
# Appended 4314
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-07_20-06 exists
# Appended 4315
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-07_20-11 exists
# Appended 4316
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-08_06-46 exists
# Appended 4317
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-08_06-51 exists
# Appended 4318
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-08_08-31 exists
# Appended 4319
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-08_08-36 exists
# Appended 4320
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-08_18-06 exists
# Appended 4321
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-08_18-11 exists
# Appended 4322
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-08_19-46 exists
# Appended 4323
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-08_19-51 exists
# Appended 4324
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-09_06-31 exists
# Appended 4325
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-09_08-11 exists
# Appended 4326
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-09_08-16 exists
# Appended 4327
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-09_09-51 exists
# Appended 4328
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-09_17-46 exists
# Appended 4329
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-09_19-31 exists
# Appended 4330
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-09_21-11 exists
# Appended 4331
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-10_06-11 exists
# Appended 4332
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-10_07-51 exists
# Appended 4333
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-10_08-01 exists
# Appended 4334
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-10_09-36 exists
# Appended 4335
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-10_19-11 exists
# Appended 4336
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-10_20-51 exists
# Appended 4337
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-11_07-36 exists
# Appended 4338
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-11_09-11 exists
# Appended 4339
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-11_09-16 exists
# Appended 4340
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-11_18-51 exists
# Appended 4341
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-11_20-36 exists
# Appended 4342
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-12_07-16 exists
# Appended 4343
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-12_08-51 exists
# Appended 4344
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-12_09-01 exists
# Appended 4345
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-12_18-31 exists
# Appended 4346
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-12_18-36 exists
# Appended 4347
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-12_20-11 exists
# Appended 4348
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-12_20-16 exists
# Appended 4349
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-13_06-51 exists
# Appended 4350
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-13_07-01 exists
# Appended 4351
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-13_08-36 exists
# Appended 4352
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-13_08-41 exists
# Appended 4353
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-13_18-11 exists
# Appended 4354
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-13_18-16 exists
# Appended 4355
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-13_19-51 exists
# Appended 4356
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-13_20-01 exists
# Appended 4357
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-14_08-16 exists
# Appended 4358
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-14_10-01 exists
# Appended 4359
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-14_17-51 exists
# Appended 4360
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-14_18-01 exists
# Appended 4361
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-14_19-36 exists
# Appended 4362
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-14_21-16 exists
# Appended 4363
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-15_08-01 exists
# Appended 4364
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-15_09-41 exists
# Appended 4365
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-15_17-36 exists
# Appended 4366
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-15_19-16 exists
# Appended 4367
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-15_21-01 exists
# Appended 4368
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-16_07-41 exists
# Appended 4369
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-16_09-16 exists
# Appended 4370
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-16_09-21 exists
# Appended 4371
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-17_07-21 exists
# Appended 4372
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-17_09-01 exists
# Appended 4373
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-17_09-06 exists
# Appended 4374
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-17_18-41 exists
# Appended 4375
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-17_20-16 exists
# Appended 4376
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-17_20-21 exists
# Appended 4377
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-18_07-01 exists
# Appended 4378
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-18_07-06 exists
# Appended 4379
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-18_08-41 exists
# Appended 4380
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-18_08-46 exists
# Appended 4381
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-18_18-16 exists
# Appended 4382
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-18_18-21 exists
# Appended 4383
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-18_20-01 exists
# Appended 4384
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-18_20-06 exists
# Appended 4385
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-19_06-41 exists
# Appended 4386
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-19_06-46 exists
# Appended 4387
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-19_08-21 exists
# Appended 4388
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-19_08-31 exists
# Appended 4389
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-19_18-01 exists
# Appended 4390
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-19_18-06 exists
# Appended 4391
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-19_19-41 exists
# Appended 4392
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-20_06-21 exists
# Appended 4393
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-20_08-06 exists
# Appended 4394
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-20_08-11 exists
# Appended 4395
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-20_09-46 exists
# Appended 4396
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-20_17-41 exists
# Appended 4397
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-20_19-21 exists
# Appended 4398
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-21_07-46 exists
# Appended 4399
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-21_09-31 exists
# Appended 4400
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-21_19-06 exists
# Appended 4401
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-21_20-46 exists
# Appended 4402
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-22_07-31 exists
# Appended 4403
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-22_09-06 exists
# Appended 4404
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-22_09-11 exists
# Appended 4405
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-22_18-46 exists
# Appended 4406
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-22_20-31 exists
# Appended 4407
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-23_07-11 exists
# Appended 4408
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-23_08-46 exists
# Appended 4409
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-23_08-51 exists
# Appended 4410
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-23_18-21 exists
# Appended 4411
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-23_18-31 exists
# Appended 4412
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-23_20-06 exists
# Appended 4413
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-24_06-46 exists
# Appended 4414
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-24_06-51 exists
# Appended 4415
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-24_08-31 exists
# Appended 4416
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-24_08-36 exists
# Appended 4417
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-24_19-46 exists
# Appended 4418
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-25_08-11 exists
# Appended 4419
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-25_09-51 exists
# Appended 4420
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-25_19-31 exists
# Appended 4421
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-26_07-51 exists
# Appended 4422
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-26_09-36 exists
# Appended 4423
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-26_19-11 exists
# Appended 4424
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-26_20-51 exists
# Appended 4425
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-27_07-36 exists
# Appended 4426
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-27_09-11 exists
# Appended 4427
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-27_09-16 exists
# Appended 4428
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-27_18-51 exists
# Appended 4429
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-27_20-31 exists
# Appended 4430
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-27_20-36 exists
# Appended 4431
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-28_07-16 exists
# Appended 4432
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-28_08-51 exists
# Appended 4433
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-28_09-01 exists
# Appended 4434
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-28_18-36 exists
# Appended 4435
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-28_20-11 exists
# Appended 4436
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-28_20-16 exists
# Appended 4437
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-29_06-51 exists
# Appended 4438
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-29_07-01 exists
# Appended 4439
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-29_08-36 exists
# Appended 4440
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-29_08-41 exists
# Appended 4441
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-29_18-11 exists
# Appended 4442
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-29_18-16 exists
# Appended 4443
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-29_19-51 exists
# Appended 4444
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-29_20-01 exists
# Appended 4445
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-30_06-36 exists
# Appended 4446
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-30_06-41 exists
# Appended 4447
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-30_08-16 exists
# Appended 4448
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-30_08-21 exists
# Appended 4449
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-30_17-51 exists
# Appended 4450
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-30_18-01 exists
# Appended 4451
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-30_19-36 exists
# Appended 4452
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-31_06-16 exists
# Appended 4453
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-31_06-21 exists
# Appended 4454
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-31_08-01 exists
# Appended 4455
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-31_09-41 exists
# Appended 4456
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-31_17-36 exists
# Appended 4457
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-31_19-16 exists
# Appended 4458
# Directory F:\ML_project\GOES_16\temporal_GOES\2023-12-31_21-01 exists
# Appended 4459

# %%
d = {"No_4_files": no_4_files} ## create a dictionary
df_no_4_files = pd.DataFrame(data = d) ## create a dataframe
df_no_4_files
# Out:
#           No_4_files
# 0   2022-03-05 17:21
# 1   2022-04-26 17:51
# 2   2022-04-26 19:31
# 3   2022-09-25 20:21
# 4   2022-09-27 18:06
# 5   2022-10-05 18:51
# 6   2023-03-08 17:21
# 7   2023-05-01 20:36
# 8   2023-11-02 17:41
# 9   2023-11-06 18:06
# 10  2023-11-27 19:51

# %%
df_temporal_list_concat = pd.concat(df_temporal_list).reset_index(drop=True) ## concatenate the dataframes

# %%
out_dir = f"{os.getcwd()}\\temporal_df" ## output directory
if not os.path.exists(out_dir): ## if the output directory does not exist
    os.makedirs(out_dir) ## make the directory
else:
    print(f"Directory {out_dir} exists") ## print that the directory exists
# Out:
# Directory c:\Users\asaf_rs\Dropbox\Fire_Detection\python_ML_project\create_ML_df\temporal_df exists

# %%
df_no_4_files.to_csv(f"{out_dir}\\no_4_files.csv", index=False) ## save the no 4 files dataframe
df_temporal_list_concat.to_csv(f"{out_dir}\\temporal_df.csv", index=False) ## save the temporal dataframe
