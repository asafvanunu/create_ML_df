# %% [markdown]
# **Name**:
# Build_ML_train df
#
# **Description**:
# In this notebook, we will build the dataset for training the ML model.
#
# **Date created**:
# `2024-12-26`
#
# **Author**:
# Asaf Vanunu
#
# ---

# %% [markdown]
# - First we will upload our libraries and the df.

# %%
import os
import pandas as pd
import geopandas as gpd
import numpy as np
import ML_toolbox as MLT ## Custom module
from rasterio.plot import show
import itertools

# %%
main_path = os.getcwd() ## get the current working directory
temporal_df_path = "temporal_df"
for file in os.listdir(main_path): ## loop through the files in the current working directory
    if file.endswith(".csv"): ## check if the file is a csv file
        NC_VIIRS_df = pd.read_csv(file) ## read the csv file
temporal_df_csv_list = [os.path.join(temporal_df_path, file) for file in os.listdir(temporal_df_path) if file.endswith(".csv")]
for file in temporal_df_csv_list: ## loop through the files in the temporal_df folder
    if file.endswith(".csv"): ## check if the file is a csv file
        file_name = os.path.basename(file) ## get the name of the file
        if file_name.startswith("no_4"): ## check if the file is the no_4 csv file
            no_4_df = pd.read_csv(file) ## read the no_4 csv file
        elif file_name.startswith("temporal"): ## check if the file is the temporal csv file
            temporal_df = pd.read_csv(file)## read the temporal csv file

# %% [markdown]
# - So now we have 3 df:
# - NetCDF df with matching VIIRS
# - Temporal df with matching GOES time
# - df who doesent have 4 temporal files

# %% [markdown]
# - Now we will filter out files that doesent have 4 temporal files. from our df.

# %%
NC_VIIRS_df = NC_VIIRS_df[~np.isin(NC_VIIRS_df["GOES_date_time"], no_4_df["No_4_files"])].reset_index(drop=True)

# %%
NC_VIIRS_df[:5]
# Out:
#      GOES_file_name    GOES_date_time  \
# 0  s202201010731.nc  2022-01-01 07:31
# 1  s202201010911.nc  2022-01-01 09:11
# 2  s202201011846.nc  2022-01-01 18:46
# 3  s202201012021.nc  2022-01-01 20:21
# 4  s202201012031.nc  2022-01-01 20:31
#
#                                                 MCMI  \
# 0  F:\ML_project\GOES_16\MCMI\OR_ABI-L2-MCMIPC-M6...
# 1  F:\ML_project\GOES_16\MCMI\OR_ABI-L2-MCMIPC-M6...
# 2  F:\ML_project\GOES_16\MCMI\OR_ABI-L2-MCMIPC-M6...
# 3  F:\ML_project\GOES_16\MCMI\OR_ABI-L2-MCMIPC-M6...
# 4  F:\ML_project\GOES_16\MCMI\OR_ABI-L2-MCMIPC-M6...
#
#                                                  FDC  \
# 0  F:\ML_project\GOES_16\FDC\OR_ABI-L2-FDCC-M6_G1...
# 1  F:\ML_project\GOES_16\FDC\OR_ABI-L2-FDCC-M6_G1...
# 2  F:\ML_project\GOES_16\FDC\OR_ABI-L2-FDCC-M6_G1...
# 3  F:\ML_project\GOES_16\FDC\OR_ABI-L2-FDCC-M6_G1...
# 4  F:\ML_project\GOES_16\FDC\OR_ABI-L2-FDCC-M6_G1...
#
#                                                  ACM  \
# 0  F:\ML_project\GOES_16\ACM\OR_ABI-L2-ACMC-M6_G1...
# 1  F:\ML_project\GOES_16\ACM\OR_ABI-L2-ACMC-M6_G1...
# 2  F:\ML_project\GOES_16\ACM\OR_ABI-L2-ACMC-M6_G1...
# 3  F:\ML_project\GOES_16\ACM\OR_ABI-L2-ACMC-M6_G1...
# 4  F:\ML_project\GOES_16\ACM\OR_ABI-L2-ACMC-M6_G1...
#
#                                     VIIRS_file  \
# 0  VNP14IMG.A2022001.0724.002.2024075110909.nc
# 1  VNP14IMG.A2022001.0906.002.2024075110907.nc
# 2  VNP14IMG.A2022001.1842.002.2024075110906.nc
# 3  VNP14IMG.A2022001.2018.002.2024075110907.nc
# 4  VNP14IMG.A2022001.2024.002.2024075110907.nc
#
#                                 VIIRS_file_full_path
# 0  F:\ML_project\east_us\VIIRS\VIIRS_fire\VNP14IM...
# 1  F:\ML_project\east_us\VIIRS\VIIRS_fire\VNP14IM...
# 2  F:\ML_project\east_us\VIIRS\VIIRS_fire\VNP14IM...
# 3  F:\ML_project\east_us\VIIRS\VIIRS_fire\VNP14IM...
# 4  F:\ML_project\east_us\VIIRS\VIIRS_fire\VNP14IM...

# %% [markdown]
# - Now we can load our VIIRS files

# %%
ML_project_path = "F:\\ML_project"
AOI_list = ["mexico", "east_us"] ## list of AOIs
for dir in os.listdir(ML_project_path): ## loop through the directories in the ML_project folder
    if dir in AOI_list: ## check if the directory is in the AOI_list
        print(f"Now working in {dir} directory")
        AOI_path = os.path.join(ML_project_path, dir) ## get the path of the AOI directory
        for sub_dir in os.listdir(AOI_path): ## loop through the directories in the AOI directory
            if sub_dir == "VIIRS": ## check if the directory is the VIIRS directory
                print(f"Now working in {sub_dir} directory")
                VIIRS_path = os.path.join(AOI_path, sub_dir)
                for sub_VIIRS_dir in os.listdir(VIIRS_path):## loop through the directories in the VIIRS directory
                    if sub_VIIRS_dir == "VIIRS_points": ## check if the directory is the VIIRS_points directory
                        print(f"Now working in {sub_VIIRS_dir} directory")
                        VIIRS_points_path = os.path.join(VIIRS_path, sub_VIIRS_dir) ## get the path of the VIIRS_points directory
                        for file in os.listdir(VIIRS_points_path): ## loop through the files in the VIIRS_points directory
                            if file.endswith(".shp"):
                                print(f"Now working in {file} file")
                                VIIRS_file_path = os.path.join(VIIRS_points_path, file)
                                if dir == "mexico":
                                    mexico_VIIRS_gdf = gpd.read_file(VIIRS_file_path)
                                elif dir == "east_us":
                                    east_us_VIIRS_gdf = gpd.read_file(VIIRS_file_path)
# Out:
# Now working in east_us directory
# Now working in VIIRS directory
# Now working in VIIRS_points directory
# Now working in VIIRS_points_east_US.shp file
# Now working in mexico directory
# Now working in VIIRS directory
# Now working in VIIRS_points directory
# Now working in VIIRS_points_mexico.shp file

# %% [markdown]
# - Now we will concat the VIIRS files into one gdf

# %%
VIIRS = pd.concat([mexico_VIIRS_gdf, east_us_VIIRS_gdf], ignore_index=True)
VIIRS[:5]
# Out:
#     latitude   longitude                                    Fire_file  \
# 0  28.684410 -106.088280  VNP14IMG.A2022001.0906.002.2024075110907.nc
# 1  23.640375 -103.911507  VNP14IMG.A2022001.2018.002.2024075110907.nc
# 2  23.965340 -104.134377  VNP14IMG.A2022001.2018.002.2024075110907.nc
# 3  24.011993 -104.437927  VNP14IMG.A2022001.2018.002.2024075110907.nc
# 4  24.008282 -104.437370  VNP14IMG.A2022001.2018.002.2024075110907.nc
#
#   Unique_dat Unique_tim        DATE   TIME         DATE_TIME        FRP  \
# 0   A2022001       0912  2022-01-01  09:12  2022-01-01 09:12   1.660624
# 1   A2022001       2024  2022-01-01  20:24  2022-01-01 20:24  10.240311
# 2   A2022001       2024  2022-01-01  20:24  2022-01-01 20:24  13.236159
# 3   A2022001       2024  2022-01-01  20:24  2022-01-01 20:24   3.556983
# 4   A2022001       2024  2022-01-01  20:24  2022-01-01 20:24  15.063047
#
#    FP_MAD_DT  ...       FP_T4       FP_T5  FP_con  FP_con_str  scan_line  \
# 0  -0.422919  ...  307.343140  283.351349       8           n       2772
# 1   0.511257  ...  341.236176  303.784210       8           n       5708
# 2   0.489004  ...  336.169220  302.682037       8           n       5812
# 3   0.610675  ...  334.978088  298.806671       8           n       5838
# 4   0.701251  ...  339.781769  304.147705       8           n       5837
#
#    grid_sampl  View_Zenit  night/day  region                     geometry
# 0        4281   33.149998      Night  mexico  POINT (-106.08828 28.68441)
# 1        2173   31.449999        Day  mexico  POINT (-103.91151 23.64038)
# 2        2203   30.510000        Day  mexico  POINT (-104.13438 23.96534)
# 3        2261   28.699999        Day  mexico  POINT (-104.43793 24.01199)
# 4        2261   28.699999        Day  mexico  POINT (-104.43737 24.00828)
#
# [5 rows x 27 columns]

# %% [markdown]
# * Now we can create a fire index column for VIIRS

# %%
## Create a new column called "Fire_index" in the VIIRS dataframe
# this is the normalized difference between the brightness temperature of the two channels I4 and I5
# I4 is 3.74 um and I5 is 11.45 um
VIIRS["Fire_index"] = (VIIRS["FP_T4"] - VIIRS["FP_T5"])/(VIIRS["FP_T4"] + VIIRS["FP_T5"])

# %% [markdown]
# * Now we will crop GOES bands to matching VIIRS and create a fire index

# %%
B7 = MLT.crop_GOES_using_VIIRS(GOES_path=NC_VIIRS_df["MCMI"].iloc[0], GOES_band=7, VIIRS_path=NC_VIIRS_df["VIIRS_file_full_path"].iloc[0])
B14 = MLT.crop_GOES_using_VIIRS(GOES_path=NC_VIIRS_df["MCMI"].iloc[0], GOES_band=14, VIIRS_path=NC_VIIRS_df["VIIRS_file_full_path"].iloc[0])

# %%
## open cloud mask file
cloud_mask = MLT.crop_GOES_using_VIIRS(GOES_path=NC_VIIRS_df["ACM"].iloc[0], GOES_band="ACM", VIIRS_path=NC_VIIRS_df["VIIRS_file_full_path"].iloc[0])
cloud_mask_values = cloud_mask.values[0]

# %%
## all MCMI bands
all = MLT.crop_GOES_using_VIIRS(GOES_path=NC_VIIRS_df["MCMI"].iloc[0], GOES_band="all", VIIRS_path=NC_VIIRS_df["VIIRS_file_full_path"].iloc[0])

# %%
FI = (B7.values[0] - B14.values[0])/(B7.values[0] + B14.values[0])

# %%
B7.values[0].shape
# Out:
# (1095, 1744)

# %% [markdown]
# * We can also open the cloud mask

# %% [markdown]
# * Now we will filter the VIIRS gdf so it will match the GOES image we are going to use

# %%
VIIRS_file = NC_VIIRS_df["VIIRS_file"].iloc[0]
VIIRS_filter = VIIRS[VIIRS["Fire_file"] == VIIRS_file]

# %% [markdown]
# * Now we will use the rasterize function to create an array for the VIIRS gdf

# %%
rasterize_VIIRS = MLT.rasterize_VIIRS(cropped_GOES_image=B7, filter_VIIRS_gdf=VIIRS_filter,
                                      rasterize_type="count", number_of_VIIRS_points=1, VIIRS_band = None)

# %% [markdown]
# * Now we will use the rasterize VIIRS to get the actual locations of the GOES fire pixels

# %%
GOES_fp_pixel_list = MLT.get_GOES_actual_fire_pixel_locations(GOES_Fire_Index_array=FI, rasterize_VIIRS=rasterize_VIIRS)

# %%
len(GOES_fp_pixel_list)
# Out:
# 35

# %% [markdown]
# * Here we will create a list of pixel locations that are fires or fire neighbors. So that means we cant use them for labeling non fire pixels
# * We will get the locations of: VIIRS fire pixels and neighbors, GOES fire pixels and neighbors and nan values
# * We also make sure that the list dosent have duplicates

# %%
VIIRS_to_kill = MLT.VIIRS_locations_to_kill(rasterize_VIIRS=rasterize_VIIRS)
GOES_to_kill = MLT.GOES_locations_to_kill(GOES_fp_list=GOES_fp_pixel_list,GOES_Fire_Index_array=FI)
nan_kill_list = MLT.nan_locations_to_kill(GOES_Fire_Index_array=FI)
kill_list = GOES_to_kill + VIIRS_to_kill + nan_kill_list ## combine the GOES_to_kill, VIIRS_to_kill and nan_loc_list
corrected_kill  = list(kill_list for kill_list,_ in itertools.groupby(kill_list)) ## remove duplicates

# %% [markdown]
# * After that we can label the non fire pixels from the GOES image

# %%
non_fire_pixels = MLT.get_random_non_fire_pixels(GOES_Fire_Index_array=FI, number_of_non_fire_pixels=1000, corrected_kill_list=corrected_kill)

# %% [markdown]
# * Now we can create a df of fire pixels to train

# %%
df_fire_pixels = MLT.get_fire_pixel_values_in_all_bands(pixel_location_list=GOES_fp_pixel_list,
                                            MCMI_path=NC_VIIRS_df["MCMI"].iloc[0],
                                            FDC_path=NC_VIIRS_df["FDC"].iloc[0],
                                            ACM_path=NC_VIIRS_df["ACM"].iloc[0],
                                            VIIRS_path=NC_VIIRS_df["VIIRS_file_full_path"].iloc[0],
                                            GOES_date_time=NC_VIIRS_df["GOES_date_time"].iloc[0],
                                            rasterize_VIIRS=rasterize_VIIRS,
                                            cloud_probability_list=[3,4])
# Out:
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds
# in pixel 295, 730 all of the neighbors are clouds

# %%
df_fire_pixels
# Out:
#         t0_MCMI_file t0_GOES_date_time  row   col  VIIRS_fp_max  VIIRS_fp_sum  \
# 0   s202201010731.nc  2022-01-01 07:31  245   804           2.0           2.0
# 1   s202201010731.nc  2022-01-01 07:31  273   739           1.0           2.0
# 2   s202201010731.nc  2022-01-01 07:31  274   741           1.0           1.0
# 3   s202201010731.nc  2022-01-01 07:31  295   730           2.0           4.0
# 4   s202201010731.nc  2022-01-01 07:31  303   805           1.0           1.0
# 5   s202201010731.nc  2022-01-01 07:31  308   806           1.0           1.0
# 6   s202201010731.nc  2022-01-01 07:31  326  1003           1.0           1.0
# 7   s202201010731.nc  2022-01-01 07:31  332   497           1.0           1.0
# 8   s202201010731.nc  2022-01-01 07:31  331   823           2.0           2.0
# 9   s202201010731.nc  2022-01-01 07:31  334   882           1.0           1.0
# 10  s202201010731.nc  2022-01-01 07:31  359   990           1.0           1.0
# 11  s202201010731.nc  2022-01-01 07:31  372   454           1.0           1.0
# 12  s202201010731.nc  2022-01-01 07:31  373   764           1.0           1.0
# 13  s202201010731.nc  2022-01-01 07:31  393   739           3.0           4.0
# 14  s202201010731.nc  2022-01-01 07:31  402   736           1.0           1.0
IIRS_path=NC_VIIRS_df["VIIRS_file_full_path"].iloc[0],
                                                                          GOES_date_time=NC_VIIRS_df["GOES_date_time"].iloc[0],
                                                                          temporal_images=4,
                                                                          cloud_probability_list=[3,4])
# Out:
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 245, 804 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 273, 739 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds
# in pixel 274, 741 all of the neighbors are clouds

# %% [markdown]
# * Now we can concat the the df and add a label column

# %%
df_fire_pixels_concat_temporal = pd.concat([df_fire_pixels, df_temporal_fire_pixels], axis=1)

# %%
df_fire_pixels_concat_temporal["fire_label"] = 1

# %%
df_fire_pixels_concat_temporal[:5]
# Out:
#        t0_MCMI_file t0_GOES_date_time  row  col  VIIRS_fp_max  VIIRS_fp_sum  \
# 0  s202201010731.nc  2022-01-01 07:31  245  804           2.0           2.0
# 1  s202201010731.nc  2022-01-01 07:31  273  739           1.0           2.0
# 2  s202201010731.nc  2022-01-01 07:31  274  741           1.0           1.0
# 3  s202201010731.nc  2022-01-01 07:31  295  730           2.0           4.0
# 4  s202201010731.nc  2022-01-01 07:31  303  805           1.0           1.0
#
#    t0_B01_value  t0_B01_mean  t0_B01_median  t0_B01_std  ...  t4_B16_max  \
# 0           0.0       -999.0         -999.0      -999.0  ... -999.000000
# 1           0.0       -999.0         -999.0      -999.0  ... -999.000000
# 2           0.0       -999.0         -999.0      -999.0  ... -999.000000
# 3           0.0       -999.0         -999.0      -999.0  ...  268.740570
# 4           0.0          0.0            0.0         0.0  ...  270.503174
#
#    t4_FI_value  t4_FI_mean  t4_FI_median   t4_FI_std   t4_FI_min   t4_FI_max  \
# 0     0.013518 -999.000000   -999.000000 -999.000000 -999.000000 -999.000000
# 1     0.009540 -999.000000   -999.000000 -999.000000 -999.000000 -999.000000
# 2     0.010895 -999.000000   -999.000000 -999.000000 -999.000000 -999.000000
# 3     0.006053    0.004273      0.004349    0.000522    0.003545    0.004847
# 4    -0.002857   -0.002898     -0.002830    0.000714   -0.004262   -0.002012
#
#    t4_FDC_value  t4_ACM_value  fire_label
# 0         240.0           3.0           1
# 1         100.0           3.0           1
# 2         240.0           3.0           1
# 3         100.0           3.0           1
# 4         100.0           1.0           1
#
# [5 rows x 538 columns]

# %% [markdown]
# * Now we will do the same for the non fire pixels

# %%
df_non_fire_pixels = MLT.get_fire_pixel_values_in_all_bands(pixel_location_list=non_fire_pixels,
                                            MCMI_path=NC_VIIRS_df["MCMI"].iloc[0],
                                            FDC_path=NC_VIIRS_df["FDC"].iloc[0],
                                            ACM_path=NC_VIIRS_df["ACM"].iloc[0],
                                            VIIRS_path=NC_VIIRS_df["VIIRS_file_full_path"].iloc[0],
                                            GOES_date_time=NC_VIIRS_df["GOES_date_time"].iloc[0],
                                            rasterize_VIIRS=rasterize_VIIRS)
# Out:
# in pixel 207, 643 all of the neighbors are clouds
# in pixel 207, 643 all of the neighbors are clouds
# in pixel 207, 643 all of the neighbors are clouds
# in pixel 207, 643 all of the neighbors are clouds
# in pixel 207, 643 all of the neighbors are clouds
# in pixel 230, 908 all of the neighbors are clouds
# in pixel 230, 908 all of the neighbors are clouds
# in pixel 230, 908 all of the neighbors are clouds
# in pixel 230, 908 all of the neighbors are clouds
# in pixel 230, 908 all of the neighbors are clouds
# in pixel 269, 617 all of the neighbors are clouds
# in pixel 269, 617 all of the neighbors are clouds
# in pixel 269, 617 all of the neighbors are clouds
# in pixel 269, 617 all of the neighbors are clouds
# in pixel 269, 617 all of the neighbors are clouds
# in pixel 92, 1017 all of the neighbors are clouds
# in pixel 92, 1017 all of the neighbors are clouds
# in pixel 92, 1017 all of the neighbors are clouds
# in pixel 92, 1017 all of the neighbors are clouds
# in pixel 92, 1017 all of the neighbors are clouds
# in pixel 221, 626 all of the neighbors are clouds
# in pixel 221, 626 all of the neighbors are clouds
# in pixel 221, 626 all of the neighbors are clouds
# in pixel 221, 626 all of the neighbors are clouds
# in pixel 221, 626 all of the neighbors are clouds
# in pixel 182, 1108 all of the neighbors are clouds
# in pixel 182, 1108 all of the neighbors are clouds
# in pixel 182, 1108 all of the neighbors are clouds
# in pixel 182, 1108 all of the neighbors are clouds
# in pixel 182, 1108 all of the neighbors are clouds
# in pixel 388, 1560 all of the neighbors are clouds
# in pixel 388, 1560 all of the neighbors are clouds
# in pixel 388, 1560 all of the neighbors are clouds
# in pixel 388, 1560 all of the neighbors are clouds
# in pixel 388, 1560 all of the neighbors are clouds
# in pixel 313, 487 all of the neighbors are clouds
# in pixel 313, 487 all of the neighbors are clouds
# in pixel 313, 487 all of the neighbors are clouds
# in pixel 313, 487 all of the neighbors are clouds
# in pixel 313, 487 all of the neighbors are clouds
# in pixel 93, 926 all of the neighbors are clouds
# in pixel 93, 926 all of the neighbors are clouds
# in pixel 93, 926 all of the neighbors are clouds
# in pixel 93, 926 all of the neighbors are clouds
# in pixel 93, 926 all of the neighbors are clouds
# in pixel 41, 587 all of the neighbors are clouds
# in pixel 41, 587 all of the neighbors are clouds
# in pixel 41, 587 all of the neighbors are clouds
# in pixel 41, 587 all of the neighbors are clouds
# in pixel 41, 587 all of the neighbors are clouds
# in pixel 250, 554 all of the neighbors are clouds
# in pixel 250, 554 all of the neighbors are clouds
# in pixel 250, 554 all of the neighbors are clouds
# in pixel 250, 554 all of the neighbors are clouds
# in pixel 250, 554 all of the neighbors are clouds
# in pixel 99, 967 all of the neighbors are clouds
# in pixel 99, 967 all of the neighbors are clouds
# in pixel 99, 967 all of the neighbors are clouds
# in pixel 99, 967 all of the neighbors are clouds
# in pixel 99, 967 all of the neighbors are clouds
# in pixel 273, 1629 all of the neighbors are clouds
# in pixel 273, 1629 all of the neighbors are clouds
# in pixel 273, 1629 all of the neighbors are clouds
# in pixel 273, 1629 all of the neighbors are clouds
# in pixel 273, 1629 all of the neighbors are clouds
# in pixel 418, 277 all of the neighbors are clouds
# in pixel 418, 277 all of the neighbors are clouds
# in pixel 418, 277 all of the neighbors are clouds
# in pixel 418, 277 all of the neighbors are clouds
# in pixel 418, 277 all of the neighbors are clouds
# in pixel 192, 860 all of the neighbors are clouds
# in pixel 192, 860 all of the neighbors are clouds
# in pixel 192, 860 all of the neighbors are clouds
# in pixel 192, 860 all of the neighbors are clouds
# in pixel 192, 860 all of the neighbors are clouds
# in pixel 169, 1582 all of the neighbors are clouds
# in pixel 169, 1582 all of the neighbors are clouds
# in pixel 169, 1582 all of the neighbors are clouds
# in pixel 169, 1582 all of the neighbors are clouds
# in pixel 169, 1582 all of the neighbors are clouds
# in pixel 161, 969 all of the neighbors are clouds
# in pixel 161, 969 all of the neighbors are clouds
# in pixel 161, 969 all of the neighbors are clouds
# in pixel 161, 969 all of the neighbors are clouds
# in pixel 161, 969 all of the neighbors are clouds
# in pixel 103, 916 all of the neighbors are clouds
# in pixel 103, 916 all of the neighbors are clouds
# in pixel 103, 916 all of the neighbors are clouds
# in pixel 103, 916 all of the neighbors are clouds
# in pixel 103, 916 all of the neighbors are clouds
# in pixel 813, 1273 all of the neighbors are clouds
# in pixel 813, 1273 all of the neighbors are clouds
# in pixel 813, 1273 all of the neighbors are clouds
# in pixel 813, 1273 all of the neighbors are clouds
# in pixel 813, 1273 all of the neighbors are clouds
# in pixel 193, 1581 all of the neighbors are clouds
# in pixel 193, 1581 all of the neighbors are clouds
# in pixel 193, 1581 all of the neighbors are clouds
# in pixel 193, 1581 all of the neighbors are clouds
# in pixel 193, 1581 all of the neighbors are clouds
# in pixel 405, 1589 all of the neighbors are clouds
# in pixel 405, 1589 all of the neighbors are clouds
# in pixel 405, 1589 all of the neighbors are clouds
# in pixel 405, 1589 all of the neighbors are clouds
# in pixel 405, 1589 all of the neighbors are clouds
# in pixel 156, 1506 all of the neighbors are clouds
# in pixel 156, 1506 all of the neighbors are clouds
# in pixel 156, 1506 all of the neighbors are clouds
# in pixel 156, 1506 all of the neighbors are clouds
# in pixel 156, 1506 all of the neighbors are clouds
# in pixel 322, 1318 all of the neighbors are clouds
# in pixel 322, 1318 all of the neighbors are clouds
# in pixel 322, 1318 all of the neighbors are clouds
# in pixel 322, 1318 all of the neighbors are clouds
# in pixel 322, 1318 all of the neighbors are clouds
# in pixel 196, 597 all of the neighbors are clouds
# in pixel 196, 597 all of the neighbors are clouds
# in pixel 196, 597 all of the neighbors are clouds
# in pixel 196, 597 all of the neighbors are clouds
# in pixel 196, 597 all of the neighbors are clouds
# in pixel 259, 538 all of the neighbors are clouds
# in pixel 259, 538 all of the neighbors are clouds
# in pixel 259, 538 all of the neighbors are clouds
# in pixel 259, 538 all of the neighbors are clouds
# in pixel 259, 538 all of the neighbors are clouds
# in pixel 290, 1681 all of the neighbors are clouds
# in pixel 290, 1681 all of the neighbors are clouds
# in pixel 290, 1681 all of the neighbors are clouds
# in pixel 290, 1681 all of the neighbors are clouds
# in pixel 290, 1681 all of the neighbors are clouds
# in pixel 199, 1011 all of the neighbors are clouds
# in pixel 199, 1011 all of the neighbors are clouds
# in pixel 199, 1011 all of the neighbors are clouds
# in pixel 199, 1011 all of the neighbors are clouds
# in pixel 199, 1011 all of the neighbors are clouds
# in pixel 186, 1406 all of the neighbors are clouds
# in pixel 186, 1406 all of the neighbors are clouds
# in pixel 186, 1406 all of the neighbors are clouds
# in pixel 186, 1406 all of the neighbors are clouds
# in pixel 186, 1406 all of the neighbors are clouds
# in pixel 189, 1152 all of the neighbors are clouds
# in pixel 189, 1152 all of the neighbors are clouds
# in pixel 189, 1152 all of the neighbors are clouds
# in pixel 189, 1152 all of the neighbors are clouds
# in pixel 189, 1152 all of the neighbors are clouds
# in pixel 179, 1556 all of the neighbors are clouds
# in pixel 179, 1556 all of the neighbors are clouds
# in pixel 179, 1556 all of the neighbors are clouds
# in pixel 179, 1556 all of the neighbors are clouds
# in pixel 179, 1556 all of the neighbors are clouds
# in pixel 410, 1615 all of the neighbors are clouds
# in pixel 410, 1615 all of the neighbors are clouds
# in pixel 410, 1615 all of the neighbors are clouds
# in pixel 410, 1615 all of the neighbors are clouds
# in pixel 410, 1615 all of the neighbors are clouds
# in pixel 342, 379 all of the neighbors are clouds
# in pixel 342, 379 all of the neighbors are clouds
# in pixel 342, 379 all of the neighbors are clouds
# in pixel 342, 379 all of the neighbors are clouds
# in pixel 342, 379 all of the neighbors are clouds
# in pixel 134, 846 all of the neighbors are clouds
# in pixel 134, 846 all of the neighbors are clouds
# in pixel 134, 846 all of the neighbors are clouds
# in pixel 134, 846 all of the neighbors are clouds
# in pixel 134, 846 all of the neighbors are clouds
# in pixel 975, 1113 all of the neighbors are clouds
# in pixel 975, 1113 all of the neighbors are clouds
# in pixel 975, 1113 all of the neighbors are clouds
# in pixel 975, 1113 all of the neighbors are clouds
# in pixel 975, 1113 all of the neighbors are clouds
# in pixel 323, 1350 all of the neighbors are clouds
# in pixel 323, 1350 all of the neighbors are clouds
# in pixel 323, 1350 all of the neighbors are clouds
# in pixel 323, 1350 all of the neighbors are clouds
# in pixel 323, 1350 all of the neighbors are clouds
# in pixel 868, 1466 all of the neighbors are clouds
# in pixel 868, 1466 all of the neighbors are clouds
# in pixel 868, 1466 all of the neighbors are clouds
# in pixel 868, 1466 all of the neighbors are clouds
# in pixel 868, 1466 all of the neighbors are clouds
# in pixel 265, 476 all of the neighbors are clouds
# in pixel 265, 476 all of the neighbors are clouds
# in pixel 265, 476 all of the neighbors are clouds
# in pixel 265, 476 all of the neighbors are clouds
# in pixel 265, 476 all of the neighbors are clouds
# in pixel 351, 1551 all of the neighbors are clouds
# in pixel 351, 1551 all of the neighbors are clouds
# in pixel 351, 1551 all of the neighbors are clouds
# in pixel 351, 1551 all of the neighbors are clouds
# in pixel 351, 1551 all of the neighbors are clouds
# in pixel 235, 449 all of the neighbors are clouds
# in pixel 235, 449 all of the neighbors are clouds
# in pixel 235, 449 all of the neighbors are clouds
# in pixel 235, 449 all of the neighbors are clouds
# in pixel 235, 449 all of the neighbors are clouds
# in pixel 298, 473 all of the neighbors are clouds
# in pixel 298, 473 all of the neighbors are clouds
# in pixel 298, 473 all of the neighbors are clouds
# in pixel 298, 473 all of the neighbors are clouds
# in pixel 298, 473 all of the neighbors are clouds
# in pixel 199, 1031 all of the neighbors are clouds
# in pixel 199, 1031 all of the neighbors are clouds
# in pixel 199, 1031 all of the neighbors are clouds
# in pixel 199, 1031 all of the neighbors are clouds
# in pixel 199, 1031 all of the neighbors are clouds
# in pixel 127, 606 all of the neighbors are clouds
# in pixel 127, 606 all of the neighbors are clouds
# in pixel 127, 606 all of the neighbors are clouds
# in pixel 127, 606 all of the neighbors are clouds
# in pixel 127, 606 all of the neighbors are clouds
# in pixel 252, 593 all of the neighbors are clouds
# in pixel 252, 593 all of the neighbors are clouds
# in pixel 252, 593 all of the neighbors are clouds
# in pixel 252, 593 all of the neighbors are clouds
# in pixel 252, 593 all of the neighbors are clouds
# in pixel 122, 509 all of the neighbors are clouds
# in pixel 122, 509 all of the neighbors are clouds
# in pixel 122, 509 all of the neighbors are clouds
# in pixel 122, 509 all of the neighbors are clouds
# in pixel 122, 509 all of the neighbors are clouds
# in pixel 420, 317 all of the neighbors are clouds
# in pixel 420, 317 all of the neighbors are clouds
# in pixel 420, 317 all of the neighbors are clouds
# in pixel 420, 317 all of the neighbors are clouds
# in pixel 420, 317 all of the neighbors are clouds
# in pixel 343, 263 all of the neighbors are clouds
# in pixel 343, 263 all of the neighbors are clouds
# in pixel 343, 263 all of the neighbors are clouds
# in pixel 343, 263 all of the neighbors are clouds
# in pixel 343, 263 all of the neighbors are clouds
# in pixel 135, 757 all of the neighbors are clouds
# in pixel 135, 757 all of the neighbors are clouds
# in pixel 135, 757 all of the neighbors are clouds
# in pixel 135, 757 all of the neighbors are clouds
# in pixel 135, 757 all of the neighbors are clouds
# in pixel 335, 338 all of the neighbors are clouds
# in pixel 335, 338 all of the neighbors are clouds
# in pixel 335, 338 all of the neighbors are clouds
# in pixel 335, 338 all of the neighbors are clouds
# in pixel 335, 338 all of the neighbors are clouds
# in pixel 257, 305 all of the neighbors are clouds
# in pixel 257, 305 all of the neighbors are clouds
# in pixel 257, 305 all of the neighbors are clouds
# in pixel 257, 305 all of the neighbors are clouds
# in pixel 257, 305 all of the neighbors are clouds
# in pixel 166, 392 all of the neighbors are clouds
# in pixel 166, 392 all of the neighbors are clouds
# in pixel 166, 392 all of the neighbors are clouds
# in pixel 166, 392 all of the neighbors are clouds
# in pixel 166, 392 all of the neighbors are clouds
# in pixel 416, 224 all of the neighbors are clouds
# in pixel 416, 224 all of the neighbors are clouds
# in pixel 416, 224 all of the neighbors are clouds
# in pixel 416, 224 all of the neighbors are clouds
# in pixel 416, 224 all of the neighbors are clouds
# in pixel 422, 333 all of the neighbors are clouds
# in pixel 422, 333 all of the neighbors are clouds
# in pixel 422, 333 all of the neighbors are clouds
# in pixel 422, 333 all of the neighbors are clouds
# in pixel 422, 333 all of the neighbors are clouds
# in pixel 306, 1390 all of the neighbors are clouds
# in pixel 306, 1390 all of the neighbors are clouds
# in pixel 306, 1390 all of the neighbors are clouds
# in pixel 306, 1390 all of the neighbors are clouds
# in pixel 306, 1390 all of the neighbors are clouds
# in pixel 208, 300 all of the neighbors are clouds
# in pixel 208, 300 all of the neighbors are clouds
# in pixel 208, 300 all of the neighbors are clouds
# in pixel 208, 300 all of the neighbors are clouds
# in pixel 208, 300 all of the neighbors are clouds
# in pixel 293, 506 all of the neighbors are clouds
# in pixel 293, 506 all of the neighbors are clouds
# in pixel 293, 506 all of the neighbors are clouds
# in pixel 293, 506 all of the neighbors are clouds
# in pixel 293, 506 all of the neighbors are clouds
# in pixel 192, 492 all of the neighbors are clouds
# in pixel 192, 492 all of the neighbors are clouds
# in pixel 192, 492 all of the neighbors are clouds
# in pixel 192, 492 all of the neighbors are clouds
# in pixel 192, 492 all of the neighbors are clouds
# in pixel 150, 1293 all of the neighbors are clouds
# in pixel 150, 1293 all of the neighbors are clouds
# in pixel 150, 1293 all of the neighbors are clouds
# in pixel 150, 1293 all of the neighbors are clouds
# in pixel 150, 1293 all of the neighbors are clouds
# in pixel 211, 1438 all of the neighbors are clouds
# in pixel 211, 1438 all of the neighbors are clouds
# in pixel 211, 1438 all of the neighbors are clouds
# in pixel 211, 1438 all of the neighbors are clouds
# in pixel 211, 1438 all of the neighbors are clouds
# in pixel 236, 1414 all of the neighbors are clouds
# in pixel 236, 1414 all of the neighbors are clouds
# in pixel 236, 1414 all of the neighbors are clouds
# in pixel 236, 1414 all of the neighbors are clouds
# in pixel 236, 1414 all of the neighbors are clouds
# in pixel 119, 622 all of the neighbors are clouds
# in pixel 119, 622 all of the neighbors are clouds
# in pixel 119, 622 all of the neighbors are clouds
# in pixel 119, 622 all of the neighbors are clouds
# in pixel 119, 622 all of the neighbors are clouds
# in pixel 215, 891 all of the neighbors are clouds
# in pixel 215, 891 all of the neighbors are clouds
# in pixel 215, 891 all of the neighbors are clouds
# in pixel 215, 891 all of the neighbors are clouds
# in pixel 215, 891 all of the neighbors are clouds
# in pixel 174, 566 all of the neighbors are clouds
# in pixel 174, 566 all of the neighbors are clouds
# in pixel 174, 566 all of the neighbors are clouds
# in pixel 174, 566 all of the neighbors are clouds
# in pixel 174, 566 all of the neighbors are clouds
# in pixel 57, 584 all of the neighbors are clouds
# in pixel 57, 584 all of the neighbors are clouds
# in pixel 57, 584 all of the neighbors are clouds
# in pixel 57, 584 all of the neighbors are clouds
# in pixel 57, 584 all of the neighbors are clouds
# in pixel 114, 650 all of the neighbors are clouds
# in pixel 114, 650 all of the neighbors are clouds
# in pixel 114, 650 all of the neighbors are clouds
# in pixel 114, 650 all of the neighbors are clouds
# in pixel 114, 650 all of the neighbors are clouds
# in pixel 242, 1321 all of the neighbors are clouds
# in pixel 242, 1321 all of the neighbors are clouds
# in pixel 242, 1321 all of the neighbors are clouds
# in pixel 242, 1321 all of the neighbors are clouds
# in pixel 242, 1321 all of the neighbors are clouds
# in pixel 216, 1388 all of the neighbors are clouds
# in pixel 216, 1388 all of the neighbors are clouds
# in pixel 216, 1388 all of the neighbors are clouds
# in pixel 216, 1388 all of the neighbors are clouds
# in pixel 216, 1388 all of the neighbors are clouds
# in pixel 255, 1352 all of the neighbors are clouds
# in pixel 255, 1352 all of the neighbors are clouds
# in pixel 255, 1352 all of the neighbors are clouds
# in pixel 255, 1352 all of the neighbors are clouds
# in pixel 255, 1352 all of the neighbors are clouds
# in pixel 220, 1657 all of the neighbors are clouds
# in pixel 220, 1657 all of the neighbors are clouds
# in pixel 220, 1657 all of the neighbors are clouds
# in pixel 220, 1657 all of the neighbors are clouds
# in pixel 220, 1657 all of the neighbors are clouds
# in pixel 202, 1623 all of the neighbors are clouds
# in pixel 202, 1623 all of the neighbors are clouds
# in pixel 202, 1623 all of the neighbors are clouds
# in pixel 202, 1623 all of the neighbors are clouds
# in pixel 202, 1623 all of the neighbors are clouds
# in pixel 102, 913 all of the neighbors are clouds
# in pixel 102, 913 all of the neighbors are clouds
# in pixel 102, 913 all of the neighbors are clouds
# in pixel 102, 913 all of the neighbors are clouds
# in pixel 102, 913 all of the neighbors are clouds
# in pixel 133, 994 all of the neighbors are clouds
# in pixel 133, 994 all of the neighbors are clouds
# in pixel 133, 994 all of the neighbors are clouds
# in pixel 133, 994 all of the neighbors are clouds
# in pixel 133, 994 all of the neighbors are clouds
# in pixel 457, 193 all of the neighbors are clouds
# in pixel 457, 193 all of the neighbors are clouds
# in pixel 457, 193 all of the neighbors are clouds
# in pixel 457, 193 all of the neighbors are clouds
# in pixel 457, 193 all of the neighbors are clouds
# in pixel 365, 1393 all of the neighbors are clouds
# in pixel 365, 1393 all of the neighbors are clouds
# in pixel 365, 1393 all of the neighbors are clouds
# in pixel 365, 1393 all of the neighbors are clouds
# in pixel 365, 1393 all of the neighbors are clouds
# in pixel 91, 573 all of the neighbors are clouds
# in pixel 91, 573 all of the neighbors are clouds
# in pixel 91, 573 all of the neighbors are clouds
# in pixel 91, 573 all of the neighbors are clouds
# in pixel 91, 573 all of the neighbors are clouds
# in pixel 270, 352 all of the neighbors are clouds
# in pixel 270, 352 all of the neighbors are clouds
# in pixel 270, 352 all of the neighbors are clouds
# in pixel 270, 352 all of the neighbors are clouds
# in pixel 270, 352 all of the neighbors are clouds
# in pixel 79, 945 all of the neighbors are clouds
# in pixel 79, 945 all of the neighbors are clouds
# in pixel 79, 945 all of the neighbors are clouds
# in pixel 79, 945 all of the neighbors are clouds
# in pixel 79, 945 all of the neighbors are clouds
# in pixel 147, 544 all of the neighbors are clouds
# in pixel 147, 544 all of the neighbors are clouds
# in pixel 147, 544 all of the neighbors are clouds
# in pixel 147, 544 all of the neighbors are clouds
# in pixel 147, 544 all of the neighbors are clouds
# in pixel 924, 1128 all of the neighbors are clouds
# in pixel 924, 1128 all of the neighbors are clouds
# in pixel 924, 1128 all of the neighbors are clouds
# in pixel 924, 1128 all of the neighbors are clouds
# in pixel 924, 1128 all of the neighbors are clouds
# in pixel 244, 1504 all of the neighbors are clouds
# in pixel 244, 1504 all of the neighbors are clouds
# in pixel 244, 1504 all of the neighbors are clouds
# in pixel 244, 1504 all of the neighbors are clouds
# in pixel 244, 1504 all of the neighbors are clouds
# in pixel 299, 1682 all of the neighbors are clouds
# in pixel 299, 1682 all of the neighbors are clouds
# in pixel 299, 1682 all of the neighbors are clouds
# in pixel 299, 1682 all of the neighbors are clouds
# in pixel 299, 1682 all of the neighbors are clouds
# in pixel 86, 453 all of the neighbors are clouds
# in pixel 86, 453 all of the neighbors are clouds
# in pixel 86, 453 all of the neighbors are clouds
# in pixel 86, 453 all of the neighbors are clouds
# in pixel 86, 453 all of the neighbors are clouds
# in pixel 752, 1401 all of the neighbors are clouds
# in pixel 752, 1401 all of the neighbors are clouds
# in pixel 752, 1401 all of the neighbors are clouds
# in pixel 752, 1401 all of the neighbors are clouds
# in pixel 752, 1401 all of the neighbors are clouds
# in pixel 100, 580 all of the neighbors are clouds
# in pixel 100, 580 all of the neighbors are clouds
# in pixel 100, 580 all of the neighbors are clouds
# in pixel 100, 580 all of the neighbors are clouds
# in pixel 100, 580 all of the neighbors are clouds
# in pixel 115, 340 all of the neighbors are clouds
# in pixel 115, 340 all of the neighbors are clouds
# in pixel 115, 340 all of the neighbors are clouds
# in pixel 115, 340 all of the neighbors are clouds
# in pixel 115, 340 all of the neighbors are clouds
# in pixel 85, 995 all of the neighbors are clouds
# in pixel 85, 995 all of the neighbors are clouds
# in pixel 85, 995 all of the neighbors are clouds
# in pixel 85, 995 all of the neighbors are clouds
# in pixel 85, 995 all of the neighbors are clouds
# in pixel 548, 238 all of the neighbors are clouds
# in pixel 548, 238 all of the neighbors are clouds
# in pixel 548, 238 all of the neighbors are clouds
# in pixel 548, 238 all of the neighbors are clouds
# in pixel 548, 238 all of the neighbors are clouds
# in pixel 189, 1300 all of the neighbors are clouds
# in pixel 189, 1300 all of the neighbors are clouds
# in pixel 189, 1300 all of the neighbors are clouds
# in pixel 189, 1300 all of the neighbors are clouds
# in pixel 189, 1300 all of the neighbors are clouds
# in pixel 77, 614 all of the neighbors are clouds
# in pixel 77, 614 all of the neighbors are clouds
# in pixel 77, 614 all of the neighbors are clouds
# in pixel 77, 614 all of the neighbors are clouds
# in pixel 77, 614 all of the neighbors are clouds
# in pixel 280, 591 all of the neighbors are clouds
# in pixel 280, 591 all of the neighbors are clouds
# in pixel 280, 591 all of the neighbors are clouds
# in pixel 280, 591 all of the neighbors are clouds
# in pixel 280, 591 all of the neighbors are clouds
# in pixel 216, 335 all of the neighbors are clouds
# in pixel 216, 335 all of the neighbors are clouds
# in pixel 216, 335 all of the neighbors are clouds
# in pixel 216, 335 all of the neighbors are clouds
# in pixel 216, 335 all of the neighbors are clouds
# in pixel 767, 297 all of the neighbors are clouds
# in pixel 767, 297 all of the neighbors are clouds
# in pixel 767, 297 all of the neighbors are clouds
# in pixel 767, 297 all of the neighbors are clouds
# in pixel 767, 297 all of the neighbors are clouds
# in pixel 139, 617 all of the neighbors are clouds
# in pixel 139, 617 all of the neighbors are clouds
# in pixel 139, 617 all of the neighbors are clouds
# in pixel 139, 617 all of the neighbors are clouds
# in pixel 139, 617 all of the neighbors are clouds
# in pixel 365, 1495 all of the neighbors are clouds
# in pixel 365, 1495 all of the neighbors are clouds
# in pixel 365, 1495 all of the neighbors are clouds
# in pixel 365, 1495 all of the neighbors are clouds
# in pixel 365, 1495 all of the neighbors are clouds
# in pixel 227, 1156 all of the neighbors are clouds
# in pixel 227, 1156 all of the neighbors are clouds
# in pixel 227, 1156 all of the neighbors are clouds
# in pixel 227, 1156 all of the neighbors are clouds
# in pixel 227, 1156 all of the neighbors are clouds
# in pixel 328, 1249 all of the neighbors are clouds
# in pixel 328, 1249 all of the neighbors are clouds
# in pixel 328, 1249 all of the neighbors are clouds
# in pixel 328, 1249 all of the neighbors are clouds
# in pixel 328, 1249 all of the neighbors are clouds
# in pixel 198, 1180 all of the neighbors are clouds
# in pixel 198, 1180 all of the neighbors are clouds
# in pixel 198, 1180 all of the neighbors are clouds
# in pixel 198, 1180 all of the neighbors are clouds
# in pixel 198, 1180 all of the neighbors are clouds
# in pixel 270, 401 all of the neighbors are clouds
# in pixel 270, 401 all of the neighbors are clouds
# in pixel 270, 401 all of the neighbors are clouds
# in pixel 270, 401 all of the neighbors are clouds
# in pixel 270, 401 all of the neighbors are clouds
# in pixel 250, 1354 all of the neighbors are clouds
# in pixel 250, 1354 all of the neighbors are clouds
# in pixel 250, 1354 all of the neighbors are clouds
# in pixel 250, 1354 all of the neighbors are clouds
# in pixel 250, 1354 all of the neighbors are clouds
# in pixel 223, 1419 all of the neighbors are clouds
# in pixel 223, 1419 all of the neighbors are clouds
# in pixel 223, 1419 all of the neighbors are clouds
# in pixel 223, 1419 all of the neighbors are clouds
# in pixel 223, 1419 all of the neighbors are clouds
# in pixel 341, 1361 all of the neighbors are clouds
# in pixel 341, 1361 all of the neighbors are clouds
# in pixel 341, 1361 all of the neighbors are clouds
# in pixel 341, 1361 all of the neighbors are clouds
# in pixel 341, 1361 all of the neighbors are clouds
# in pixel 253, 1662 all of the neighbors are clouds
# in pixel 253, 1662 all of the neighbors are clouds
# in pixel 253, 1662 all of the neighbors are clouds
# in pixel 253, 1662 all of the neighbors are clouds
# in pixel 253, 1662 all of the neighbors are clouds
# in pixel 225, 545 all of the neighbors are clouds
# in pixel 225, 545 all of the neighbors are clouds
# in pixel 225, 545 all of the neighbors are clouds
# in pixel 225, 545 all of the neighbors are clouds
# in pixel 225, 545 all of the neighbors are clouds
# in pixel 177, 1488 all of the neighbors are clouds
# in pixel 177, 1488 all of the neighbors are clouds
# in pixel 177, 1488 all of the neighbors are clouds
# in pixel 177, 1488 all of the neighbors are clouds
# in pixel 177, 1488 all of the neighbors are clouds
# in pixel 165, 380 all of the neighbors are clouds
# in pixel 165, 380 all of the neighbors are clouds
# in pixel 165, 380 all of the neighbors are clouds
# in pixel 165, 380 all of the neighbors are clouds
# in pixel 165, 380 all of the neighbors are clouds
# in pixel 168, 676 all of the neighbors are clouds
# in pixel 168, 676 all of the neighbors are clouds
# in pixel 168, 676 all of the neighbors are clouds
# in pixel 168, 676 all of the neighbors are clouds
# in pixel 168, 676 all of the neighbors are clouds
# in pixel 289, 499 all of the neighbors are clouds
# in pixel 289, 499 all of the neighbors are clouds
# in pixel 289, 499 all of the neighbors are clouds
# in pixel 289, 499 all of the neighbors are clouds
# in pixel 289, 499 all of the neighbors are clouds
# in pixel 336, 1359 all of the neighbors are clouds
# in pixel 336, 1359 all of the neighbors are clouds
# in pixel 336, 1359 all of the neighbors are clouds
# in pixel 336, 1359 all of the neighbors are clouds
# in pixel 336, 1359 all of the neighbors are clouds
# in pixel 284, 468 all of the neighbors are clouds
# in pixel 284, 468 all of the neighbors are clouds
# in pixel 284, 468 all of the neighbors are clouds
# in pixel 284, 468 all of the neighbors are clouds
# in pixel 284, 468 all of the neighbors are clouds
# in pixel 178, 1429 all of the neighbors are clouds
# in pixel 178, 1429 all of the neighbors are clouds
# in pixel 178, 1429 all of the neighbors are clouds
# in pixel 178, 1429 all of the neighbors are clouds
# in pixel 178, 1429 all of the neighbors are clouds
# in pixel 139, 1347 all of the neighbors are clouds
# in pixel 139, 1347 all of the neighbors are clouds
# in pixel 139, 1347 all of the neighbors are clouds
# in pixel 139, 1347 all of the neighbors are clouds
# in pixel 139, 1347 all of the neighbors are clouds
# in pixel 241, 293 all of the neighbors are clouds
# in pixel 241, 293 all of the neighbors are clouds
# in pixel 241, 293 all of the neighbors are clouds
# in pixel 241, 293 all of the neighbors are clouds
# in pixel 241, 293 all of the neighbors are clouds
# in pixel 106, 390 all of the neighbors are clouds
# in pixel 106, 390 all of the neighbors are clouds
# in pixel 106, 390 all of the neighbors are clouds
# in pixel 106, 390 all of the neighbors are clouds
# in pixel 106, 390 all of the neighbors are clouds
# in pixel 163, 620 all of the neighbors are clouds
# in pixel 163, 620 all of the neighbors are clouds
# in pixel 163, 620 all of the neighbors are clouds
# in pixel 163, 620 all of the neighbors are clouds
# in pixel 163, 620 all of the neighbors are clouds
# in pixel 663, 587 all of the neighbors are clouds
# in pixel 663, 587 all of the neighbors are clouds
# in pixel 663, 587 all of the neighbors are clouds
# in pixel 663, 587 all of the neighbors are clouds
# in pixel 663, 587 all of the neighbors are clouds
# in pixel 237, 728 all of the neighbors are clouds
# in pixel 237, 728 all of the neighbors are clouds
# in pixel 237, 728 all of the neighbors are clouds
# in pixel 237, 728 all of the neighbors are clouds
# in pixel 237, 728 all of the neighbors are clouds
# in pixel 381, 232 all of the neighbors are clouds
# in pixel 381, 232 all of the neighbors are clouds
# in pixel 381, 232 all of the neighbors are clouds
# in pixel 381, 232 all of the neighbors are clouds
# in pixel 381, 232 all of the neighbors are clouds
# in pixel 216, 386 all of the neighbors are clouds
# in pixel 216, 386 all of the neighbors are clouds
# in pixel 216, 386 all of the neighbors are clouds
# in pixel 216, 386 all of the neighbors are clouds
# in pixel 216, 386 all of the neighbors are clouds
# in pixel 348, 1659 all of the neighbors are clouds
# in pixel 348, 1659 all of the neighbors are clouds
# in pixel 348, 1659 all of the neighbors are clouds
# in pixel 348, 1659 all of the neighbors are clouds
# in pixel 348, 1659 all of the neighbors are clouds
# in pixel 249, 1265 all of the neighbors are clouds
# in pixel 249, 1265 all of the neighbors are clouds
# in pixel 249, 1265 all of the neighbors are clouds
# in pixel 249, 1265 all of the neighbors are clouds
# in pixel 249, 1265 all of the neighbors are clouds
# in pixel 426, 278 all of the neighbors are clouds
# in pixel 426, 278 all of the neighbors are clouds
# in pixel 426, 278 all of the neighbors are clouds
# in pixel 426, 278 all of the neighbors are clouds
# in pixel 426, 278 all of the neighbors are clouds
# in pixel 596, 501 all of the neighbors are clouds
# in pixel 596, 501 all of the neighbors are clouds
# in pixel 596, 501 all of the neighbors are clouds
# in pixel 596, 501 all of the neighbors are clouds
# in pixel 596, 501 all of the neighbors are clouds
# in pixel 240, 986 all of the neighbors are clouds
# in pixel 240, 986 all of the neighbors are clouds
# in pixel 240, 986 all of the neighbors are clouds
# in pixel 240, 986 all of the neighbors are clouds
# in pixel 240, 986 all of the neighbors are clouds
# in pixel 214, 753 all of the neighbors are clouds
# in pixel 214, 753 all of the neighbors are clouds
# in pixel 214, 753 all of the neighbors are clouds
# in pixel 214, 753 all of the neighbors are clouds
# in pixel 214, 753 all of the neighbors are clouds
# in pixel 79, 832 all of the neighbors are clouds
# in pixel 79, 832 all of the neighbors are clouds
# in pixel 79, 832 all of the neighbors are clouds
# in pixel 79, 832 all of the neighbors are clouds
# in pixel 79, 832 all of the neighbors are clouds
# in pixel 159, 1263 all of the neighbors are clouds
# in pixel 159, 1263 all of the neighbors are clouds
# in pixel 159, 1263 all of the neighbors are clouds
# in pixel 159, 1263 all of the neighbors are clouds
# in pixel 159, 1263 all of the neighbors are clouds
# in pixel 93, 940 all of the neighbors are clouds
# in pixel 93, 940 all of the neighbors are clouds
# in pixel 93, 940 all of the neighbors are clouds
# in pixel 93, 940 all of the neighbors are clouds
# in pixel 93, 940 all of the neighbors are clouds
# in pixel 250, 591 all of the neighbors are clouds
# in pixel 250, 591 all of the neighbors are clouds
# in pixel 250, 591 all of the neighbors are clouds
# in pixel 250, 591 all of the neighbors are clouds
# in pixel 250, 591 all of the neighbors are clouds
# in pixel 716, 619 all of the neighbors are clouds
# in pixel 716, 619 all of the neighbors are clouds
# in pixel 716, 619 all of the neighbors are clouds
# in pixel 716, 619 all of the neighbors are clouds
# in pixel 716, 619 all of the neighbors are clouds
# in pixel 387, 218 all of the neighbors are clouds
# in pixel 387, 218 all of the neighbors are clouds
# in pixel 387, 218 all of the neighbors are clouds
# in pixel 387, 218 all of the neighbors are clouds
# in pixel 387, 218 all of the neighbors are clouds
# in pixel 499, 187 all of the neighbors are clouds
# in pixel 499, 187 all of the neighbors are clouds
# in pixel 499, 187 all of the neighbors are clouds
# in pixel 499, 187 all of the neighbors are clouds
# in pixel 499, 187 all of the neighbors are clouds
# in pixel 151, 1102 all of the neighbors are clouds
# in pixel 151, 1102 all of the neighbors are clouds
# in pixel 151, 1102 all of the neighbors are clouds
# in pixel 151, 1102 all of the neighbors are clouds
# in pixel 151, 1102 all of the neighbors are clouds
# in pixel 471, 735 all of the neighbors are clouds
# in pixel 471, 735 all of the neighbors are clouds
# in pixel 471, 735 all of the neighbors are clouds
# in pixel 471, 735 all of the neighbors are clouds
# in pixel 471, 735 all of the neighbors are clouds
# in pixel 128, 612 all of the neighbors are clouds
# in pixel 128, 612 all of the neighbors are clouds
# in pixel 128, 612 all of the neighbors are clouds
# in pixel 128, 612 all of the neighbors are clouds
# in pixel 128, 612 all of the neighbors are clouds
# in pixel 235, 591 all of the neighbors are clouds
# in pixel 235, 591 all of the neighbors are clouds
# in pixel 235, 591 all of the neighbors are clouds
# in pixel 235, 591 all of the neighbors are clouds
# in pixel 235, 591 all of the neighbors are clouds
# in pixel 288, 622 all of the neighbors are clouds
# in pixel 288, 622 all of the neighbors are clouds
# in pixel 288, 622 all of the neighbors are clouds
# in pixel 288, 622 all of the neighbors are clouds
# in pixel 288, 622 all of the neighbors are clouds
# in pixel 139, 356 all of the neighbors are clouds
# in pixel 139, 356 all of the neighbors are clouds
# in pixel 139, 356 all of the neighbors are clouds
# in pixel 139, 356 all of the neighbors are clouds
# in pixel 139, 356 all of the neighbors are clouds
# in pixel 371, 319 all of the neighbors are clouds
# in pixel 371, 319 all of the neighbors are clouds
# in pixel 371, 319 all of the neighbors are clouds
# in pixel 371, 319 all of the neighbors are clouds
# in pixel 371, 319 all of the neighbors are clouds
# in pixel 53, 611 all of the neighbors are clouds
# in pixel 53, 611 all of the neighbors are clouds
# in pixel 53, 611 all of the neighbors are clouds
# in pixel 53, 611 all of the neighbors are clouds
# in pixel 53, 611 all of the neighbors are clouds
# in pixel 281, 1624 all of the neighbors are clouds
# in pixel 281, 1624 all of the neighbors are clouds
# in pixel 281, 1624 all of the neighbors are clouds
# in pixel 281, 1624 all of the neighbors are clouds
# in pixel 281, 1624 all of the neighbors are clouds
# in pixel 195, 620 all of the neighbors are clouds
# in pixel 195, 620 all of the neighbors are clouds
# in pixel 195, 620 all of the neighbors are clouds
# in pixel 195, 620 all of the neighbors are clouds
# in pixel 195, 620 all of the neighbors are clouds
# in pixel 293, 309 all of the neighbors are clouds
# in pixel 293, 309 all of the neighbors are clouds
# in pixel 293, 309 all of the neighbors are clouds
# in pixel 293, 309 all of the neighbors are clouds
# in pixel 293, 309 all of the neighbors are clouds
# in pixel 404, 1436 all of the neighbors are clouds
# in pixel 404, 1436 all of the neighbors are clouds
# in pixel 404, 1436 all of the neighbors are clouds
# in pixel 404, 1436 all of the neighbors are clouds
# in pixel 404, 1436 all of the neighbors are clouds
# in pixel 49, 579 all of the neighbors are clouds
# in pixel 49, 579 all of the neighbors are clouds
# in pixel 49, 579 all of the neighbors are clouds
# in pixel 49, 579 all of the neighbors are clouds
# in pixel 49, 579 all of the neighbors are clouds
# in pixel 153, 726 all of the neighbors are clouds
# in pixel 153, 726 all of the neighbors are clouds
# in pixel 153, 726 all of the neighbors are clouds
# in pixel 153, 726 all of the neighbors are clouds
# in pixel 153, 726 all of the neighbors are clouds
# in pixel 116, 626 all of the neighbors are clouds
# in pixel 116, 626 all of the neighbors are clouds
# in pixel 116, 626 all of the neighbors are clouds
# in pixel 116, 626 all of the neighbors are clouds
# in pixel 116, 626 all of the neighbors are clouds
# in pixel 248, 508 all of the neighbors are clouds
# in pixel 248, 508 all of the neighbors are clouds
# in pixel 248, 508 all of the neighbors are clouds
# in pixel 248, 508 all of the neighbors are clouds
# in pixel 248, 508 all of the neighbors are clouds
# in pixel 238, 753 all of the neighbors are clouds
# in pixel 238, 753 all of the neighbors are clouds
# in pixel 238, 753 all of the neighbors are clouds
# in pixel 238, 753 all of the neighbors are clouds
# in pixel 238, 753 all of the neighbors are clouds
# in pixel 100, 1062 all of the neighbors are clouds
# in pixel 100, 1062 all of the neighbors are clouds
# in pixel 100, 1062 all of the neighbors are clouds
# in pixel 100, 1062 all of the neighbors are clouds
# in pixel 100, 1062 all of the neighbors are clouds
# in pixel 87, 413 all of the neighbors are clouds
# in pixel 87, 413 all of the neighbors are clouds
# in pixel 87, 413 all of the neighbors are clouds
# in pixel 87, 413 all of the neighbors are clouds
# in pixel 87, 413 all of the neighbors are clouds
# in pixel 223, 1450 all of the neighbors are clouds
# in pixel 223, 1450 all of the neighbors are clouds
# in pixel 223, 1450 all of the neighbors are clouds
# in pixel 223, 1450 all of the neighbors are clouds
# in pixel 223, 1450 all of the neighbors are clouds
# in pixel 154, 960 all of the neighbors are clouds
# in pixel 154, 960 all of the neighbors are clouds
# in pixel 154, 960 all of the neighbors are clouds
# in pixel 154, 960 all of the neighbors are clouds
# in pixel 154, 960 all of the neighbors are clouds
# in pixel 222, 1199 all of the neighbors are clouds
# in pixel 222, 1199 all of the neighbors are clouds
# in pixel 222, 1199 all of the neighbors are clouds
# in pixel 222, 1199 all of the neighbors are clouds
# in pixel 222, 1199 all of the neighbors are clouds
# in pixel 81, 512 all of the neighbors are clouds
# in pixel 81, 512 all of the neighbors are clouds
# in pixel 81, 512 all of the neighbors are clouds
# in pixel 81, 512 all of the neighbors are clouds
# in pixel 81, 512 all of the neighbors are clouds
# in pixel 121, 1193 all of the neighbors are clouds
# in pixel 121, 1193 all of the neighbors are clouds
# in pixel 121, 1193 all of the neighbors are clouds
# in pixel 121, 1193 all of the neighbors are clouds
# in pixel 121, 1193 all of the neighbors are clouds
# in pixel 104, 838 all of the neighbors are clouds
# in pixel 104, 838 all of the neighbors are clouds
# in pixel 104, 838 all of the neighbors are clouds
# in pixel 104, 838 all of the neighbors are clouds
# in pixel 104, 838 all of the neighbors are clouds
# in pixel 212, 345 all of the neighbors are clouds
# in pixel 212, 345 all of the neighbors are clouds
# in pixel 212, 345 all of the neighbors are clouds
# in pixel 212, 345 all of the neighbors are clouds
# in pixel 212, 345 all of the neighbors are clouds
# in pixel 297, 253 all of the neighbors are clouds
# in pixel 297, 253 all of the neighbors are clouds
# in pixel 297, 253 all of the neighbors are clouds
# in pixel 297, 253 all of the neighbors are clouds
# in pixel 297, 253 all of the neighbors are clouds
# in pixel 225, 590 all of the neighbors are clouds
# in pixel 225, 590 all of the neighbors are clouds
# in pixel 225, 590 all of the neighbors are clouds
# in pixel 225, 590 all of the neighbors are clouds
# in pixel 225, 590 all of the neighbors are clouds
# in pixel 211, 1577 all of the neighbors are clouds
# in pixel 211, 1577 all of the neighbors are clouds
# in pixel 211, 1577 all of the neighbors are clouds
# in pixel 211, 1577 all of the neighbors are clouds
# in pixel 211, 1577 all of the neighbors are clouds
# in pixel 196, 1117 all of the neighbors are clouds
# in pixel 196, 1117 all of the neighbors are clouds
# in pixel 196, 1117 all of the neighbors are clouds
# in pixel 196, 1117 all of the neighbors are clouds
# in pixel 196, 1117 all of the neighbors are clouds
# in pixel 93, 623 all of the neighbors are clouds
# in pixel 93, 623 all of the neighbors are clouds
# in pixel 93, 623 all of the neighbors are clouds
# in pixel 93, 623 all of the neighbors are clouds
# in pixel 93, 623 all of the neighbors are clouds
# in pixel 290, 1512 all of the neighbors are clouds
# in pixel 290, 1512 all of the neighbors are clouds
# in pixel 290, 1512 all of the neighbors are clouds
# in pixel 290, 1512 all of the neighbors are clouds
# in pixel 290, 1512 all of the neighbors are clouds
# in pixel 285, 1667 all of the neighbors are clouds
# in pixel 285, 1667 all of the neighbors are clouds
# in pixel 285, 1667 all of the neighbors are clouds
# in pixel 285, 1667 all of the neighbors are clouds
# in pixel 285, 1667 all of the neighbors are clouds
# in pixel 448, 186 all of the neighbors are clouds
# in pixel 448, 186 all of the neighbors are clouds
# in pixel 448, 186 all of the neighbors are clouds
# in pixel 448, 186 all of the neighbors are clouds
# in pixel 448, 186 all of the neighbors are clouds
# in pixel 246, 766 all of the neighbors are clouds
# in pixel 246, 766 all of the neighbors are clouds
# in pixel 246, 766 all of the neighbors are clouds
# in pixel 246, 766 all of the neighbors are clouds
# in pixel 246, 766 all of the neighbors are clouds
# in pixel 100, 686 all of the neighbors are clouds
# in pixel 100, 686 all of the neighbors are clouds
# in pixel 100, 686 all of the neighbors are clouds
# in pixel 100, 686 all of the neighbors are clouds
# in pixel 100, 686 all of the neighbors are clouds
# in pixel 352, 325 all of the neighbors are clouds
# in pixel 352, 325 all of the neighbors are clouds
# in pixel 352, 325 all of the neighbors are clouds
# in pixel 352, 325 all of the neighbors are clouds
# in pixel 352, 325 all of the neighbors are clouds
# in pixel 219, 1518 all of the neighbors are clouds
# in pixel 219, 1518 all of the neighbors are clouds
# in pixel 219, 1518 all of the neighbors are clouds
# in pixel 219, 1518 all of the neighbors are clouds
# in pixel 219, 1518 all of the neighbors are clouds
# in pixel 142, 562 all of the neighbors are clouds
# in pixel 142, 562 all of the neighbors are clouds
# in pixel 142, 562 all of the neighbors are clouds
# in pixel 142, 562 all of the neighbors are clouds
# in pixel 142, 562 all of the neighbors are clouds
# in pixel 201, 1058 all of the neighbors are clouds
# in pixel 201, 1058 all of the neighbors are clouds
# in pixel 201, 1058 all of the neighbors are clouds
# in pixel 201, 1058 all of the neighbors are clouds
# in pixel 201, 1058 all of the neighbors are clouds
# in pixel 215, 1471 all of the neighbors are clouds
# in pixel 215, 1471 all of the neighbors are clouds
# in pixel 215, 1471 all of the neighbors are clouds
# in pixel 215, 1471 all of the neighbors are clouds
# in pixel 215, 1471 all of the neighbors are clouds
# in pixel 333, 1244 all of the neighbors are clouds
# in pixel 333, 1244 all of the neighbors are clouds
# in pixel 333, 1244 all of the neighbors are clouds
# in pixel 333, 1244 all of the neighbors are clouds
# in pixel 333, 1244 all of the neighbors are clouds
# in pixel 221, 1033 all of the neighbors are clouds
# in pixel 221, 1033 all of the neighbors are clouds
# in pixel 221, 1033 all of the neighbors are clouds
# in pixel 221, 1033 all of the neighbors are clouds
# in pixel 221, 1033 all of the neighbors are clouds
# in pixel 333, 1656 all of the neighbors are clouds
# in pixel 333, 1656 all of the neighbors are clouds
# in pixel 333, 1656 all of the neighbors are clouds
# in pixel 333, 1656 all of the neighbors are clouds
# in pixel 333, 1656 all of the neighbors are clouds
# in pixel 329, 1588 all of the neighbors are clouds
# in pixel 329, 1588 all of the neighbors are clouds
# in pixel 329, 1588 all of the neighbors are clouds
# in pixel 329, 1588 all of the neighbors are clouds
# in pixel 329, 1588 all of the neighbors are clouds
# in pixel 255, 334 all of the neighbors are clouds
# in pixel 255, 334 all of the neighbors are clouds
# in pixel 255, 334 all of the neighbors are clouds
# in pixel 255, 334 all of the neighbors are clouds
# in pixel 255, 334 all of the neighbors are clouds
# in pixel 164, 624 all of the neighbors are clouds
# in pixel 164, 624 all of the neighbors are clouds
# in pixel 164, 624 all of the neighbors are clouds
# in pixel 164, 624 all of the neighbors are clouds
# in pixel 164, 624 all of the neighbors are clouds
# in pixel 158, 616 all of the neighbors are clouds
# in pixel 158, 616 all of the neighbors are clouds
# in pixel 158, 616 all of the neighbors are clouds
# in pixel 158, 616 all of the neighbors are clouds
# in pixel 158, 616 all of the neighbors are clouds
# in pixel 788, 1123 all of the neighbors are clouds
# in pixel 788, 1123 all of the neighbors are clouds
# in pixel 788, 1123 all of the neighbors are clouds
# in pixel 788, 1123 all of the neighbors are clouds
# in pixel 788, 1123 all of the neighbors are clouds
# in pixel 131, 897 all of the neighbors are clouds
# in pixel 131, 897 all of the neighbors are clouds
# in pixel 131, 897 all of the neighbors are clouds
# in pixel 131, 897 all of the neighbors are clouds
# in pixel 131, 897 all of the neighbors are clouds
# in pixel 165, 1018 all of the neighbors are clouds
# in pixel 165, 1018 all of the neighbors are clouds
# in pixel 165, 1018 all of the neighbors are clouds
# in pixel 165, 1018 all of the neighbors are clouds
# in pixel 165, 1018 all of the neighbors are clouds
# in pixel 47, 667 all of the neighbors are clouds
# in pixel 47, 667 all of the neighbors are clouds
# in pixel 47, 667 all of the neighbors are clouds
# in pixel 47, 667 all of the neighbors are clouds
# in pixel 47, 667 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# ...
# in pixel 164, 624 all of the neighbors are clouds
# in pixel 164, 624 all of the neighbors are clouds
# in pixel 164, 624 all of the neighbors are clouds
# in pixel 158, 616 all of the neighbors are clouds
# in pixel 158, 616 all of the neighbors are clouds
# in pixel 158, 616 all of the neighbors are clouds
# in pixel 158, 616 all of the neighbors are clouds
# in pixel 158, 616 all of the neighbors are clouds
# in pixel 788, 1123 all of the neighbors are clouds
# in pixel 788, 1123 all of the neighbors are clouds
# in pixel 788, 1123 all of the neighbors are clouds
# in pixel 788, 1123 all of the neighbors are clouds
# in pixel 788, 1123 all of the neighbors are clouds
# in pixel 131, 897 all of the neighbors are clouds
# in pixel 131, 897 all of the neighbors are clouds
# in pixel 131, 897 all of the neighbors are clouds
# in pixel 131, 897 all of the neighbors are clouds
# in pixel 131, 897 all of the neighbors are clouds
# in pixel 165, 1018 all of the neighbors are clouds
# in pixel 165, 1018 all of the neighbors are clouds
# in pixel 165, 1018 all of the neighbors are clouds
# in pixel 165, 1018 all of the neighbors are clouds
# in pixel 165, 1018 all of the neighbors are clouds
# in pixel 47, 667 all of the neighbors are clouds
# in pixel 47, 667 all of the neighbors are clouds
# in pixel 47, 667 all of the neighbors are clouds
# in pixel 47, 667 all of the neighbors are clouds
# in pixel 47, 667 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 156, 833 all of the neighbors are clouds
# in pixel 156, 833 all of the neighbors are clouds
# in pixel 156, 833 all of the neighbors are clouds
# in pixel 156, 833 all of the neighbors are clouds
# in pixel 156, 833 all of the neighbors are clouds
# in pixel 239, 395 all of the neighbors are clouds
# in pixel 239, 395 all of the neighbors are clouds
# in pixel 239, 395 all of the neighbors are clouds
# in pixel 239, 395 all of the neighbors are clouds
# in pixel 239, 395 all of the neighbors are clouds
# in pixel 231, 717 all of the neighbors are clouds
# in pixel 231, 717 all of the neighbors are clouds
# in pixel 231, 717 all of the neighbors are clouds
# in pixel 231, 717 all of the neighbors are clouds
# in pixel 231, 717 all of the neighbors are clouds
# in pixel 336, 421 all of the neighbors are clouds
# in pixel 336, 421 all of the neighbors are clouds
# in pixel 336, 421 all of the neighbors are clouds
# in pixel 336, 421 all of the neighbors are clouds
# in pixel 336, 421 all of the neighbors are clouds
# in pixel 110, 532 all of the neighbors are clouds
# in pixel 110, 532 all of the neighbors are clouds
# in pixel 110, 532 all of the neighbors are clouds
# in pixel 110, 532 all of the neighbors are clouds
# in pixel 110, 532 all of the neighbors are clouds
# in pixel 250, 704 all of the neighbors are clouds
# in pixel 250, 704 all of the neighbors are clouds
# in pixel 250, 704 all of the neighbors are clouds
# in pixel 250, 704 all of the neighbors are clouds
# in pixel 250, 704 all of the neighbors are clouds
# in pixel 100, 437 all of the neighbors are clouds
# in pixel 100, 437 all of the neighbors are clouds
# in pixel 100, 437 all of the neighbors are clouds
# in pixel 100, 437 all of the neighbors are clouds
# in pixel 100, 437 all of the neighbors are clouds
# in pixel 485, 721 all of the neighbors are clouds
# in pixel 485, 721 all of the neighbors are clouds
# in pixel 485, 721 all of the neighbors are clouds
# in pixel 485, 721 all of the neighbors are clouds
# in pixel 485, 721 all of the neighbors are clouds
# in pixel 235, 385 all of the neighbors are clouds
# in pixel 235, 385 all of the neighbors are clouds
# in pixel 235, 385 all of the neighbors are clouds
# in pixel 235, 385 all of the neighbors are clouds
# in pixel 235, 385 all of the neighbors are clouds
# in pixel 192, 761 all of the neighbors are clouds
# in pixel 192, 761 all of the neighbors are clouds
# in pixel 192, 761 all of the neighbors are clouds
# in pixel 192, 761 all of the neighbors are clouds
# in pixel 192, 761 all of the neighbors are clouds
# in pixel 180, 627 all of the neighbors are clouds
# in pixel 180, 627 all of the neighbors are clouds
# in pixel 180, 627 all of the neighbors are clouds
# in pixel 180, 627 all of the neighbors are clouds
# in pixel 180, 627 all of the neighbors are clouds
# in pixel 230, 1481 all of the neighbors are clouds
# in pixel 230, 1481 all of the neighbors are clouds
# in pixel 230, 1481 all of the neighbors are clouds
# in pixel 230, 1481 all of the neighbors are clouds
# in pixel 230, 1481 all of the neighbors are clouds
# in pixel 295, 1600 all of the neighbors are clouds
# in pixel 295, 1600 all of the neighbors are clouds
# in pixel 295, 1600 all of the neighbors are clouds
# in pixel 295, 1600 all of the neighbors are clouds
# in pixel 295, 1600 all of the neighbors are clouds
# in pixel 302, 401 all of the neighbors are clouds
# in pixel 302, 401 all of the neighbors are clouds
# in pixel 302, 401 all of the neighbors are clouds
# in pixel 302, 401 all of the neighbors are clouds
# in pixel 302, 401 all of the neighbors are clouds
# in pixel 1027, 1252 all of the neighbors are clouds
# in pixel 1027, 1252 all of the neighbors are clouds
# in pixel 1027, 1252 all of the neighbors are clouds
# in pixel 1027, 1252 all of the neighbors are clouds
# in pixel 1027, 1252 all of the neighbors are clouds
# in pixel 382, 1577 all of the neighbors are clouds
# in pixel 382, 1577 all of the neighbors are clouds
# in pixel 382, 1577 all of the neighbors are clouds
# in pixel 382, 1577 all of the neighbors are clouds
# in pixel 382, 1577 all of the neighbors are clouds
# in pixel 159, 1534 all of the neighbors are clouds
# in pixel 159, 1534 all of the neighbors are clouds
# in pixel 159, 1534 all of the neighbors are clouds
# in pixel 159, 1534 all of the neighbors are clouds
# in pixel 159, 1534 all of the neighbors are clouds
# in pixel 161, 897 all of the neighbors are clouds
# in pixel 161, 897 all of the neighbors are clouds
# in pixel 161, 897 all of the neighbors are clouds
# in pixel 161, 897 all of the neighbors are clouds
# in pixel 161, 897 all of the neighbors are clouds
# in pixel 340, 1398 all of the neighbors are clouds
# in pixel 340, 1398 all of the neighbors are clouds
# in pixel 340, 1398 all of the neighbors are clouds
# in pixel 340, 1398 all of the neighbors are clouds
# in pixel 340, 1398 all of the neighbors are clouds
# in pixel 126, 1153 all of the neighbors are clouds
# in pixel 126, 1153 all of the neighbors are clouds
# in pixel 126, 1153 all of the neighbors are clouds
# in pixel 126, 1153 all of the neighbors are clouds
# in pixel 126, 1153 all of the neighbors are clouds
# in pixel 60, 515 all of the neighbors are clouds
# in pixel 60, 515 all of the neighbors are clouds
# in pixel 60, 515 all of the neighbors are clouds
# in pixel 60, 515 all of the neighbors are clouds
# in pixel 60, 515 all of the neighbors are clouds
# in pixel 132, 969 all of the neighbors are clouds
# in pixel 132, 969 all of the neighbors are clouds
# in pixel 132, 969 all of the neighbors are clouds
# in pixel 132, 969 all of the neighbors are clouds
# in pixel 132, 969 all of the neighbors are clouds
# in pixel 363, 1639 all of the neighbors are clouds
# in pixel 363, 1639 all of the neighbors are clouds
# in pixel 363, 1639 all of the neighbors are clouds
# in pixel 363, 1639 all of the neighbors are clouds
# in pixel 363, 1639 all of the neighbors are clouds
# in pixel 280, 307 all of the neighbors are clouds
# in pixel 280, 307 all of the neighbors are clouds
# in pixel 280, 307 all of the neighbors are clouds
# in pixel 280, 307 all of the neighbors are clouds
# in pixel 280, 307 all of the neighbors are clouds
# in pixel 144, 1441 all of the neighbors are clouds
# in pixel 144, 1441 all of the neighbors are clouds
# in pixel 144, 1441 all of the neighbors are clouds
# in pixel 144, 1441 all of the neighbors are clouds
# in pixel 144, 1441 all of the neighbors are clouds
# in pixel 138, 373 all of the neighbors are clouds
# in pixel 138, 373 all of the neighbors are clouds
# in pixel 138, 373 all of the neighbors are clouds
# in pixel 138, 373 all of the neighbors are clouds
# in pixel 138, 373 all of the neighbors are clouds
# in pixel 184, 425 all of the neighbors are clouds
# in pixel 184, 425 all of the neighbors are clouds
# in pixel 184, 425 all of the neighbors are clouds
# in pixel 184, 425 all of the neighbors are clouds
# in pixel 184, 425 all of the neighbors are clouds
# in pixel 88, 405 all of the neighbors are clouds
# in pixel 88, 405 all of the neighbors are clouds
# in pixel 88, 405 all of the neighbors are clouds
# in pixel 88, 405 all of the neighbors are clouds
# in pixel 88, 405 all of the neighbors are clouds
# in pixel 234, 1560 all of the neighbors are clouds
# in pixel 234, 1560 all of the neighbors are clouds
# in pixel 234, 1560 all of the neighbors are clouds
# in pixel 234, 1560 all of the neighbors are clouds
# in pixel 234, 1560 all of the neighbors are clouds
# in pixel 224, 331 all of the neighbors are clouds
# in pixel 224, 331 all of the neighbors are clouds
# in pixel 224, 331 all of the neighbors are clouds
# in pixel 224, 331 all of the neighbors are clouds
# in pixel 224, 331 all of the neighbors are clouds
# in pixel 830, 251 all of the neighbors are clouds
# in pixel 830, 251 all of the neighbors are clouds
# in pixel 830, 251 all of the neighbors are clouds
# in pixel 830, 251 all of the neighbors are clouds
# in pixel 830, 251 all of the neighbors are clouds
# in pixel 269, 1442 all of the neighbors are clouds
# in pixel 269, 1442 all of the neighbors are clouds
# in pixel 269, 1442 all of the neighbors are clouds
# in pixel 269, 1442 all of the neighbors are clouds
# in pixel 269, 1442 all of the neighbors are clouds
# in pixel 51, 750 all of the neighbors are clouds
# in pixel 51, 750 all of the neighbors are clouds
# in pixel 51, 750 all of the neighbors are clouds
# in pixel 51, 750 all of the neighbors are clouds
# in pixel 51, 750 all of the neighbors are clouds
# in pixel 140, 902 all of the neighbors are clouds
# in pixel 140, 902 all of the neighbors are clouds
# in pixel 140, 902 all of the neighbors are clouds
# in pixel 140, 902 all of the neighbors are clouds
# in pixel 140, 902 all of the neighbors are clouds
# in pixel 137, 1242 all of the neighbors are clouds
# in pixel 137, 1242 all of the neighbors are clouds
# in pixel 137, 1242 all of the neighbors are clouds
# in pixel 137, 1242 all of the neighbors are clouds
# in pixel 137, 1242 all of the neighbors are clouds
# in pixel 149, 949 all of the neighbors are clouds
# in pixel 149, 949 all of the neighbors are clouds
# in pixel 149, 949 all of the neighbors are clouds
# in pixel 149, 949 all of the neighbors are clouds
# in pixel 149, 949 all of the neighbors are clouds
# in pixel 137, 941 all of the neighbors are clouds
# in pixel 137, 941 all of the neighbors are clouds
# in pixel 137, 941 all of the neighbors are clouds
# in pixel 137, 941 all of the neighbors are clouds
# in pixel 137, 941 all of the neighbors are clouds
# in pixel 284, 328 all of the neighbors are clouds
# in pixel 284, 328 all of the neighbors are clouds
# in pixel 284, 328 all of the neighbors are clouds
# in pixel 284, 328 all of the neighbors are clouds
# in pixel 284, 328 all of the neighbors are clouds
# in pixel 368, 262 all of the neighbors are clouds
# in pixel 368, 262 all of the neighbors are clouds
# in pixel 368, 262 all of the neighbors are clouds
# in pixel 368, 262 all of the neighbors are clouds
# in pixel 368, 262 all of the neighbors are clouds
# in pixel 310, 365 all of the neighbors are clouds
# in pixel 310, 365 all of the neighbors are clouds
# in pixel 310, 365 all of the neighbors are clouds
# in pixel 310, 365 all of the neighbors are clouds
# in pixel 310, 365 all of the neighbors are clouds
# in pixel 208, 1146 all of the neighbors are clouds
# in pixel 208, 1146 all of the neighbors are clouds
# in pixel 208, 1146 all of the neighbors are clouds
# in pixel 208, 1146 all of the neighbors are clouds
# in pixel 208, 1146 all of the neighbors are clouds
# in pixel 207, 576 all of the neighbors are clouds
# in pixel 207, 576 all of the neighbors are clouds
# in pixel 207, 576 all of the neighbors are clouds
# in pixel 207, 576 all of the neighbors are clouds
# in pixel 207, 576 all of the neighbors are clouds
# in pixel 293, 495 all of the neighbors are clouds
# in pixel 293, 495 all of the neighbors are clouds
# in pixel 293, 495 all of the neighbors are clouds
# in pixel 293, 495 all of the neighbors are clouds
# in pixel 293, 495 all of the neighbors are clouds
# in pixel 320, 1677 all of the neighbors are clouds
# in pixel 320, 1677 all of the neighbors are clouds
# in pixel 320, 1677 all of the neighbors are clouds
# in pixel 320, 1677 all of the neighbors are clouds
# in pixel 320, 1677 all of the neighbors are clouds
# in pixel 213, 1312 all of the neighbors are clouds
# in pixel 213, 1312 all of the neighbors are clouds
# in pixel 213, 1312 all of the neighbors are clouds
# in pixel 213, 1312 all of the neighbors are clouds
# in pixel 213, 1312 all of the neighbors are clouds
# in pixel 173, 868 all of the neighbors are clouds
# in pixel 173, 868 all of the neighbors are clouds
# in pixel 173, 868 all of the neighbors are clouds
# in pixel 173, 868 all of the neighbors are clouds
# in pixel 173, 868 all of the neighbors are clouds
# in pixel 131, 1301 all of the neighbors are clouds
# in pixel 131, 1301 all of the neighbors are clouds
# in pixel 131, 1301 all of the neighbors are clouds
# in pixel 131, 1301 all of the neighbors are clouds
# in pixel 131, 1301 all of the neighbors are clouds
# in pixel 159, 484 all of the neighbors are clouds
# in pixel 159, 484 all of the neighbors are clouds
# in pixel 159, 484 all of the neighbors are clouds
# in pixel 159, 484 all of the neighbors are clouds
# in pixel 159, 484 all of the neighbors are clouds
# in pixel 214, 1227 all of the neighbors are clouds
# in pixel 214, 1227 all of the neighbors are clouds
# in pixel 214, 1227 all of the neighbors are clouds
# in pixel 214, 1227 all of the neighbors are clouds
# in pixel 214, 1227 all of the neighbors are clouds

# %%
df_temporal_non_fire_pixels = MLT.get_temporal_fire_pixel_values_in_all_bands(temporal_df=temporal_df,
                                                                          pixel_location_list=non_fire_pixels,
                                                                          VIIRS_path=NC_VIIRS_df["VIIRS_file_full_path"].iloc[0],
                                                                          GOES_date_time=NC_VIIRS_df["GOES_date_time"].iloc[0],
                                                                          temporal_images=4)
# Out:
# in pixel 207, 643 all of the neighbors are clouds
# in pixel 207, 643 all of the neighbors are clouds
# in pixel 207, 643 all of the neighbors are clouds
# in pixel 207, 643 all of the neighbors are clouds
# in pixel 207, 643 all of the neighbors are clouds
# in pixel 230, 908 all of the neighbors are clouds
# in pixel 230, 908 all of the neighbors are clouds
# in pixel 230, 908 all of the neighbors are clouds
# in pixel 230, 908 all of the neighbors are clouds
# in pixel 230, 908 all of the neighbors are clouds
# in pixel 269, 617 all of the neighbors are clouds
# in pixel 269, 617 all of the neighbors are clouds
# in pixel 269, 617 all of the neighbors are clouds
# in pixel 269, 617 all of the neighbors are clouds
# in pixel 269, 617 all of the neighbors are clouds
# in pixel 92, 1017 all of the neighbors are clouds
# in pixel 92, 1017 all of the neighbors are clouds
# in pixel 92, 1017 all of the neighbors are clouds
# in pixel 92, 1017 all of the neighbors are clouds
# in pixel 92, 1017 all of the neighbors are clouds
# in pixel 221, 626 all of the neighbors are clouds
# in pixel 221, 626 all of the neighbors are clouds
# in pixel 221, 626 all of the neighbors are clouds
# in pixel 221, 626 all of the neighbors are clouds
# in pixel 221, 626 all of the neighbors are clouds
# in pixel 182, 1108 all of the neighbors are clouds
# in pixel 182, 1108 all of the neighbors are clouds
# in pixel 182, 1108 all of the neighbors are clouds
# in pixel 182, 1108 all of the neighbors are clouds
# in pixel 182, 1108 all of the neighbors are clouds
# in pixel 388, 1560 all of the neighbors are clouds
# in pixel 388, 1560 all of the neighbors are clouds
# in pixel 388, 1560 all of the neighbors are clouds
# in pixel 388, 1560 all of the neighbors are clouds
# in pixel 388, 1560 all of the neighbors are clouds
# in pixel 313, 487 all of the neighbors are clouds
# in pixel 313, 487 all of the neighbors are clouds
# in pixel 313, 487 all of the neighbors are clouds
# in pixel 313, 487 all of the neighbors are clouds
# in pixel 313, 487 all of the neighbors are clouds
# in pixel 93, 926 all of the neighbors are clouds
# in pixel 93, 926 all of the neighbors are clouds
# in pixel 93, 926 all of the neighbors are clouds
# in pixel 93, 926 all of the neighbors are clouds
# in pixel 93, 926 all of the neighbors are clouds
# in pixel 41, 587 all of the neighbors are clouds
# in pixel 41, 587 all of the neighbors are clouds
# in pixel 41, 587 all of the neighbors are clouds
# in pixel 41, 587 all of the neighbors are clouds
# in pixel 41, 587 all of the neighbors are clouds
# in pixel 250, 554 all of the neighbors are clouds
# in pixel 250, 554 all of the neighbors are clouds
# in pixel 250, 554 all of the neighbors are clouds
# in pixel 250, 554 all of the neighbors are clouds
# in pixel 250, 554 all of the neighbors are clouds
# in pixel 99, 967 all of the neighbors are clouds
# in pixel 99, 967 all of the neighbors are clouds
# in pixel 99, 967 all of the neighbors are clouds
# in pixel 99, 967 all of the neighbors are clouds
# in pixel 99, 967 all of the neighbors are clouds
# in pixel 273, 1629 all of the neighbors are clouds
# in pixel 273, 1629 all of the neighbors are clouds
# in pixel 273, 1629 all of the neighbors are clouds
# in pixel 273, 1629 all of the neighbors are clouds
# in pixel 273, 1629 all of the neighbors are clouds
# in pixel 418, 277 all of the neighbors are clouds
# in pixel 418, 277 all of the neighbors are clouds
# in pixel 418, 277 all of the neighbors are clouds
# in pixel 418, 277 all of the neighbors are clouds
# in pixel 418, 277 all of the neighbors are clouds
# in pixel 192, 860 all of the neighbors are clouds
# in pixel 192, 860 all of the neighbors are clouds
# in pixel 192, 860 all of the neighbors are clouds
# in pixel 192, 860 all of the neighbors are clouds
# in pixel 192, 860 all of the neighbors are clouds
# in pixel 169, 1582 all of the neighbors are clouds
# in pixel 169, 1582 all of the neighbors are clouds
# in pixel 169, 1582 all of the neighbors are clouds
# in pixel 169, 1582 all of the neighbors are clouds
# in pixel 169, 1582 all of the neighbors are clouds
# in pixel 161, 969 all of the neighbors are clouds
# in pixel 161, 969 all of the neighbors are clouds
# in pixel 161, 969 all of the neighbors are clouds
# in pixel 161, 969 all of the neighbors are clouds
# in pixel 161, 969 all of the neighbors are clouds
# in pixel 103, 916 all of the neighbors are clouds
# in pixel 103, 916 all of the neighbors are clouds
# in pixel 103, 916 all of the neighbors are clouds
# in pixel 103, 916 all of the neighbors are clouds
# in pixel 103, 916 all of the neighbors are clouds
# in pixel 813, 1273 all of the neighbors are clouds
# in pixel 813, 1273 all of the neighbors are clouds
# in pixel 813, 1273 all of the neighbors are clouds
# in pixel 813, 1273 all of the neighbors are clouds
# in pixel 813, 1273 all of the neighbors are clouds
# in pixel 193, 1581 all of the neighbors are clouds
# in pixel 193, 1581 all of the neighbors are clouds
# in pixel 193, 1581 all of the neighbors are clouds
# in pixel 193, 1581 all of the neighbors are clouds
# in pixel 193, 1581 all of the neighbors are clouds
# in pixel 405, 1589 all of the neighbors are clouds
# in pixel 405, 1589 all of the neighbors are clouds
# in pixel 405, 1589 all of the neighbors are clouds
# in pixel 405, 1589 all of the neighbors are clouds
# in pixel 405, 1589 all of the neighbors are clouds
# in pixel 156, 1506 all of the neighbors are clouds
# in pixel 156, 1506 all of the neighbors are clouds
# in pixel 156, 1506 all of the neighbors are clouds
# in pixel 156, 1506 all of the neighbors are clouds
# in pixel 156, 1506 all of the neighbors are clouds
# in pixel 322, 1318 all of the neighbors are clouds
# in pixel 322, 1318 all of the neighbors are clouds
# in pixel 322, 1318 all of the neighbors are clouds
# in pixel 322, 1318 all of the neighbors are clouds
# in pixel 322, 1318 all of the neighbors are clouds
# in pixel 196, 597 all of the neighbors are clouds
# in pixel 196, 597 all of the neighbors are clouds
# in pixel 196, 597 all of the neighbors are clouds
# in pixel 196, 597 all of the neighbors are clouds
# in pixel 196, 597 all of the neighbors are clouds
# in pixel 259, 538 all of the neighbors are clouds
# in pixel 259, 538 all of the neighbors are clouds
# in pixel 259, 538 all of the neighbors are clouds
# in pixel 259, 538 all of the neighbors are clouds
# in pixel 259, 538 all of the neighbors are clouds
# in pixel 290, 1681 all of the neighbors are clouds
# in pixel 290, 1681 all of the neighbors are clouds
# in pixel 290, 1681 all of the neighbors are clouds
# in pixel 290, 1681 all of the neighbors are clouds
# in pixel 290, 1681 all of the neighbors are clouds
# in pixel 199, 1011 all of the neighbors are clouds
# in pixel 199, 1011 all of the neighbors are clouds
# in pixel 199, 1011 all of the neighbors are clouds
# in pixel 199, 1011 all of the neighbors are clouds
# in pixel 199, 1011 all of the neighbors are clouds
# in pixel 186, 1406 all of the neighbors are clouds
# in pixel 186, 1406 all of the neighbors are clouds
# in pixel 186, 1406 all of the neighbors are clouds
# in pixel 186, 1406 all of the neighbors are clouds
# in pixel 186, 1406 all of the neighbors are clouds
# in pixel 179, 1556 all of the neighbors are clouds
# in pixel 179, 1556 all of the neighbors are clouds
# in pixel 179, 1556 all of the neighbors are clouds
# in pixel 179, 1556 all of the neighbors are clouds
# in pixel 179, 1556 all of the neighbors are clouds
# in pixel 410, 1615 all of the neighbors are clouds
# in pixel 410, 1615 all of the neighbors are clouds
# in pixel 410, 1615 all of the neighbors are clouds
# in pixel 410, 1615 all of the neighbors are clouds
# in pixel 410, 1615 all of the neighbors are clouds
# in pixel 342, 379 all of the neighbors are clouds
# in pixel 342, 379 all of the neighbors are clouds
# in pixel 342, 379 all of the neighbors are clouds
# in pixel 342, 379 all of the neighbors are clouds
# in pixel 342, 379 all of the neighbors are clouds
# in pixel 134, 846 all of the neighbors are clouds
# in pixel 134, 846 all of the neighbors are clouds
# in pixel 134, 846 all of the neighbors are clouds
# in pixel 134, 846 all of the neighbors are clouds
# in pixel 134, 846 all of the neighbors are clouds
# in pixel 975, 1113 all of the neighbors are clouds
# in pixel 975, 1113 all of the neighbors are clouds
# in pixel 975, 1113 all of the neighbors are clouds
# in pixel 975, 1113 all of the neighbors are clouds
# in pixel 975, 1113 all of the neighbors are clouds
# in pixel 323, 1350 all of the neighbors are clouds
# in pixel 323, 1350 all of the neighbors are clouds
# in pixel 323, 1350 all of the neighbors are clouds
# in pixel 323, 1350 all of the neighbors are clouds
# in pixel 323, 1350 all of the neighbors are clouds
# in pixel 265, 476 all of the neighbors are clouds
# in pixel 265, 476 all of the neighbors are clouds
# in pixel 265, 476 all of the neighbors are clouds
# in pixel 265, 476 all of the neighbors are clouds
# in pixel 265, 476 all of the neighbors are clouds
# in pixel 351, 1551 all of the neighbors are clouds
# in pixel 351, 1551 all of the neighbors are clouds
# in pixel 351, 1551 all of the neighbors are clouds
# in pixel 351, 1551 all of the neighbors are clouds
# in pixel 351, 1551 all of the neighbors are clouds
# in pixel 235, 449 all of the neighbors are clouds
# in pixel 235, 449 all of the neighbors are clouds
# in pixel 235, 449 all of the neighbors are clouds
# in pixel 235, 449 all of the neighbors are clouds
# in pixel 235, 449 all of the neighbors are clouds
# in pixel 298, 473 all of the neighbors are clouds
# in pixel 298, 473 all of the neighbors are clouds
# in pixel 298, 473 all of the neighbors are clouds
# in pixel 298, 473 all of the neighbors are clouds
# in pixel 298, 473 all of the neighbors are clouds
# in pixel 199, 1031 all of the neighbors are clouds
# in pixel 199, 1031 all of the neighbors are clouds
# in pixel 199, 1031 all of the neighbors are clouds
# in pixel 199, 1031 all of the neighbors are clouds
# in pixel 199, 1031 all of the neighbors are clouds
# in pixel 127, 606 all of the neighbors are clouds
# in pixel 127, 606 all of the neighbors are clouds
# in pixel 127, 606 all of the neighbors are clouds
# in pixel 127, 606 all of the neighbors are clouds
# in pixel 127, 606 all of the neighbors are clouds
# in pixel 252, 593 all of the neighbors are clouds
# in pixel 252, 593 all of the neighbors are clouds
# in pixel 252, 593 all of the neighbors are clouds
# in pixel 252, 593 all of the neighbors are clouds
# in pixel 252, 593 all of the neighbors are clouds
# in pixel 122, 509 all of the neighbors are clouds
# in pixel 122, 509 all of the neighbors are clouds
# in pixel 122, 509 all of the neighbors are clouds
# in pixel 122, 509 all of the neighbors are clouds
# in pixel 122, 509 all of the neighbors are clouds
# in pixel 420, 317 all of the neighbors are clouds
# in pixel 420, 317 all of the neighbors are clouds
# in pixel 420, 317 all of the neighbors are clouds
# in pixel 420, 317 all of the neighbors are clouds
# in pixel 420, 317 all of the neighbors are clouds
# in pixel 343, 263 all of the neighbors are clouds
# in pixel 343, 263 all of the neighbors are clouds
# in pixel 343, 263 all of the neighbors are clouds
# in pixel 343, 263 all of the neighbors are clouds
# in pixel 343, 263 all of the neighbors are clouds
# in pixel 135, 757 all of the neighbors are clouds
# in pixel 135, 757 all of the neighbors are clouds
# in pixel 135, 757 all of the neighbors are clouds
# in pixel 135, 757 all of the neighbors are clouds
# in pixel 135, 757 all of the neighbors are clouds
# in pixel 335, 338 all of the neighbors are clouds
# in pixel 335, 338 all of the neighbors are clouds
# in pixel 335, 338 all of the neighbors are clouds
# in pixel 335, 338 all of the neighbors are clouds
# in pixel 335, 338 all of the neighbors are clouds
# in pixel 257, 305 all of the neighbors are clouds
# in pixel 257, 305 all of the neighbors are clouds
# in pixel 257, 305 all of the neighbors are clouds
# in pixel 257, 305 all of the neighbors are clouds
# in pixel 257, 305 all of the neighbors are clouds
# in pixel 166, 392 all of the neighbors are clouds
# in pixel 166, 392 all of the neighbors are clouds
# in pixel 166, 392 all of the neighbors are clouds
# in pixel 166, 392 all of the neighbors are clouds
# in pixel 166, 392 all of the neighbors are clouds
# in pixel 416, 224 all of the neighbors are clouds
# in pixel 416, 224 all of the neighbors are clouds
# in pixel 416, 224 all of the neighbors are clouds
# in pixel 416, 224 all of the neighbors are clouds
# in pixel 416, 224 all of the neighbors are clouds
# in pixel 422, 333 all of the neighbors are clouds
# in pixel 422, 333 all of the neighbors are clouds
# in pixel 422, 333 all of the neighbors are clouds
# in pixel 422, 333 all of the neighbors are clouds
# in pixel 422, 333 all of the neighbors are clouds
# in pixel 306, 1390 all of the neighbors are clouds
# in pixel 306, 1390 all of the neighbors are clouds
# in pixel 306, 1390 all of the neighbors are clouds
# in pixel 306, 1390 all of the neighbors are clouds
# in pixel 306, 1390 all of the neighbors are clouds
# in pixel 208, 300 all of the neighbors are clouds
# in pixel 208, 300 all of the neighbors are clouds
# in pixel 208, 300 all of the neighbors are clouds
# in pixel 208, 300 all of the neighbors are clouds
# in pixel 208, 300 all of the neighbors are clouds
# in pixel 293, 506 all of the neighbors are clouds
# in pixel 293, 506 all of the neighbors are clouds
# in pixel 293, 506 all of the neighbors are clouds
# in pixel 293, 506 all of the neighbors are clouds
# in pixel 293, 506 all of the neighbors are clouds
# in pixel 192, 492 all of the neighbors are clouds
# in pixel 192, 492 all of the neighbors are clouds
# in pixel 192, 492 all of the neighbors are clouds
# in pixel 192, 492 all of the neighbors are clouds
# in pixel 192, 492 all of the neighbors are clouds
# in pixel 150, 1293 all of the neighbors are clouds
# in pixel 150, 1293 all of the neighbors are clouds
# in pixel 150, 1293 all of the neighbors are clouds
# in pixel 150, 1293 all of the neighbors are clouds
# in pixel 150, 1293 all of the neighbors are clouds
# in pixel 211, 1438 all of the neighbors are clouds
# in pixel 211, 1438 all of the neighbors are clouds
# in pixel 211, 1438 all of the neighbors are clouds
# in pixel 211, 1438 all of the neighbors are clouds
# in pixel 211, 1438 all of the neighbors are clouds
# in pixel 236, 1414 all of the neighbors are clouds
# in pixel 236, 1414 all of the neighbors are clouds
# in pixel 236, 1414 all of the neighbors are clouds
# in pixel 236, 1414 all of the neighbors are clouds
# in pixel 236, 1414 all of the neighbors are clouds
# in pixel 119, 622 all of the neighbors are clouds
# in pixel 119, 622 all of the neighbors are clouds
# in pixel 119, 622 all of the neighbors are clouds
# in pixel 119, 622 all of the neighbors are clouds
# in pixel 119, 622 all of the neighbors are clouds
# in pixel 215, 891 all of the neighbors are clouds
# in pixel 215, 891 all of the neighbors are clouds
# in pixel 215, 891 all of the neighbors are clouds
# in pixel 215, 891 all of the neighbors are clouds
# in pixel 215, 891 all of the neighbors are clouds
# in pixel 174, 566 all of the neighbors are clouds
# in pixel 174, 566 all of the neighbors are clouds
# in pixel 174, 566 all of the neighbors are clouds
# in pixel 174, 566 all of the neighbors are clouds
# in pixel 174, 566 all of the neighbors are clouds
# in pixel 57, 584 all of the neighbors are clouds
# in pixel 57, 584 all of the neighbors are clouds
# in pixel 57, 584 all of the neighbors are clouds
# in pixel 57, 584 all of the neighbors are clouds
# in pixel 57, 584 all of the neighbors are clouds
# in pixel 459, 232 all of the neighbors are clouds
# in pixel 459, 232 all of the neighbors are clouds
# in pixel 459, 232 all of the neighbors are clouds
# in pixel 459, 232 all of the neighbors are clouds
# in pixel 459, 232 all of the neighbors are clouds
# in pixel 114, 650 all of the neighbors are clouds
# in pixel 114, 650 all of the neighbors are clouds
# in pixel 114, 650 all of the neighbors are clouds
# in pixel 114, 650 all of the neighbors are clouds
# in pixel 114, 650 all of the neighbors are clouds
# in pixel 242, 1321 all of the neighbors are clouds
# in pixel 242, 1321 all of the neighbors are clouds
# in pixel 242, 1321 all of the neighbors are clouds
# in pixel 242, 1321 all of the neighbors are clouds
# in pixel 242, 1321 all of the neighbors are clouds
# in pixel 216, 1388 all of the neighbors are clouds
# in pixel 216, 1388 all of the neighbors are clouds
# in pixel 216, 1388 all of the neighbors are clouds
# in pixel 216, 1388 all of the neighbors are clouds
# in pixel 216, 1388 all of the neighbors are clouds
# in pixel 255, 1352 all of the neighbors are clouds
# in pixel 255, 1352 all of the neighbors are clouds
# in pixel 255, 1352 all of the neighbors are clouds
# in pixel 255, 1352 all of the neighbors are clouds
# in pixel 255, 1352 all of the neighbors are clouds
# in pixel 220, 1657 all of the neighbors are clouds
# in pixel 220, 1657 all of the neighbors are clouds
# in pixel 220, 1657 all of the neighbors are clouds
# in pixel 220, 1657 all of the neighbors are clouds
# in pixel 220, 1657 all of the neighbors are clouds
# in pixel 202, 1623 all of the neighbors are clouds
# in pixel 202, 1623 all of the neighbors are clouds
# in pixel 202, 1623 all of the neighbors are clouds
# in pixel 202, 1623 all of the neighbors are clouds
# in pixel 202, 1623 all of the neighbors are clouds
# in pixel 102, 913 all of the neighbors are clouds
# in pixel 102, 913 all of the neighbors are clouds
# in pixel 102, 913 all of the neighbors are clouds
# in pixel 102, 913 all of the neighbors are clouds
# in pixel 102, 913 all of the neighbors are clouds
# in pixel 133, 994 all of the neighbors are clouds
# in pixel 133, 994 all of the neighbors are clouds
# in pixel 133, 994 all of the neighbors are clouds
# in pixel 133, 994 all of the neighbors are clouds
# in pixel 133, 994 all of the neighbors are clouds
# in pixel 457, 193 all of the neighbors are clouds
# in pixel 457, 193 all of the neighbors are clouds
# in pixel 457, 193 all of the neighbors are clouds
# in pixel 457, 193 all of the neighbors are clouds
# in pixel 457, 193 all of the neighbors are clouds
# in pixel 365, 1393 all of the neighbors are clouds
# in pixel 365, 1393 all of the neighbors are clouds
# in pixel 365, 1393 all of the neighbors are clouds
# in pixel 365, 1393 all of the neighbors are clouds
# in pixel 365, 1393 all of the neighbors are clouds
# in pixel 91, 573 all of the neighbors are clouds
# in pixel 91, 573 all of the neighbors are clouds
# in pixel 91, 573 all of the neighbors are clouds
# in pixel 91, 573 all of the neighbors are clouds
# in pixel 91, 573 all of the neighbors are clouds
# in pixel 270, 352 all of the neighbors are clouds
# in pixel 270, 352 all of the neighbors are clouds
# in pixel 270, 352 all of the neighbors are clouds
# in pixel 270, 352 all of the neighbors are clouds
# in pixel 270, 352 all of the neighbors are clouds
# in pixel 79, 945 all of the neighbors are clouds
# in pixel 79, 945 all of the neighbors are clouds
# in pixel 79, 945 all of the neighbors are clouds
# in pixel 79, 945 all of the neighbors are clouds
# in pixel 79, 945 all of the neighbors are clouds
# in pixel 147, 544 all of the neighbors are clouds
# in pixel 147, 544 all of the neighbors are clouds
# in pixel 147, 544 all of the neighbors are clouds
# in pixel 147, 544 all of the neighbors are clouds
# in pixel 147, 544 all of the neighbors are clouds
# in pixel 924, 1128 all of the neighbors are clouds
# in pixel 924, 1128 all of the neighbors are clouds
# in pixel 924, 1128 all of the neighbors are clouds
# in pixel 924, 1128 all of the neighbors are clouds
# in pixel 924, 1128 all of the neighbors are clouds
# in pixel 244, 1504 all of the neighbors are clouds
# in pixel 244, 1504 all of the neighbors are clouds
# in pixel 244, 1504 all of the neighbors are clouds
# in pixel 244, 1504 all of the neighbors are clouds
# in pixel 244, 1504 all of the neighbors are clouds
# in pixel 299, 1682 all of the neighbors are clouds
# in pixel 299, 1682 all of the neighbors are clouds
# in pixel 299, 1682 all of the neighbors are clouds
# in pixel 299, 1682 all of the neighbors are clouds
# in pixel 299, 1682 all of the neighbors are clouds
# in pixel 86, 453 all of the neighbors are clouds
# in pixel 86, 453 all of the neighbors are clouds
# in pixel 86, 453 all of the neighbors are clouds
# in pixel 86, 453 all of the neighbors are clouds
# in pixel 86, 453 all of the neighbors are clouds
# in pixel 100, 580 all of the neighbors are clouds
# in pixel 100, 580 all of the neighbors are clouds
# in pixel 100, 580 all of the neighbors are clouds
# in pixel 100, 580 all of the neighbors are clouds
# in pixel 100, 580 all of the neighbors are clouds
# in pixel 85, 995 all of the neighbors are clouds
# in pixel 85, 995 all of the neighbors are clouds
# in pixel 85, 995 all of the neighbors are clouds
# in pixel 85, 995 all of the neighbors are clouds
# in pixel 85, 995 all of the neighbors are clouds
# in pixel 548, 238 all of the neighbors are clouds
# in pixel 548, 238 all of the neighbors are clouds
# in pixel 548, 238 all of the neighbors are clouds
# in pixel 548, 238 all of the neighbors are clouds
# in pixel 548, 238 all of the neighbors are clouds
# in pixel 66, 409 all of the neighbors are clouds
# in pixel 66, 409 all of the neighbors are clouds
# in pixel 66, 409 all of the neighbors are clouds
# in pixel 66, 409 all of the neighbors are clouds
# in pixel 66, 409 all of the neighbors are clouds
# in pixel 189, 1300 all of the neighbors are clouds
# in pixel 189, 1300 all of the neighbors are clouds
# in pixel 189, 1300 all of the neighbors are clouds
# in pixel 189, 1300 all of the neighbors are clouds
# in pixel 189, 1300 all of the neighbors are clouds
# in pixel 77, 614 all of the neighbors are clouds
# in pixel 77, 614 all of the neighbors are clouds
# in pixel 77, 614 all of the neighbors are clouds
# in pixel 77, 614 all of the neighbors are clouds
# in pixel 77, 614 all of the neighbors are clouds
# in pixel 280, 591 all of the neighbors are clouds
# in pixel 280, 591 all of the neighbors are clouds
# in pixel 280, 591 all of the neighbors are clouds
# in pixel 280, 591 all of the neighbors are clouds
# in pixel 280, 591 all of the neighbors are clouds
# in pixel 216, 335 all of the neighbors are clouds
# in pixel 216, 335 all of the neighbors are clouds
# in pixel 216, 335 all of the neighbors are clouds
# in pixel 216, 335 all of the neighbors are clouds
# in pixel 216, 335 all of the neighbors are clouds
# in pixel 139, 617 all of the neighbors are clouds
# in pixel 139, 617 all of the neighbors are clouds
# in pixel 139, 617 all of the neighbors are clouds
# in pixel 139, 617 all of the neighbors are clouds
# in pixel 139, 617 all of the neighbors are clouds
# in pixel 365, 1495 all of the neighbors are clouds
# in pixel 365, 1495 all of the neighbors are clouds
# in pixel 365, 1495 all of the neighbors are clouds
# in pixel 365, 1495 all of the neighbors are clouds
# in pixel 365, 1495 all of the neighbors are clouds
# in pixel 227, 1156 all of the neighbors are clouds
# in pixel 227, 1156 all of the neighbors are clouds
# in pixel 227, 1156 all of the neighbors are clouds
# in pixel 227, 1156 all of the neighbors are clouds
# in pixel 227, 1156 all of the neighbors are clouds
# in pixel 328, 1249 all of the neighbors are clouds
# in pixel 328, 1249 all of the neighbors are clouds
# in pixel 328, 1249 all of the neighbors are clouds
# in pixel 328, 1249 all of the neighbors are clouds
# in pixel 328, 1249 all of the neighbors are clouds
# in pixel 198, 1180 all of the neighbors are clouds
# in pixel 198, 1180 all of the neighbors are clouds
# in pixel 198, 1180 all of the neighbors are clouds
# in pixel 198, 1180 all of the neighbors are clouds
# in pixel 198, 1180 all of the neighbors are clouds
# in pixel 270, 401 all of the neighbors are clouds
# in pixel 270, 401 all of the neighbors are clouds
# in pixel 270, 401 all of the neighbors are clouds
# in pixel 270, 401 all of the neighbors are clouds
# in pixel 270, 401 all of the neighbors are clouds
# in pixel 250, 1354 all of the neighbors are clouds
# in pixel 250, 1354 all of the neighbors are clouds
# in pixel 250, 1354 all of the neighbors are clouds
# in pixel 250, 1354 all of the neighbors are clouds
# in pixel 250, 1354 all of the neighbors are clouds
# in pixel 223, 1419 all of the neighbors are clouds
# in pixel 223, 1419 all of the neighbors are clouds
# in pixel 223, 1419 all of the neighbors are clouds
# in pixel 223, 1419 all of the neighbors are clouds
# in pixel 223, 1419 all of the neighbors are clouds
# in pixel 341, 1361 all of the neighbors are clouds
# in pixel 341, 1361 all of the neighbors are clouds
# in pixel 341, 1361 all of the neighbors are clouds
# in pixel 341, 1361 all of the neighbors are clouds
# in pixel 341, 1361 all of the neighbors are clouds
# in pixel 253, 1662 all of the neighbors are clouds
# in pixel 253, 1662 all of the neighbors are clouds
# in pixel 253, 1662 all of the neighbors are clouds
# in pixel 253, 1662 all of the neighbors are clouds
# in pixel 253, 1662 all of the neighbors are clouds
# in pixel 225, 545 all of the neighbors are clouds
# in pixel 225, 545 all of the neighbors are clouds
# in pixel 225, 545 all of the neighbors are clouds
# in pixel 225, 545 all of the neighbors are clouds
# in pixel 225, 545 all of the neighbors are clouds
# in pixel 177, 1488 all of the neighbors are clouds
# in pixel 177, 1488 all of the neighbors are clouds
# in pixel 177, 1488 all of the neighbors are clouds
# in pixel 177, 1488 all of the neighbors are clouds
# in pixel 177, 1488 all of the neighbors are clouds
# in pixel 165, 380 all of the neighbors are clouds
# in pixel 165, 380 all of the neighbors are clouds
# in pixel 165, 380 all of the neighbors are clouds
# in pixel 165, 380 all of the neighbors are clouds
# in pixel 165, 380 all of the neighbors are clouds
# in pixel 168, 676 all of the neighbors are clouds
# in pixel 168, 676 all of the neighbors are clouds
# in pixel 168, 676 all of the neighbors are clouds
# in pixel 168, 676 all of the neighbors are clouds
# in pixel 168, 676 all of the neighbors are clouds
# in pixel 289, 499 all of the neighbors are clouds
# in pixel 289, 499 all of the neighbors are clouds
# in pixel 289, 499 all of the neighbors are clouds
# in pixel 289, 499 all of the neighbors are clouds
# in pixel 289, 499 all of the neighbors are clouds
# in pixel 336, 1359 all of the neighbors are clouds
# in pixel 336, 1359 all of the neighbors are clouds
# in pixel 336, 1359 all of the neighbors are clouds
# in pixel 336, 1359 all of the neighbors are clouds
# in pixel 336, 1359 all of the neighbors are clouds
# in pixel 284, 468 all of the neighbors are clouds
# in pixel 284, 468 all of the neighbors are clouds
# in pixel 284, 468 all of the neighbors are clouds
# in pixel 284, 468 all of the neighbors are clouds
# in pixel 284, 468 all of the neighbors are clouds
# in pixel 178, 1429 all of the neighbors are clouds
# in pixel 178, 1429 all of the neighbors are clouds
# in pixel 178, 1429 all of the neighbors are clouds
# in pixel 178, 1429 all of the neighbors are clouds
# in pixel 178, 1429 all of the neighbors are clouds
# in pixel 139, 1347 all of the neighbors are clouds
# in pixel 139, 1347 all of the neighbors are clouds
# in pixel 139, 1347 all of the neighbors are clouds
# in pixel 139, 1347 all of the neighbors are clouds
# in pixel 139, 1347 all of the neighbors are clouds
# in pixel 241, 293 all of the neighbors are clouds
# in pixel 241, 293 all of the neighbors are clouds
# in pixel 241, 293 all of the neighbors are clouds
# in pixel 241, 293 all of the neighbors are clouds
# in pixel 241, 293 all of the neighbors are clouds
# in pixel 106, 390 all of the neighbors are clouds
# in pixel 106, 390 all of the neighbors are clouds
# in pixel 106, 390 all of the neighbors are clouds
# in pixel 106, 390 all of the neighbors are clouds
# in pixel 106, 390 all of the neighbors are clouds
# in pixel 163, 620 all of the neighbors are clouds
# in pixel 163, 620 all of the neighbors are clouds
# in pixel 163, 620 all of the neighbors are clouds
# in pixel 163, 620 all of the neighbors are clouds
# in pixel 163, 620 all of the neighbors are clouds
# in pixel 663, 587 all of the neighbors are clouds
# in pixel 663, 587 all of the neighbors are clouds
# in pixel 663, 587 all of the neighbors are clouds
# in pixel 663, 587 all of the neighbors are clouds
# in pixel 663, 587 all of the neighbors are clouds
# in pixel 237, 728 all of the neighbors are clouds
# in pixel 237, 728 all of the neighbors are clouds
# in pixel 237, 728 all of the neighbors are clouds
# in pixel 237, 728 all of the neighbors are clouds
# in pixel 237, 728 all of the neighbors are clouds
# in pixel 381, 232 all of the neighbors are clouds
# in pixel 381, 232 all of the neighbors are clouds
# in pixel 381, 232 all of the neighbors are clouds
# in pixel 381, 232 all of the neighbors are clouds
# in pixel 381, 232 all of the neighbors are clouds
# in pixel 216, 386 all of the neighbors are clouds
# in pixel 216, 386 all of the neighbors are clouds
# in pixel 216, 386 all of the neighbors are clouds
# in pixel 216, 386 all of the neighbors are clouds
# in pixel 216, 386 all of the neighbors are clouds
# in pixel 348, 1659 all of the neighbors are clouds
# in pixel 348, 1659 all of the neighbors are clouds
# in pixel 348, 1659 all of the neighbors are clouds
# in pixel 348, 1659 all of the neighbors are clouds
# in pixel 348, 1659 all of the neighbors are clouds
# in pixel 249, 1265 all of the neighbors are clouds
# in pixel 249, 1265 all of the neighbors are clouds
# in pixel 249, 1265 all of the neighbors are clouds
# in pixel 249, 1265 all of the neighbors are clouds
# in pixel 249, 1265 all of the neighbors are clouds
# in pixel 596, 501 all of the neighbors are clouds
# in pixel 596, 501 all of the neighbors are clouds
# in pixel 596, 501 all of the neighbors are clouds
# in pixel 596, 501 all of the neighbors are clouds
# in pixel 596, 501 all of the neighbors are clouds
# in pixel 240, 986 all of the neighbors are clouds
# in pixel 240, 986 all of the neighbors are clouds
# in pixel 240, 986 all of the neighbors are clouds
# in pixel 240, 986 all of the neighbors are clouds
# in pixel 240, 986 all of the neighbors are clouds
# in pixel 214, 753 all of the neighbors are clouds
# in pixel 214, 753 all of the neighbors are clouds
# in pixel 214, 753 all of the neighbors are clouds
# in pixel 214, 753 all of the neighbors are clouds
# in pixel 214, 753 all of the neighbors are clouds
# in pixel 79, 832 all of the neighbors are clouds
# in pixel 79, 832 all of the neighbors are clouds
# in pixel 79, 832 all of the neighbors are clouds
# in pixel 79, 832 all of the neighbors are clouds
# in pixel 79, 832 all of the neighbors are clouds
# in pixel 159, 1263 all of the neighbors are clouds
# in pixel 159, 1263 all of the neighbors are clouds
# in pixel 159, 1263 all of the neighbors are clouds
# in pixel 159, 1263 all of the neighbors are clouds
# in pixel 159, 1263 all of the neighbors are clouds
# in pixel 93, 940 all of the neighbors are clouds
# in pixel 93, 940 all of the neighbors are clouds
# in pixel 93, 940 all of the neighbors are clouds
# in pixel 93, 940 all of the neighbors are clouds
# in pixel 93, 940 all of the neighbors are clouds
# in pixel 250, 591 all of the neighbors are clouds
# in pixel 250, 591 all of the neighbors are clouds
# in pixel 250, 591 all of the neighbors are clouds
# in pixel 250, 591 all of the neighbors are clouds
# in pixel 250, 591 all of the neighbors are clouds
# in pixel 716, 619 all of the neighbors are clouds
# in pixel 716, 619 all of the neighbors are clouds
# in pixel 716, 619 all of the neighbors are clouds
# in pixel 716, 619 all of the neighbors are clouds
# in pixel 716, 619 all of the neighbors are clouds
# in pixel 387, 218 all of the neighbors are clouds
# in pixel 387, 218 all of the neighbors are clouds
# in pixel 387, 218 all of the neighbors are clouds
# in pixel 387, 218 all of the neighbors are clouds
# in pixel 387, 218 all of the neighbors are clouds
# in pixel 499, 187 all of the neighbors are clouds
# in pixel 499, 187 all of the neighbors are clouds
# in pixel 499, 187 all of the neighbors are clouds
# in pixel 499, 187 all of the neighbors are clouds
# in pixel 499, 187 all of the neighbors are clouds
# in pixel 151, 1102 all of the neighbors are clouds
# in pixel 151, 1102 all of the neighbors are clouds
# in pixel 151, 1102 all of the neighbors are clouds
# in pixel 151, 1102 all of the neighbors are clouds
# in pixel 151, 1102 all of the neighbors are clouds
# in pixel 471, 735 all of the neighbors are clouds
# in pixel 471, 735 all of the neighbors are clouds
# in pixel 471, 735 all of the neighbors are clouds
# in pixel 471, 735 all of the neighbors are clouds
# in pixel 471, 735 all of the neighbors are clouds
# in pixel 128, 612 all of the neighbors are clouds
# in pixel 128, 612 all of the neighbors are clouds
# in pixel 128, 612 all of the neighbors are clouds
# in pixel 128, 612 all of the neighbors are clouds
# in pixel 128, 612 all of the neighbors are clouds
# in pixel 235, 591 all of the neighbors are clouds
# in pixel 235, 591 all of the neighbors are clouds
# in pixel 235, 591 all of the neighbors are clouds
# in pixel 235, 591 all of the neighbors are clouds
# in pixel 235, 591 all of the neighbors are clouds
# in pixel 139, 356 all of the neighbors are clouds
# in pixel 139, 356 all of the neighbors are clouds
# in pixel 139, 356 all of the neighbors are clouds
# in pixel 139, 356 all of the neighbors are clouds
# in pixel 139, 356 all of the neighbors are clouds
# in pixel 371, 319 all of the neighbors are clouds
# in pixel 371, 319 all of the neighbors are clouds
# in pixel 371, 319 all of the neighbors are clouds
# in pixel 371, 319 all of the neighbors are clouds
# in pixel 371, 319 all of the neighbors are clouds
# in pixel 53, 611 all of the neighbors are clouds
# in pixel 53, 611 all of the neighbors are clouds
# in pixel 53, 611 all of the neighbors are clouds
# in pixel 53, 611 all of the neighbors are clouds
# in pixel 53, 611 all of the neighbors are clouds
# in pixel 281, 1624 all of the neighbors are clouds
# in pixel 281, 1624 all of the neighbors are clouds
# in pixel 281, 1624 all of the neighbors are clouds
# in pixel 281, 1624 all of the neighbors are clouds
# in pixel 281, 1624 all of the neighbors are clouds
# in pixel 195, 620 all of the neighbors are clouds
# in pixel 195, 620 all of the neighbors are clouds
# in pixel 195, 620 all of the neighbors are clouds
# in pixel 195, 620 all of the neighbors are clouds
# in pixel 195, 620 all of the neighbors are clouds
# in pixel 293, 309 all of the neighbors are clouds
# in pixel 293, 309 all of the neighbors are clouds
# in pixel 293, 309 all of the neighbors are clouds
# in pixel 293, 309 all of the neighbors are clouds
# in pixel 293, 309 all of the neighbors are clouds
# in pixel 404, 1436 all of the neighbors are clouds
# in pixel 404, 1436 all of the neighbors are clouds
# in pixel 404, 1436 all of the neighbors are clouds
# in pixel 404, 1436 all of the neighbors are clouds
# in pixel 404, 1436 all of the neighbors are clouds
# in pixel 49, 579 all of the neighbors are clouds
# in pixel 49, 579 all of the neighbors are clouds
# in pixel 49, 579 all of the neighbors are clouds
# in pixel 49, 579 all of the neighbors are clouds
# in pixel 49, 579 all of the neighbors are clouds
# in pixel 153, 726 all of the neighbors are clouds
# in pixel 153, 726 all of the neighbors are clouds
# in pixel 153, 726 all of the neighbors are clouds
# in pixel 153, 726 all of the neighbors are clouds
# in pixel 153, 726 all of the neighbors are clouds
# in pixel 116, 626 all of the neighbors are clouds
# in pixel 116, 626 all of the neighbors are clouds
# in pixel 116, 626 all of the neighbors are clouds
# in pixel 116, 626 all of the neighbors are clouds
# in pixel 116, 626 all of the neighbors are clouds
# in pixel 248, 508 all of the neighbors are clouds
# in pixel 248, 508 all of the neighbors are clouds
# in pixel 248, 508 all of the neighbors are clouds
# in pixel 248, 508 all of the neighbors are clouds
# in pixel 248, 508 all of the neighbors are clouds
# in pixel 238, 753 all of the neighbors are clouds
# in pixel 238, 753 all of the neighbors are clouds
# in pixel 238, 753 all of the neighbors are clouds
# in pixel 238, 753 all of the neighbors are clouds
# in pixel 238, 753 all of the neighbors are clouds
# in pixel 100, 1062 all of the neighbors are clouds
# in pixel 100, 1062 all of the neighbors are clouds
# in pixel 100, 1062 all of the neighbors are clouds
# in pixel 100, 1062 all of the neighbors are clouds
# in pixel 100, 1062 all of the neighbors are clouds
# in pixel 87, 413 all of the neighbors are clouds
# in pixel 87, 413 all of the neighbors are clouds
# in pixel 87, 413 all of the neighbors are clouds
# in pixel 87, 413 all of the neighbors are clouds
# in pixel 87, 413 all of the neighbors are clouds
# in pixel 223, 1450 all of the neighbors are clouds
# in pixel 223, 1450 all of the neighbors are clouds
# in pixel 223, 1450 all of the neighbors are clouds
# in pixel 223, 1450 all of the neighbors are clouds
# in pixel 223, 1450 all of the neighbors are clouds
# in pixel 154, 960 all of the neighbors are clouds
# in pixel 154, 960 all of the neighbors are clouds
# in pixel 154, 960 all of the neighbors are clouds
# in pixel 154, 960 all of the neighbors are clouds
# in pixel 154, 960 all of the neighbors are clouds
# in pixel 222, 1199 all of the neighbors are clouds
# in pixel 222, 1199 all of the neighbors are clouds
# in pixel 222, 1199 all of the neighbors are clouds
# in pixel 222, 1199 all of the neighbors are clouds
# in pixel 222, 1199 all of the neighbors are clouds
# in pixel 81, 512 all of the neighbors are clouds
# in pixel 81, 512 all of the neighbors are clouds
# in pixel 81, 512 all of the neighbors are clouds
# in pixel 81, 512 all of the neighbors are clouds
# in pixel 81, 512 all of the neighbors are clouds
# in pixel 121, 1193 all of the neighbors are clouds
# in pixel 121, 1193 all of the neighbors are clouds
# in pixel 121, 1193 all of the neighbors are clouds
# in pixel 121, 1193 all of the neighbors are clouds
# in pixel 121, 1193 all of the neighbors are clouds
# in pixel 104, 838 all of the neighbors are clouds
# in pixel 104, 838 all of the neighbors are clouds
# in pixel 104, 838 all of the neighbors are clouds
# in pixel 104, 838 all of the neighbors are clouds
# in pixel 104, 838 all of the neighbors are clouds
# in pixel 212, 345 all of the neighbors are clouds
# in pixel 212, 345 all of the neighbors are clouds
# in pixel 212, 345 all of the neighbors are clouds
# in pixel 212, 345 all of the neighbors are clouds
# in pixel 212, 345 all of the neighbors are clouds
# in pixel 297, 253 all of the neighbors are clouds
# in pixel 297, 253 all of the neighbors are clouds
# in pixel 297, 253 all of the neighbors are clouds
# in pixel 297, 253 all of the neighbors are clouds
# in pixel 297, 253 all of the neighbors are clouds
# in pixel 225, 590 all of the neighbors are clouds
# in pixel 225, 590 all of the neighbors are clouds
# in pixel 225, 590 all of the neighbors are clouds
# in pixel 225, 590 all of the neighbors are clouds
# in pixel 225, 590 all of the neighbors are clouds
# in pixel 211, 1577 all of the neighbors are clouds
# in pixel 211, 1577 all of the neighbors are clouds
# in pixel 211, 1577 all of the neighbors are clouds
# in pixel 211, 1577 all of the neighbors are clouds
# in pixel 211, 1577 all of the neighbors are clouds
# in pixel 196, 1117 all of the neighbors are clouds
# in pixel 196, 1117 all of the neighbors are clouds
# in pixel 196, 1117 all of the neighbors are clouds
# in pixel 196, 1117 all of the neighbors are clouds
# in pixel 196, 1117 all of the neighbors are clouds
# in pixel 93, 623 all of the neighbors are clouds
# in pixel 93, 623 all of the neighbors are clouds
# in pixel 93, 623 all of the neighbors are clouds
# in pixel 93, 623 all of the neighbors are clouds
# in pixel 93, 623 all of the neighbors are clouds
# in pixel 290, 1512 all of the neighbors are clouds
# in pixel 290, 1512 all of the neighbors are clouds
# in pixel 290, 1512 all of the neighbors are clouds
# in pixel 290, 1512 all of the neighbors are clouds
# in pixel 290, 1512 all of the neighbors are clouds
# in pixel 285, 1667 all of the neighbors are clouds
# in pixel 285, 1667 all of the neighbors are clouds
# in pixel 285, 1667 all of the neighbors are clouds
# in pixel 285, 1667 all of the neighbors are clouds
# in pixel 285, 1667 all of the neighbors are clouds
# in pixel 448, 186 all of the neighbors are clouds
# in pixel 448, 186 all of the neighbors are clouds
# in pixel 448, 186 all of the neighbors are clouds
# in pixel 448, 186 all of the neighbors are clouds
# in pixel 448, 186 all of the neighbors are clouds
# in pixel 246, 766 all of the neighbors are clouds
# in pixel 246, 766 all of the neighbors are clouds
# in pixel 246, 766 all of the neighbors are clouds
# in pixel 246, 766 all of the neighbors are clouds
# in pixel 246, 766 all of the neighbors are clouds
# in pixel 351, 1161 all of the neighbors are clouds
# in pixel 351, 1161 all of the neighbors are clouds
# in pixel 351, 1161 all of the neighbors are clouds
# in pixel 351, 1161 all of the neighbors are clouds
# in pixel 351, 1161 all of the neighbors are clouds
# in pixel 100, 686 all of the neighbors are clouds
# in pixel 100, 686 all of the neighbors are clouds
# in pixel 100, 686 all of the neighbors are clouds
# in pixel 100, 686 all of the neighbors are clouds
# in pixel 100, 686 all of the neighbors are clouds
# in pixel 352, 325 all of the neighbors are clouds
# in pixel 352, 325 all of the neighbors are clouds
# in pixel 352, 325 all of the neighbors are clouds
# in pixel 352, 325 all of the neighbors are clouds
# in pixel 352, 325 all of the neighbors are clouds
# in pixel 219, 1518 all of the neighbors are clouds
# in pixel 219, 1518 all of the neighbors are clouds
# in pixel 219, 1518 all of the neighbors are clouds
# in pixel 219, 1518 all of the neighbors are clouds
# in pixel 219, 1518 all of the neighbors are clouds
# in pixel 142, 562 all of the neighbors are clouds
# in pixel 142, 562 all of the neighbors are clouds
# in pixel 142, 562 all of the neighbors are clouds
# in pixel 142, 562 all of the neighbors are clouds
# in pixel 142, 562 all of the neighbors are clouds
# in pixel 201, 1058 all of the neighbors are clouds
# in pixel 201, 1058 all of the neighbors are clouds
# in pixel 201, 1058 all of the neighbors are clouds
# in pixel 201, 1058 all of the neighbors are clouds
# in pixel 201, 1058 all of the neighbors are clouds
# in pixel 215, 1471 all of the neighbors are clouds
# in pixel 215, 1471 all of the neighbors are clouds
# in pixel 215, 1471 all of the neighbors are clouds
# in pixel 215, 1471 all of the neighbors are clouds
# in pixel 215, 1471 all of the neighbors are clouds
# in pixel 221, 1033 all of the neighbors are clouds
# in pixel 221, 1033 all of the neighbors are clouds
# in pixel 221, 1033 all of the neighbors are clouds
# in pixel 221, 1033 all of the neighbors are clouds
# in pixel 221, 1033 all of the neighbors are clouds
# in pixel 333, 1656 all of the neighbors are clouds
# in pixel 333, 1656 all of the neighbors are clouds
# in pixel 333, 1656 all of the neighbors are clouds
# in pixel 333, 1656 all of the neighbors are clouds
# in pixel 333, 1656 all of the neighbors are clouds
# in pixel 329, 1588 all of the neighbors are clouds
# in pixel 329, 1588 all of the neighbors are clouds
# in pixel 329, 1588 all of the neighbors are clouds
# in pixel 329, 1588 all of the neighbors are clouds
# in pixel 329, 1588 all of the neighbors are clouds
# in pixel 255, 334 all of the neighbors are clouds
# in pixel 255, 334 all of the neighbors are clouds
# in pixel 255, 334 all of the neighbors are clouds
# in pixel 255, 334 all of the neighbors are clouds
# in pixel 255, 334 all of the neighbors are clouds
# in pixel 164, 624 all of the neighbors are clouds
# in pixel 164, 624 all of the neighbors are clouds
# in pixel 164, 624 all of the neighbors are clouds
# in pixel 164, 624 all of the neighbors are clouds
# in pixel 164, 624 all of the neighbors are clouds
# in pixel 158, 616 all of the neighbors are clouds
# in pixel 158, 616 all of the neighbors are clouds
# in pixel 158, 616 all of the neighbors are clouds
# in pixel 158, 616 all of the neighbors are clouds
# in pixel 158, 616 all of the neighbors are clouds
# in pixel 788, 1123 all of the neighbors are clouds
# in pixel 788, 1123 all of the neighbors are clouds
# in pixel 788, 1123 all of the neighbors are clouds
# in pixel 788, 1123 all of the neighbors are clouds
# in pixel 788, 1123 all of the neighbors are clouds
# in pixel 131, 897 all of the neighbors are clouds
# in pixel 131, 897 all of the neighbors are clouds
# in pixel 131, 897 all of the neighbors are clouds
# in pixel 131, 897 all of the neighbors are clouds
# in pixel 131, 897 all of the neighbors are clouds
# in pixel 207, 1510 all of the neighbors are clouds
# in pixel 207, 1510 all of the neighbors are clouds
# in pixel 207, 1510 all of the neighbors are clouds
# in pixel 207, 1510 all of the neighbors are clouds
# in pixel 207, 1510 all of the neighbors are clouds
# in pixel 504, 257 all of the neighbors are clouds
# in pixel 504, 257 all of the neighbors are clouds
# in pixel 504, 257 all of the neighbors are clouds
# in pixel 504, 257 all of the neighbors are clouds
# in pixel 504, 257 all of the neighbors are clouds
# in pixel 165, 1018 all of the neighbors are clouds
# in pixel 165, 1018 all of the neighbors are clouds
# in pixel 165, 1018 all of the neighbors are clouds
# in pixel 165, 1018 all of the neighbors are clouds
# in pixel 165, 1018 all of the neighbors are clouds
# in pixel 47, 667 all of the neighbors are clouds
# in pixel 47, 667 all of the neighbors are clouds
# in pixel 47, 667 all of the neighbors are clouds
# in pixel 47, 667 all of the neighbors are clouds
# in pixel 47, 667 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 286, 1474 all of the neighbors are clouds
# in pixel 286, 1474 all of the neighbors are clouds
# in pixel 286, 1474 all of the neighbors are clouds
# in pixel 286, 1474 all of the neighbors are clouds
# in pixel 286, 1474 all of the neighbors are clouds
# in pixel 156, 833 all of the neighbors are clouds
# in pixel 156, 833 all of the neighbors are clouds
# in pixel 156, 833 all of the neighbors are clouds
# in pixel 156, 833 all of the neighbors are clouds
# in pixel 156, 833 all of the neighbors are clouds
# in pixel 239, 395 all of the neighbors are clouds
# in pixel 239, 395 all of the neighbors are clouds
# in pixel 239, 395 all of the neighbors are clouds
# in pixel 239, 395 all of the neighbors are clouds
# ...
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 281, 1676 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 178, 849 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 284, 1423 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 110, 696 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 83, 950 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 129, 752 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 84, 750 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 359, 1364 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 315, 1663 all of the neighbors are clouds
# in pixel 156, 833 all of the neighbors are clouds
# in pixel 156, 833 all of the neighbors are clouds
# in pixel 156, 833 all of the neighbors are clouds
# in pixel 156, 833 all of the neighbors are clouds
# in pixel 156, 833 all of the neighbors are clouds
# in pixel 239, 395 all of the neighbors are clouds
# in pixel 239, 395 all of the neighbors are clouds
# in pixel 239, 395 all of the neighbors are clouds
# in pixel 239, 395 all of the neighbors are clouds
# in pixel 239, 395 all of the neighbors are clouds
# in pixel 231, 717 all of the neighbors are clouds
# in pixel 231, 717 all of the neighbors are clouds
# in pixel 231, 717 all of the neighbors are clouds
# in pixel 231, 717 all of the neighbors are clouds
# in pixel 231, 717 all of the neighbors are clouds
# in pixel 336, 421 all of the neighbors are clouds
# in pixel 336, 421 all of the neighbors are clouds
# in pixel 336, 421 all of the neighbors are clouds
# in pixel 336, 421 all of the neighbors are clouds
# in pixel 336, 421 all of the neighbors are clouds
# in pixel 110, 532 all of the neighbors are clouds
# in pixel 110, 532 all of the neighbors are clouds
# in pixel 110, 532 all of the neighbors are clouds
# in pixel 110, 532 all of the neighbors are clouds
# in pixel 110, 532 all of the neighbors are clouds
# in pixel 250, 704 all of the neighbors are clouds
# in pixel 250, 704 all of the neighbors are clouds
# in pixel 250, 704 all of the neighbors are clouds
# in pixel 250, 704 all of the neighbors are clouds
# in pixel 250, 704 all of the neighbors are clouds
# in pixel 100, 437 all of the neighbors are clouds
# in pixel 100, 437 all of the neighbors are clouds
# in pixel 100, 437 all of the neighbors are clouds
# in pixel 100, 437 all of the neighbors are clouds
# in pixel 100, 437 all of the neighbors are clouds
# in pixel 235, 385 all of the neighbors are clouds
# in pixel 235, 385 all of the neighbors are clouds
# in pixel 235, 385 all of the neighbors are clouds
# in pixel 235, 385 all of the neighbors are clouds
# in pixel 235, 385 all of the neighbors are clouds
# in pixel 192, 761 all of the neighbors are clouds
# in pixel 192, 761 all of the neighbors are clouds
# in pixel 192, 761 all of the neighbors are clouds
# in pixel 192, 761 all of the neighbors are clouds
# in pixel 192, 761 all of the neighbors are clouds
# in pixel 180, 627 all of the neighbors are clouds
# in pixel 180, 627 all of the neighbors are clouds
# in pixel 180, 627 all of the neighbors are clouds
# in pixel 180, 627 all of the neighbors are clouds
# in pixel 180, 627 all of the neighbors are clouds
# in pixel 230, 1481 all of the neighbors are clouds
# in pixel 230, 1481 all of the neighbors are clouds
# in pixel 230, 1481 all of the neighbors are clouds
# in pixel 230, 1481 all of the neighbors are clouds
# in pixel 230, 1481 all of the neighbors are clouds
# in pixel 295, 1600 all of the neighbors are clouds
# in pixel 295, 1600 all of the neighbors are clouds
# in pixel 295, 1600 all of the neighbors are clouds
# in pixel 295, 1600 all of the neighbors are clouds
# in pixel 295, 1600 all of the neighbors are clouds
# in pixel 302, 401 all of the neighbors are clouds
# in pixel 302, 401 all of the neighbors are clouds
# in pixel 302, 401 all of the neighbors are clouds
# in pixel 302, 401 all of the neighbors are clouds
# in pixel 302, 401 all of the neighbors are clouds
# in pixel 1027, 1252 all of the neighbors are clouds
# in pixel 1027, 1252 all of the neighbors are clouds
# in pixel 1027, 1252 all of the neighbors are clouds
# in pixel 1027, 1252 all of the neighbors are clouds
# in pixel 1027, 1252 all of the neighbors are clouds
# in pixel 382, 1577 all of the neighbors are clouds
# in pixel 382, 1577 all of the neighbors are clouds
# in pixel 382, 1577 all of the neighbors are clouds
# in pixel 382, 1577 all of the neighbors are clouds
# in pixel 382, 1577 all of the neighbors are clouds
# in pixel 159, 1534 all of the neighbors are clouds
# in pixel 159, 1534 all of the neighbors are clouds
# in pixel 159, 1534 all of the neighbors are clouds
# in pixel 159, 1534 all of the neighbors are clouds
# in pixel 159, 1534 all of the neighbors are clouds
# in pixel 161, 897 all of the neighbors are clouds
# in pixel 161, 897 all of the neighbors are clouds
# in pixel 161, 897 all of the neighbors are clouds
# in pixel 161, 897 all of the neighbors are clouds
# in pixel 161, 897 all of the neighbors are clouds
# in pixel 340, 1398 all of the neighbors are clouds
# in pixel 340, 1398 all of the neighbors are clouds
# in pixel 340, 1398 all of the neighbors are clouds
# in pixel 340, 1398 all of the neighbors are clouds
# in pixel 340, 1398 all of the neighbors are clouds
# in pixel 126, 1153 all of the neighbors are clouds
# in pixel 126, 1153 all of the neighbors are clouds
# in pixel 126, 1153 all of the neighbors are clouds
# in pixel 126, 1153 all of the neighbors are clouds
# in pixel 126, 1153 all of the neighbors are clouds
# in pixel 60, 515 all of the neighbors are clouds
# in pixel 60, 515 all of the neighbors are clouds
# in pixel 60, 515 all of the neighbors are clouds
# in pixel 60, 515 all of the neighbors are clouds
# in pixel 60, 515 all of the neighbors are clouds
# in pixel 132, 969 all of the neighbors are clouds
# in pixel 132, 969 all of the neighbors are clouds
# in pixel 132, 969 all of the neighbors are clouds
# in pixel 132, 969 all of the neighbors are clouds
# in pixel 132, 969 all of the neighbors are clouds
# in pixel 363, 1639 all of the neighbors are clouds
# in pixel 363, 1639 all of the neighbors are clouds
# in pixel 363, 1639 all of the neighbors are clouds
# in pixel 363, 1639 all of the neighbors are clouds
# in pixel 363, 1639 all of the neighbors are clouds
# in pixel 280, 307 all of the neighbors are clouds
# in pixel 280, 307 all of the neighbors are clouds
# in pixel 280, 307 all of the neighbors are clouds
# in pixel 280, 307 all of the neighbors are clouds
# in pixel 280, 307 all of the neighbors are clouds
# in pixel 144, 1441 all of the neighbors are clouds
# in pixel 144, 1441 all of the neighbors are clouds
# in pixel 144, 1441 all of the neighbors are clouds
# in pixel 144, 1441 all of the neighbors are clouds
# in pixel 144, 1441 all of the neighbors are clouds
# in pixel 138, 373 all of the neighbors are clouds
# in pixel 138, 373 all of the neighbors are clouds
# in pixel 138, 373 all of the neighbors are clouds
# in pixel 138, 373 all of the neighbors are clouds
# in pixel 138, 373 all of the neighbors are clouds
# in pixel 184, 425 all of the neighbors are clouds
# in pixel 184, 425 all of the neighbors are clouds
# in pixel 184, 425 all of the neighbors are clouds
# in pixel 184, 425 all of the neighbors are clouds
# in pixel 184, 425 all of the neighbors are clouds
# in pixel 88, 405 all of the neighbors are clouds
# in pixel 88, 405 all of the neighbors are clouds
# in pixel 88, 405 all of the neighbors are clouds
# in pixel 88, 405 all of the neighbors are clouds
# in pixel 88, 405 all of the neighbors are clouds
# in pixel 378, 1058 all of the neighbors are clouds
# in pixel 378, 1058 all of the neighbors are clouds
# in pixel 378, 1058 all of the neighbors are clouds
# in pixel 378, 1058 all of the neighbors are clouds
# in pixel 378, 1058 all of the neighbors are clouds
# in pixel 234, 1560 all of the neighbors are clouds
# in pixel 234, 1560 all of the neighbors are clouds
# in pixel 234, 1560 all of the neighbors are clouds
# in pixel 234, 1560 all of the neighbors are clouds
# in pixel 234, 1560 all of the neighbors are clouds
# in pixel 795, 279 all of the neighbors are clouds
# in pixel 795, 279 all of the neighbors are clouds
# in pixel 795, 279 all of the neighbors are clouds
# in pixel 795, 279 all of the neighbors are clouds
# in pixel 795, 279 all of the neighbors are clouds
# in pixel 224, 331 all of the neighbors are clouds
# in pixel 224, 331 all of the neighbors are clouds
# in pixel 224, 331 all of the neighbors are clouds
# in pixel 224, 331 all of the neighbors are clouds
# in pixel 224, 331 all of the neighbors are clouds
# in pixel 269, 1442 all of the neighbors are clouds
# in pixel 269, 1442 all of the neighbors are clouds
# in pixel 269, 1442 all of the neighbors are clouds
# in pixel 269, 1442 all of the neighbors are clouds
# in pixel 269, 1442 all of the neighbors are clouds
# in pixel 51, 750 all of the neighbors are clouds
# in pixel 51, 750 all of the neighbors are clouds
# in pixel 51, 750 all of the neighbors are clouds
# in pixel 51, 750 all of the neighbors are clouds
# in pixel 51, 750 all of the neighbors are clouds
# in pixel 246, 652 all of the neighbors are clouds
# in pixel 246, 652 all of the neighbors are clouds
# in pixel 246, 652 all of the neighbors are clouds
# in pixel 246, 652 all of the neighbors are clouds
# in pixel 246, 652 all of the neighbors are clouds
# in pixel 419, 272 all of the neighbors are clouds
# in pixel 419, 272 all of the neighbors are clouds
# in pixel 419, 272 all of the neighbors are clouds
# in pixel 419, 272 all of the neighbors are clouds
# in pixel 419, 272 all of the neighbors are clouds
# in pixel 140, 902 all of the neighbors are clouds
# in pixel 140, 902 all of the neighbors are clouds
# in pixel 140, 902 all of the neighbors are clouds
# in pixel 140, 902 all of the neighbors are clouds
# in pixel 140, 902 all of the neighbors are clouds
# in pixel 137, 1242 all of the neighbors are clouds
# in pixel 137, 1242 all of the neighbors are clouds
# in pixel 137, 1242 all of the neighbors are clouds
# in pixel 137, 1242 all of the neighbors are clouds
# in pixel 137, 1242 all of the neighbors are clouds
# in pixel 295, 1201 all of the neighbors are clouds
# in pixel 295, 1201 all of the neighbors are clouds
# in pixel 295, 1201 all of the neighbors are clouds
# in pixel 295, 1201 all of the neighbors are clouds
# in pixel 295, 1201 all of the neighbors are clouds
# in pixel 268, 754 all of the neighbors are clouds
# in pixel 268, 754 all of the neighbors are clouds
# in pixel 268, 754 all of the neighbors are clouds
# in pixel 268, 754 all of the neighbors are clouds
# in pixel 268, 754 all of the neighbors are clouds
# in pixel 149, 949 all of the neighbors are clouds
# in pixel 149, 949 all of the neighbors are clouds
# in pixel 149, 949 all of the neighbors are clouds
# in pixel 149, 949 all of the neighbors are clouds
# in pixel 149, 949 all of the neighbors are clouds
# in pixel 137, 941 all of the neighbors are clouds
# in pixel 137, 941 all of the neighbors are clouds
# in pixel 137, 941 all of the neighbors are clouds
# in pixel 137, 941 all of the neighbors are clouds
# in pixel 137, 941 all of the neighbors are clouds
# in pixel 284, 328 all of the neighbors are clouds
# in pixel 284, 328 all of the neighbors are clouds
# in pixel 284, 328 all of the neighbors are clouds
# in pixel 284, 328 all of the neighbors are clouds
# in pixel 284, 328 all of the neighbors are clouds
# in pixel 368, 262 all of the neighbors are clouds
# in pixel 368, 262 all of the neighbors are clouds
# in pixel 368, 262 all of the neighbors are clouds
# in pixel 368, 262 all of the neighbors are clouds
# in pixel 368, 262 all of the neighbors are clouds
# in pixel 374, 1452 all of the neighbors are clouds
# in pixel 374, 1452 all of the neighbors are clouds
# in pixel 374, 1452 all of the neighbors are clouds
# in pixel 374, 1452 all of the neighbors are clouds
# in pixel 374, 1452 all of the neighbors are clouds
# in pixel 310, 365 all of the neighbors are clouds
# in pixel 310, 365 all of the neighbors are clouds
# in pixel 310, 365 all of the neighbors are clouds
# in pixel 310, 365 all of the neighbors are clouds
# in pixel 310, 365 all of the neighbors are clouds
# in pixel 208, 1146 all of the neighbors are clouds
# in pixel 208, 1146 all of the neighbors are clouds
# in pixel 208, 1146 all of the neighbors are clouds
# in pixel 208, 1146 all of the neighbors are clouds
# in pixel 208, 1146 all of the neighbors are clouds
# in pixel 207, 576 all of the neighbors are clouds
# in pixel 207, 576 all of the neighbors are clouds
# in pixel 207, 576 all of the neighbors are clouds
# in pixel 207, 576 all of the neighbors are clouds
# in pixel 207, 576 all of the neighbors are clouds
# in pixel 293, 495 all of the neighbors are clouds
# in pixel 293, 495 all of the neighbors are clouds
# in pixel 293, 495 all of the neighbors are clouds
# in pixel 293, 495 all of the neighbors are clouds
# in pixel 293, 495 all of the neighbors are clouds
# in pixel 320, 1677 all of the neighbors are clouds
# in pixel 320, 1677 all of the neighbors are clouds
# in pixel 320, 1677 all of the neighbors are clouds
# in pixel 320, 1677 all of the neighbors are clouds
# in pixel 320, 1677 all of the neighbors are clouds
# in pixel 213, 1312 all of the neighbors are clouds
# in pixel 213, 1312 all of the neighbors are clouds
# in pixel 213, 1312 all of the neighbors are clouds
# in pixel 213, 1312 all of the neighbors are clouds
# in pixel 213, 1312 all of the neighbors are clouds
# in pixel 173, 868 all of the neighbors are clouds
# in pixel 173, 868 all of the neighbors are clouds
# in pixel 173, 868 all of the neighbors are clouds
# in pixel 173, 868 all of the neighbors are clouds
# in pixel 173, 868 all of the neighbors are clouds
# in pixel 131, 1301 all of the neighbors are clouds
# in pixel 131, 1301 all of the neighbors are clouds
# in pixel 131, 1301 all of the neighbors are clouds
# in pixel 131, 1301 all of the neighbors are clouds
# in pixel 131, 1301 all of the neighbors are clouds
# in pixel 159, 484 all of the neighbors are clouds
# in pixel 159, 484 all of the neighbors are clouds
# in pixel 159, 484 all of the neighbors are clouds
# in pixel 159, 484 all of the neighbors are clouds
# in pixel 159, 484 all of the neighbors are clouds
# in pixel 861, 256 all of the neighbors are clouds
# in pixel 861, 256 all of the neighbors are clouds
# in pixel 861, 256 all of the neighbors are clouds
# in pixel 861, 256 all of the neighbors are clouds
# in pixel 861, 256 all of the neighbors are clouds
# in pixel 214, 1227 all of the neighbors are clouds
# in pixel 214, 1227 all of the neighbors are clouds
# in pixel 214, 1227 all of the neighbors are clouds
# in pixel 214, 1227 all of the neighbors are clouds
# in pixel 214, 1227 all of the neighbors are clouds

# %% [markdown]
# * Now we can concat them and label them

# %%
df_non_fire_pixels_concat_temporal = pd.concat([df_non_fire_pixels, df_temporal_non_fire_pixels], axis=1)

# %%
df_non_fire_pixels_concat_temporal["fire_label"] = 0 ## add a column called "fire_label" and set it to 0

# %% [markdown]
# * Finally we can concat the fire and non fire pixels to a df

# %%
train_df = pd.concat([df_fire_pixels_concat_temporal, df_non_fire_pixels_concat_temporal]).reset_index(drop=True)

# %%
train_df[:5]
# Out:
#        t0_MCMI_file t0_GOES_date_time  row  col  VIIRS_fp_max  VIIRS_fp_sum  \
# 0  s202201010731.nc  2022-01-01 07:31  245  804           2.0           2.0
# 1  s202201010731.nc  2022-01-01 07:31  273  739           1.0           2.0
# 2  s202201010731.nc  2022-01-01 07:31  274  741           1.0           1.0
# 3  s202201010731.nc  2022-01-01 07:31  295  730           2.0           4.0
# 4  s202201010731.nc  2022-01-01 07:31  303  805           1.0           1.0
#
#    t0_B01_value  t0_B01_mean  t0_B01_median  t0_B01_std  ...  t4_B16_max  \
# 0           0.0       -999.0         -999.0      -999.0  ... -999.000000
# 1           0.0       -999.0         -999.0      -999.0  ... -999.000000
# 2           0.0       -999.0         -999.0      -999.0  ... -999.000000
# 3           0.0       -999.0         -999.0      -999.0  ...  268.740570
# 4           0.0          0.0            0.0         0.0  ...  270.503174
#
#    t4_FI_value  t4_FI_mean  t4_FI_median   t4_FI_std   t4_FI_min   t4_FI_max  \
# 0     0.013518 -999.000000   -999.000000 -999.000000 -999.000000 -999.000000
# 1     0.009540 -999.000000   -999.000000 -999.000000 -999.000000 -999.000000
# 2     0.010895 -999.000000   -999.000000 -999.000000 -999.000000 -999.000000
# 3     0.006053    0.004273      0.004349    0.000522    0.003545    0.004847
# 4    -0.002857   -0.002898     -0.002830    0.000714   -0.004262   -0.002012
#
#    t4_FDC_value  t4_ACM_value  fire_label
# 0         240.0           3.0           1
# 1         100.0           3.0           1
# 2         240.0           3.0           1
# 3         100.0           3.0           1
# 4         100.0           1.0           1
#
# [5 rows x 538 columns]

# %% [markdown]
# # Now we can do it as a one function

# %%
no_VIIRS_points_GOES_files_list = [] ## create an empty list to store the GOES files with no VIIRS points
error_list = [] ## create an empty list to store the errors
ml_df_list = [] ## create an empty list to store the ml_df
start_image = 3300 ## start image
number_of_image = 3400 ## number of images we iterate through
file_number = 7 ## file number

for i in range(start_image, number_of_image): ## loop through all the NC_VIIRS_df
    print(f"Now working on {i} out of {len(NC_VIIRS_df)}")
    MCMI_path = NC_VIIRS_df["MCMI"].iloc[i] ## get the MCMI path
    FDC_path = NC_VIIRS_df["FDC"].iloc[i] ## get the FDC path
    ACM_path = NC_VIIRS_df["ACM"].iloc[i] ## get the ACM path
    VIIRS_path = NC_VIIRS_df["VIIRS_file_full_path"].iloc[i] ## get the VIIRS path
    GOES_date_time = NC_VIIRS_df["GOES_date_time"].iloc[i] ## get the GOES date time
    VIIRS_file = NC_VIIRS_df["VIIRS_file"].iloc[i] ## get the VIIRS file
    VIIRS_filter = VIIRS[VIIRS["Fire_file"] == VIIRS_file] ## filter the VIIRS dataframe
    
    if len(VIIRS_filter) == 0: ## if the VIIRS length is 0
        print(f"No VIIRS points for {GOES_date_time}")
        no_VIIRS_points_GOES_files_list.append(GOES_date_time)
        continue ## skip the iteration
    else: ## if the VIIRS length is greater than 0
        try: ## try the following code
            ## create the ml_df
            ml_df = MLT.create_ML_training_df(MCMI_path=MCMI_path,
                                      FDC_path=FDC_path,
                                      ACM_path=ACM_path,
                                      VIIRS_path=VIIRS_path,
                                      GOES_date_time=GOES_date_time,
                                      filter_VIIRS=VIIRS_filter,
                                      temporal_df=temporal_df,
                                      VIIRS_threshold=1,
                                      number_of_temporal_GOES_images=4,
                                      number_of_non_fire_pixels=500,
                                      cloud_probability_list=[2,3]) ## probably cloud (2) and cloud (3)
            ml_df_list.append(ml_df) ## append the ml_df to the ml_df_list
            print(f"{i} out of {len(NC_VIIRS_df)} completed") ## print the progress
        except Exception as e: ## if there is an error
            print(f"Error: {e} in {GOES_date_time}") ## print the error
            error_list.append(GOES_date_time) ## append the GOES date time to the error list
            continue ## skip the iteration
# Out:
# Now working on 3200 out of 4449
# Now working of GOES time stamp: 2023-06-06 09:41
# rasterize VIIRS is done for GOES time stamp: 2023-06-06 09:41
# GOES fire pixel list is done for GOES time stamp: 2023-06-06 09:41
# list of locations not to sample is done for GOES time stamp: 2023-06-06 09:41
# Starting to genrate 500 random non-fire pixels
# Genrated 500 random non-fire pixels for GOES time stamp: 2023-06-06 09:41
# staring to genrate fire pixel values for GOES time stamp: 2023-06-06 09:41
# Starting to get the fire pixel values for GOES time stamp: 2023-06-06 09:41
# done. Now starting working on the temporal data
# done. Now starting working on the non-fire pixels
# done. Now starting working on the temporal data
# done. df is ready for GOES time stamp: 2023-06-06
# rasterize VIIRS is done for GOES time stamp: 2023-06-21 19:36
# GOES fire pixel list is done for GOES time stamp: 2023-06-21 19:36
# list of locations not to sample is done for GOES time stamp: 2023-06-21 19:36
# Starting to genrate 500 random non-fire pixels
# Genrated 500 random non-fire pixels for GOES time stamp: 2023-06-21 19:36
# staring to genrate fire pixel values for GOES time stamp: 2023-06-21 19:36
# Starting to get the fire pixel values for GOES time stamp: 2023-06-21 19:36
# done. Now starting working on the temporal data
# done. Now starting working on the non-fire pixels
# done. Now starting working on the temporal data
# done. df is ready for GOES time stamp: 2023-06-21 19:36
# 3298 out of 4449 completed
# Now working on 3299 out of 4449
# Now working of GOES time stamp: 2023-06-21 19:41
# rasterize VIIRS is done for GOES time stamp: 2023-06-21 19:41
# GOES fire pixel list is done for GOES time stamp: 2023-06-21 19:41
# list of locations not to sample is done for GOES time stamp: 2023-06-21 19:41
# Starting to genrate 500 random non-fire pixels
# Genrated 500 random non-fire pixels for GOES time stamp: 2023-06-21 19:41
# staring to genrate fire pixel values for GOES time stamp: 2023-06-21 19:41
# Starting to get the fire pixel values for GOES time stamp: 2023-06-21 19:41
# done. Now starting working on the temporal data
# done. Now starting working on the non-fire pixels
# done. Now starting working on the temporal data
# done. df is ready for GOES time stamp: 2023-06-21 19:41
# 3299 out of 4449 completed

# %%
ml_df_concat = pd.concat(ml_df_list).reset_index(drop=True) ## concatenate the ml_df_list

# %%
ml_df_concat[:5]
# Out:
#        t0_MCMI_file t0_GOES_date_time  row  col  VIIRS_fp_max  VIIRS_fp_sum  \
# 0  s202306060941.nc  2023-06-06 09:41  482  659           1.0           1.0
# 1  s202306060941.nc  2023-06-06 09:41  485  662           2.0           2.0
# 2  s202306060941.nc  2023-06-06 09:41  488  662           2.0           3.0
# 3  s202306060941.nc  2023-06-06 09:41  488  661           2.0           5.0
# 4  s202306060941.nc  2023-06-06 09:41  489  660           2.0           4.0
#
#    t0_B01_value  t0_B01_mean  t0_B01_median  t0_B01_std  ...  t4_B16_max  \
# 0           0.0          0.0            0.0         0.0  ...  269.236298
# 1           0.0          0.0            0.0         0.0  ...  269.236298
# 2           0.0          0.0            0.0         0.0  ...  269.126160
# 3           0.0          0.0            0.0         0.0  ...  269.126160
# 4           0.0          0.0            0.0         0.0  ...  269.236298
#
#    t4_FI_value  t4_FI_mean  t4_FI_median  t4_FI_std  t4_FI_min  t4_FI_max  \
# 0    -0.002219   -0.002819     -0.002725   0.000373  -0.003499  -0.002334
# 1    -0.001350   -0.001398     -0.001467   0.000520  -0.002108  -0.000603
# 2     0.001886   -0.000845     -0.000405   0.000910  -0.002367   0.000193
# 3     0.000193   -0.000492     -0.000309   0.001238  -0.001976   0.001886
# 4     0.000478   -0.001344     -0.001466   0.001057  -0.002753   0.000193
#
#    t4_FDC_value  t4_ACM_value  fire_label
# 0         100.0           0.0           1
# 1         100.0           0.0           1
# 2         100.0           0.0           1
# 3         100.0           0.0           1
# 4         100.0           0.0           1
#
# [5 rows x 538 columns]

# %%
out_dir = r'C:\Users\asaf_rs\Dropbox\Fire_Detection\python_ML_project\create_ML_df\train_df' ## output directory

# %%
if not os.path.exists(out_dir): ## check if the output directory does not exist
    os.makedirs(out_dir) ## create the output directory
    ml_df_concat.to_pickle(os.path.join(out_dir, f"train_df_{file_number}.pkl")) ## save the ml_df_concat to a pickle file
else: ## if the output directory exists
    ml_df_concat.to_pickle(os.path.join(out_dir, f"train_df_{file_number}.pkl")) ## save the ml_df_concat to a pickle file
